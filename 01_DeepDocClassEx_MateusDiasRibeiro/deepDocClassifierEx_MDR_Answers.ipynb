# %% [markdown]
# **Exercise lecture 1 (Mateus Dias Ribeiro)**
#
# **Download Tobacco-3482 dataset:**
#
# For this exercise lecture, we are going to use a Deep Convolutional Architecture (AlexNet) to perform a classification task on the Tobbaco-3482 legistlation dataset. This dataset contains documents regarding information about the Tobacco industry in 10 different classes:
#
# 0 Ad
# 1 Email
# 2 Form
# 3 Letter
# 4 Memo
# 5 News
# 6 Note
# 7 Report
# 8 Resume
# 9 Scientific
#
#
# ![A few samples of the Tobacco-3482 dataset](https://drive.google.com/uc?export=download&id=11VP9e0YRZ321Rrpjq1suiJlONFh7pka8)
#
# Our goal here is to use Keras to replicate the results obtained in this paper:
#
# **M. Z. Afzal et al., "Deepdocclassifier: Document classification with deep Convolutional Neural Network," 2015 13th International Conference on Document Analysis and Recognition (ICDAR), Tunis, 2015, pp. 1111-1115.
# doi: 10.1109/ICDAR.2015.7333933**
#
# In that paper, the authors used the AlexNet architecture with pre-trained weights obtained from training the network on the ImageNet dataset and have shown that transfer learning can be very useful to drastically reduce the number of necessary training samples.
#
# The original dataset can be downloaded here: https://lampsrv02.umiacs.umd.edu/projdb/project.php?id=72.
#
# To start, let's download the dataset:

# %%
# !wget http://lampsrv02.umiacs.umd.edu/projdb/edit/userfiles/datasets/Tobacco3482_1.zip
# !wget http://lampsrv02.umiacs.umd.edu/projdb/edit/userfiles/datasets/Tobacco3482_2.zip
# Out:
# --2020-12-16 15:44:29--  http://lampsrv02.umiacs.umd.edu/projdb/edit/userfiles/datasets/Tobacco3482_1.zip
# Resolving lampsrv02.umiacs.umd.edu (lampsrv02.umiacs.umd.edu)... 128.8.132.49
# Connecting to lampsrv02.umiacs.umd.edu (lampsrv02.umiacs.umd.edu)|128.8.132.49|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://lampsrv02.umiacs.umd.edu/projdb/edit/userfiles/datasets/Tobacco3482_1.zip [following]
# --2020-12-16 15:44:29--  https://lampsrv02.umiacs.umd.edu/projdb/edit/userfiles/datasets/Tobacco3482_1.zip
# Connecting to lampsrv02.umiacs.umd.edu (lampsrv02.umiacs.umd.edu)|128.8.132.49|:443... connected.
# HTTP request sent, awaiting response... 503 Service Unavailable
# 2020-12-16 15:44:30 ERROR 503: Service Unavailable.
#
# --2020-12-16 15:44:30--  http://lampsrv02.umiacs.umd.edu/projdb/edit/userfiles/datasets/Tobacco3482_2.zip
# Resolving lampsrv02.umiacs.umd.edu (lampsrv02.umiacs.umd.edu)... 128.8.132.49
# Connecting to lampsrv02.umiacs.umd.edu (lampsrv02.umiacs.umd.edu)|128.8.132.49|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://lampsrv02.umiacs.umd.edu/projdb/edit/userfiles/datasets/Tobacco3482_2.zip [following]
# --2020-12-16 15:44:30--  https://lampsrv02.umiacs.umd.edu/projdb/edit/userfiles/datasets/Tobacco3482_2.zip
# Connecting to lampsrv02.umiacs.umd.edu (lampsrv02.umiacs.umd.edu)|128.8.132.49|:443... connected.
# HTTP request sent, awaiting response... 503 Service Unavailable
# 2020-12-16 15:44:30 ERROR 503: Service Unavailable.

# %%
# !unzip Tobacco3482_1.zip
# !unzip Tobacco3482_2.zip
# Out:
# Archive:  Tobacco3482_1.zip
#    creating: Memo/
#   inflating: Memo/0000008957.tif
#   inflating: Memo/0000015571.tif
#   inflating: Memo/0000022175.tif
#   inflating: Memo/0000029906.tif
#   inflating: Memo/0000043910.tif
#   inflating: Memo/0000045457.tif
#   inflating: Memo/0000059503.tif
#   inflating: Memo/0000065944.tif
#   inflating: Memo/0000067671.tif
#   inflating: Memo/00000725.tif
#   inflating: Memo/0000073229.tif
#   inflating: Memo/0000083559.tif
#   inflating: Memo/0000104448.tif
#   inflating: Memo/0000108319.tif
#   inflating: Memo/0000118560.tif
#   inflating: Memo/0000124690.tif
#   inflating: Memo/0000131535.tif
#   inflating: Memo/0000135087.tif
#   inflating: Memo/0000141695.tif
#   inflating: Memo/0000146507.tif
#   inflating: Memo/0000146942.tif
#   inflating: Memo/0000159555.tif
#   inflating: Memo/0000168771.tif
#   inflating: Memo/0000169583.tif
#   inflating: Memo/0000170925.tif
#   inflating: Memo/0000193526.tif
#   inflating: Memo/0000208865.tif
#   inflating: Memo/0000211869.tif
#   inflating: Memo/0000229184.tif
#   inflating: Memo/0000237100.tif
#   inflating: Memo/0000237399.tif
#   inflating: Memo/0000249984.tif
#   inflating: Memo/0000262962.tif
#   inflating: Memo/0000264417.tif
#   inflating: Memo/0000296750.tif
#   inflating: Memo/0000328495.tif
#   inflating: Memo/0000347162.tif
#   inflating: Memo/0000384019.tif
#   inflating: Memo/0000386602.tif
#   inflating: Memo/0000391492.tif
#   inflating: Memo/0000393586.tif
#   inflating: Memo/0000408323.tif
#   inflating: Memo/0000456149.tif
#   inflating: Memo/0000474595.tif
#   inflating: Memo/0000488853.tif
#   inflating: Memo/0000547826.tif
#   inflating: Memo/0000554052.tif
#   inflating: Memo/00005729.tif
#   inflating: Memo/0000936338.tif
#   inflating: Memo/00104455_00104456.tif
#   inflating: Memo/00119510.tif
#   inflating: Memo/0013005994.tif
#   inflating: Memo/0013140948.tif
#   inflating: Memo/00137810_00137811.tif
#   inflating: Memo/00275226_00275227.tif
#   inflating: Memo/00377005.tif
#   inflating: Memo/00450130.tif
#   inflating: Memo/01046565.tif
#   inflating: Memo/01247680.tif
#   inflating: Memo/01329196.tif
#   inflating: Memo/01329768.tif
#   inflating: Memo/01337755.tif
#   inflating: Memo/01390279.tif
#   inflating: Memo/01586188.tif
#   inflating: Memo/01591430.tif
#   inflating: Memo/01777521.tif
#   inflating: Memo/03000416_03000417.tif
#   inflating: Memo/03335936.tif
#   inflating: Memo/03364017_03364022.tif
#   inflating: Memo/03370692_0695.tif
#   inflating: Memo/03523378.tif
#   inflating: Memo/03551612.tif
#   inflating: Memo/03615288_03615289.tif
#   inflating: Memo/03654458_03654459.tif
#   inflating: Memo/03683731.tif
#   inflating: Memo/03726299_03726300.tif
#   inflating: Memo/03854099.tif
#   inflating: Memo/04004176.tif
#   inflating: Memo/04101854.tif
#   inflating: Memo/04107922_04107926.tif
#   inflating: Memo/04145740.tif
#   inflating: Memo/04146448_6449.tif
#   inflating: Memo/04242498_04242510.tif
#   inflating: Memo/04366602_04366604.tif
#   inflating: Memo/04405847_04405848.tif
#   inflating: Memo/1000251492.tif
#   inflating: Memo/1000300824.tif
#   inflating: Memo/1000767360.tif
#   inflating: Memo/1000767446.tif
#   inflating: Memo/1000775306.tif
#   inflating: Memo/1000790663.tif
#   inflating: Memo/1000798221.tif
#   inflating: Memo/1000799097.tif
#   inflating: Memo/1000816599.tif
#   inflating: Memo/1000843369_1000843370.tif
#   inflating: Memo/1000874341_1000874344.tif
#   inflating: Memo/1001767165.tif
#   inflating: Memo/1001809385_1001809386.tif
#   inflating: Memo/1001823466.tif
#   inflating: Memo/1001850798.tif
#   inflating: Memo/1001854313.tif
#   inflating: Memo/1001854931.tif
#   inflating: Memo/1001857064_1001857068.tif
#   inflating: Memo/1001858525_1001858526.tif
#   inflating: Memo/1001861874.tif
#   inflating: Memo/1001866123_1001866124.tif
#   inflating: Memo/1001889415.tif
#   inflating: Memo/1001906916.tif
#   inflating: Memo/1002404594.tif
#   inflating: Memo/1002404720_1002404721.tif
#   inflating: Memo/1002907300.tif
#   inflating: Memo/1002977842_1002977847.tif
#   inflating: Memo/1003040251_1003040252.tif
#   inflating: Memo/1003120857.tif
#   inflating: Memo/1003194341_1003194342.tif
#   inflating: Memo/1003255575.tif
#   inflating: Memo/1003387594.tif
#   inflating: Memo/1003390961.tif
#   inflating: Memo/1003479904.tif
#   inflating: Memo/1003635090.tif
#   inflating: Memo/1003640109.tif
#   inflating: Memo/1003659451_1003659454.tif
#   inflating: Memo/1003723216_1003723218.tif
#   inflating: Memo/1003726944.tif
#   inflating: Memo/1004865799_1004865800.tif
#   inflating: Memo/1005020149_1005020151.tif
#   inflating: Memo/1005095578.tif
#   inflating: Memo/11005495.tif
#   inflating: Memo/11766882.tif
#   inflating: Memo/11886054.tif
#   inflating: Memo/12850443.tif
#   inflating: Memo/12997349.tif
#   inflating: Memo/13055817.tif
#   inflating: Memo/13313809.tif
#   inflating: Memo/1331806.tif
#   inflating: Memo/13497827.tif
#   inflating: Memo/1349980.tif
#   inflating: Memo/1368724.tif
#   inflating: Memo/1396849.tif
#   inflating: Memo/2000457615_2000457620.tif
#   inflating: Memo/2000485447.tif
#   inflating: Memo/2000621665.tif
#   inflating: Memo/2000621910.tif
#   inflating: Memo/2000766495_2000766497.tif
#   inflating: Memo/2010067199.tif
#   inflating: Memo/2012580836.tif
#   inflating: Memo/2012581990.tif
#   inflating: Memo/2015017717_2015017719.tif
#   inflating: Memo/2015023714.tif
#   inflating: Memo/2020134234.tif
#   inflating: Memo/2020136618_2020136619.tif
#   inflating: Memo/2020157078.tif
#   inflating: Memo/2020238777.tif
#   inflating: Memo/2020268309.tif
#   inflating: Memo/2020280503.tif
#   inflating: Memo/2020340083.tif
#   inflating: Memo/2021266006.tif
#   inflating: Memo/2021514201_2021514203.tif
#   inflating: Memo/2021548067.tif
#   inflating: Memo/2021601265.tif
#   inflating: Memo/2022142525.tif
#   inflating: Memo/2022161599_2022161600.tif
#   inflating: Memo/2022164378.tif
#   inflating: Memo/2022165302_2022165304.tif
#   inflating: Memo/2022177049_2022177054.tif
#   inflating: Memo/2022180658_0659.tif
#   inflating: Memo/2022181033.tif
#   inflating: Memo/2022184512_2022184519.tif
#   inflating: Memo/2022209162.tif
#   inflating: Memo/2022210456_2022210457.tif
#   inflating: Memo/2022233786.tif
#   inflating: Memo/2022244803_2022244805.tif
#   inflating: Memo/2022249818.tif
#   inflating: Memo/2022254267.tif
#   inflating: Memo/2022923966.tif
#   inflating: Memo/2022948982.tif
#   inflating: Memo/2023012813.tif
#   inflating: Memo/2023118626_2023118627.tif
#   inflating: Memo/2023118657_2023118670.tif
#   inflating: Memo/2023408782_2023408790.tif
#   inflating: Memo/2023431005.tif
#   inflating: Memo/2023437101.tif
#   inflating: Memo/2023539362_2023539363.tif
#   inflating: Memo/2023551065_2023551066.tif
#   inflating: Memo/2024072051_2024072053.tif
#   inflating: Memo/2024257952.tif
#   inflating: Memo/2024412663.tif
#   inflating: Memo/2024462000_2024462016.tif
#   inflating: Memo/2024547864_2024547866.tif
#   inflating: Memo/2024816564_2024816570.tif
#   inflating: Memo/2024817982_2024817996.tif
#   inflating: Memo/2024821651_1652.tif
#   inflating: Memo/2024836429_2024836430.tif
#   inflating: Memo/2024850061_2024850070.tif
#   inflating: Memo/2024939330.tif
#   inflating: Memo/2024986135.tif
#   inflating: Memo/2025449419.tif
#   inflating: Memo/2025612606_2609.tif
#   inflating: Memo/2025614641_2025614644.tif
#   inflating: Memo/2025851048_2025851049.tif
#   inflating: Memo/2025875649.tif
#   inflating: Memo/2025877604.tif
#   inflating: Memo/2025887469.tif
#   inflating: Memo/2026164697_2026164699.tif
#   inflating: Memo/2026374867_2026374868.tif
#   inflating: Memo/2026459463.tif
#   inflating: Memo/2028584557_2028584558.tif
#   inflating: Memo/2029198047_2029198056.tif
#   inflating: Memo/2030016727_2030016729.tif
#   inflating: Memo/2030062998.tif
#   inflating: Memo/2030471856.tif
#   inflating: Memo/2030545412_2030545413.tif
#   inflating: Memo/2030974392.tif
#   inflating: Memo/2031015329_2031015330.tif
#   inflating: Memo/2031263025.tif
#   inflating: Memo/2031400439_2031400441.tif
#   inflating: Memo/2031562974.tif
#   inflating: Memo/2040287760_2040287794.tif
#   inflating: Memo/2040324939.tif
#   inflating: Memo/2040358117.tif
#   inflating: Memo/2040465704.tif
#   inflating: Memo/2040733938.tif
#   inflating: Memo/2040759890.tif
#   inflating: Memo/2040885396.tif
#   inflating: Memo/2040907509.tif
#   inflating: Memo/2040929289.tif
#   inflating: Memo/2041060506_2041060507.tif
#   inflating: Memo/2041102766.tif
#   inflating: Memo/2041268603_2041268605.tif
#   inflating: Memo/2041356925.tif
#   inflating: Memo/2041400194.tif
#   inflating: Memo/2041563228_2041563229.tif
#   inflating: Memo/2041837000_2041837001.tif
#   inflating: Memo/2041853500_2041853508.tif
#   inflating: Memo/2041874888.tif
#   inflating: Memo/2042014987.tif
#   inflating: Memo/2042017254.tif
#   inflating: Memo/2042111525_2042111534.tif
#   inflating: Memo/2042374171_2042374174.tif
#   inflating: Memo/2042389568_9570.tif
#   inflating: Memo/2042404241.tif
#   inflating: Memo/2042471428.tif
#   inflating: Memo/2042506790_2042506791.tif
#   inflating: Memo/2042790056_2042790059.tif
#   inflating: Memo/2042812605.tif
#   inflating: Memo/2042813526_2042813527.tif
#   inflating: Memo/2043215175.tif
#   inflating: Memo/2043230492_2043230503.tif
#   inflating: Memo/2043230684_2043230686.tif
#   inflating: Memo/2043616262_2043616266.tif
#   inflating: Memo/2043894005.tif
#   inflating: Memo/2044093019.tif
#   inflating: Memo/2044175001_2044175002.tif
#   inflating: Memo/2044198652.tif
#   inflating: Memo/2044300004.tif
#   inflating: Memo/2044393287.tif
#   inflating: Memo/2044801453.tif
#   inflating: Memo/2045083823_2045083824.tif
#   inflating: Memo/2045186816.tif
#   inflating: Memo/2045187675_2045187679.tif
#   inflating: Memo/2045373494_2045373496.tif
#   inflating: Memo/2045476428_2045476436.tif
#   inflating: Memo/2045482589_2590.tif
#   inflating: Memo/2045845326.tif
#   inflating: Memo/2046000414_2046000415.tif
#   inflating: Memo/2046538342.tif
#   inflating: Memo/2046579981_2046579987.tif
#   inflating: Memo/2046912122_2123.tif
#   inflating: Memo/2047038707_8709.tif
#   inflating: Memo/2047315478.tif
#   inflating: Memo/2047441654.tif
#   inflating: Memo/2047523173_3191.tif
#   inflating: Memo/2047921425.tif
#   inflating: Memo/2047929185.tif
#   inflating: Memo/2047932359_2047932361.tif
#   inflating: Memo/2047934116.tif
#   inflating: Memo/2048124824_4825.tif
#   inflating: Memo/2048129510.tif
#   inflating: Memo/2048153405_2048153423.tif
#   inflating: Memo/2048228137.tif
#   inflating: Memo/2048240768_2048240769.tif
#   inflating: Memo/2048305604.tif
#   inflating: Memo/2048309984.tif
#   inflating: Memo/2048714647.tif
#   inflating: Memo/2048965327_2048965331.tif
#   inflating: Memo/2049050527_2049050536.tif
#   inflating: Memo/2049298600_2049298603.tif
#   inflating: Memo/2049308509.tif
#   inflating: Memo/2049386508_2049386509.tif
#   inflating: Memo/2049461223.tif
#   inflating: Memo/2050258326.tif
#   inflating: Memo/2050531873_2050531874.tif
#   inflating: Memo/2050794145.tif
#   inflating: Memo/2050801870_1873.tif
#   inflating: Memo/2050804253_2050804255.tif
#   inflating: Memo/2050941553.tif
#   inflating: Memo/2050959395_2050959399.tif
#   inflating: Memo/2050984554.tif
#   inflating: Memo/2051034159.tif
#   inflating: Memo/2051035077_5081.tif
#   inflating: Memo/2051044337.tif
#   inflating: Memo/2051063550.tif
#   inflating: Memo/2051064987.tif
#   inflating: Memo/2051080096.tif
#   inflating: Memo/2051083199.tif
#   inflating: Memo/2051110023.tif
#   inflating: Memo/2051111206.tif
#   inflating: Memo/2051115864.tif
#   inflating: Memo/2051117086.tif
#   inflating: Memo/2051122847.tif
#   inflating: Memo/2051123179_2051123180.tif
#   inflating: Memo/2051124321_2051124322.tif
#   inflating: Memo/2051443365.tif
#   inflating: Memo/2051575345_2051575346.tif
#   inflating: Memo/2051691699_2051691700.tif
#   inflating: Memo/2051798475.tif
#   inflating: Memo/2051989880_2051989881.tif
#   inflating: Memo/2053471549.tif
#   inflating: Memo/2053522412.tif
#   inflating: Memo/2054504061_2054504063.tif
#   inflating: Memo/2054524189.tif
#   inflating: Memo/2054544305.tif
#   inflating: Memo/2054547221.tif
#   inflating: Memo/2054608832_2054608833.tif
#   inflating: Memo/2054620205_2054620206.tif
#   inflating: Memo/2054621429.tif
#   inflating: Memo/2054641494.tif
#   inflating: Memo/2054643904.tif
#   inflating: Memo/2054767991_7992.tif
#   inflating: Memo/2054838139_2054838140.tif
#   inflating: Memo/2054857059.tif
#   inflating: Memo/2054924695.tif
#   inflating: Memo/2054927900_2054927901.tif
#   inflating: Memo/2054964454.tif
#   inflating: Memo/2055043947_2055043948.tif
#   inflating: Memo/2055649545.tif
#   inflating: Memo/2056133713_2056133715.tif
#   inflating: Memo/2056172030_2056172032.tif
#   inflating: Memo/2056174385_4386.tif
#   inflating: Memo/2056291607.tif
#   inflating: Memo/2056550084_2056550086.tif
#   inflating: Memo/2056706291.tif
#   inflating: Memo/2057143978_2057143979.tif
#   inflating: Memo/2057154439_2057154440.tif
#   inflating: Memo/2057274390_2057274393.tif
#   inflating: Memo/2057274729_2057274731.tif
#   inflating: Memo/2057362082.tif
#   inflating: Memo/2057702349.tif
#   inflating: Memo/2057710690.tif
#   inflating: Memo/2057718509_2057718511.tif
#   inflating: Memo/2057722185_2057722186.tif
#   inflating: Memo/2057729267_2057729278.tif
#   inflating: Memo/2057762122_2057762125.tif
#   inflating: Memo/2057775423.tif
#   inflating: Memo/2058006466.tif
#   inflating: Memo/2058089097.tif
#   inflating: Memo/2058090026.tif
#   inflating: Memo/2058122315_2058122318.tif
#   inflating: Memo/2060084593_2060084599.tif
#   inflating: Memo/2060133571.tif
#   inflating: Memo/2060167949.tif
#   inflating: Memo/2060347872_2060347873.tif
#   inflating: Memo/2060353871-a_2060353872.tif
#   inflating: Memo/2060384942_2060384946.tif
#   inflating: Memo/2060528454_2060528455.tif
#   inflating: Memo/2061639550.tif
#   inflating: Memo/2061648199.tif
#   inflating: Memo/2061654420.tif
#   inflating: Memo/2061670897.tif
#   inflating: Memo/2061678550.tif
#   inflating: Memo/2061839050.tif
#   inflating: Memo/2061880058_0070.tif
#   inflating: Memo/2062210337.tif
#   inflating: Memo/2062304594.tif
#   inflating: Memo/2062427064_2062427071.tif
#   inflating: Memo/2063435963.tif
#   inflating: Memo/2063695266_5268.tif
#   inflating: Memo/2064233234.tif
#   inflating: Memo/2064509602_9604.tif
#   inflating: Memo/2064724557_4560.tif
#   inflating: Memo/2064835504.tif
#   inflating: Memo/2065224640_4641.tif
#   inflating: Memo/2065268936_8938.tif
#   inflating: Memo/2065281482_1483.tif
#   inflating: Memo/2065322958.tif
#   inflating: Memo/2065335800.tif
#   inflating: Memo/2065449140_9141.tif
#   inflating: Memo/2069625942_5947.tif
#   inflating: Memo/2070135879.tif
#   inflating: Memo/2070268662.tif
#   inflating: Memo/2070370405.tif
#   inflating: Memo/2070416152.tif
#   inflating: Memo/2071386961.tif
#   inflating: Memo/2071493775_3778.tif
#   inflating: Memo/2071760875.tif
#   inflating: Memo/2071860205_0207.tif
#   inflating: Memo/2072006278.tif
#   inflating: Memo/2072173651_3652.tif
#   inflating: Memo/2072205854.tif
#   inflating: Memo/2072514128_4129.tif
#   inflating: Memo/2072607314_7316.tif
#   inflating: Memo/2072613990.tif
#   inflating: Memo/2072665602.tif
#   inflating: Memo/2072813043.tif
#   inflating: Memo/2072877887.tif
#   inflating: Memo/2072940944.tif
#   inflating: Memo/2072956847.tif
#   inflating: Memo/2073000609_0614.tif
#   inflating: Memo/2073005257.tif
#   inflating: Memo/2073008759_8760.tif
#   inflating: Memo/2073114345.tif
#   inflating: Memo/2073336543.tif
#   inflating: Memo/2073365529_5534.tif
#   inflating: Memo/2073420633.tif
#   inflating: Memo/2073437503_7504.tif
#   inflating: Memo/2073453930.tif
#   inflating: Memo/2073497485_7486.tif
#   inflating: Memo/2073883296.tif
#   inflating: Memo/2073893399.tif
#   inflating: Memo/2073932597.tif
#   inflating: Memo/2074110669.tif
#   inflating: Memo/2074123192.tif
#   inflating: Memo/2074163081.tif
#   inflating: Memo/2074356039_6048.tif
#   inflating: Memo/2074663413_3414.tif
#   inflating: Memo/2074737024_7028.tif
#   inflating: Memo/2074847095.tif
#   inflating: Memo/2074865778_5785.tif
#   inflating: Memo/2075008304.tif
#   inflating: Memo/2075067412.tif
#   inflating: Memo/2075169250_9251.tif
#   inflating: Memo/2076128735_8736.tif
#   inflating: Memo/2076790792.tif
#   inflating: Memo/2076900993.tif
#   inflating: Memo/2078202885_2886.tif
#   inflating: Memo/2078250319.tif
#   inflating: Memo/2078388379.tif
#   inflating: Memo/2078645121_5122.tif
#   inflating: Memo/2078755206.tif
#   inflating: Memo/2078795106.tif
#   inflating: Memo/2080486842.tif
#   inflating: Memo/2080896959_6964.tif
#   inflating: Memo/2081803353.tif
#   inflating: Memo/2081932182.tif
#   inflating: Memo/2082514837.tif
#   inflating: Memo/2082621396.tif
#   inflating: Memo/2082742674.tif
#   inflating: Memo/2082852748_2749.tif
#   inflating: Memo/2083136135_6136.tif
#   inflating: Memo/2083776812.tif
#   inflating: Memo/2085618986.tif
#   inflating: Memo/24008317.tif
#   inflating: Memo/2500120257_2500120259.tif
#   inflating: Memo/2501027943.tif
#   inflating: Memo/2501065502.tif
#   inflating: Memo/2501316792_2501316793.tif
#   inflating: Memo/2501536718_2501536725.tif
#   inflating: Memo/2504048594_2504048611.tif
#   inflating: Memo/2504078584_2504078585.tif
#   inflating: Memo/2505338622.tif
#   inflating: Memo/44007097.tif
#   inflating: Memo/603677.tif
#   inflating: Memo/611829.tif
#   inflating: Memo/633619.tif
#   inflating: Memo/71146504.tif
#   inflating: Memo/80317519_7522.tif
#   inflating: Memo/80413408_80413420.tif
#   inflating: Memo/80502221_80502224.tif
#   inflating: Memo/80552294.tif
#   inflating: Memo/80722057_2058.tif
#   inflating: Memo/80726625_80726632.tif
#   inflating: Memo/80911283_80911286.tif
#   inflating: Memo/81153042_81153046.tif
#   inflating: Memo/81331173_81331174.tif
#   inflating: Memo/81634973.tif
#   inflating: Memo/81745625_5631.tif
#   inflating: Memo/82088755_8759.tif
#   inflating: Memo/82227170_7183.tif
#   inflating: Memo/82252355_2356.tif
#   inflating: Memo/82411349_1362.tif
#   inflating: Memo/82456991_6998.tif
#   inflating: Memo/82581670.tif
#   inflating: Memo/82777112.tif
#   inflating: Memo/82782147.tif
#   inflating: Memo/82866939.tif
#   inflating: Memo/82918230_82918239.tif
#   inflating: Memo/82919105.tif
#   inflating: Memo/83098512_8517.tif
#   inflating: Memo/83448568_8579.tif
#   inflating: Memo/83504123_4129.tif
#   inflating: Memo/83594945_4946.tif
#   inflating: Memo/83644858.tif
#   inflating: Memo/83664478.tif
#   inflating: Memo/85004412.tif
#   inflating: Memo/85014287_4299.tif
#   inflating: Memo/85026674_85026676.tif
#   inflating: Memo/85067598.tif
#   inflating: Memo/85069315.tif
#   inflating: Memo/85146382.tif
#   inflating: Memo/85418261.tif
#   inflating: Memo/85560397.tif
#   inflating: Memo/85580479_85580482.tif
#   inflating: Memo/85615141.tif
#   inflating: Memo/85622275.tif
#   inflating: Memo/86002263.tif
#   inflating: Memo/86235667_5668.tif
#   inflating: Memo/86264944_4947.tif
#   inflating: Memo/86265143.tif
#   inflating: Memo/86280048_0055.tif
#   inflating: Memo/86373252_3255.tif
#   inflating: Memo/86448705_8716.tif
#   inflating: Memo/86546074.tif
#   inflating: Memo/87048757_87048766.tif
#   inflating: Memo/87051325.tif
#   inflating: Memo/87222823_2825.tif
#   inflating: Memo/87293861_3880.tif
#   inflating: Memo/87325335_87325337.tif
#   inflating: Memo/87328513_87328514.tif
#   inflating: Memo/87348404.tif
#   inflating: Memo/87398712.tif
#   inflating: Memo/87644162_87644163.tif
#   inflating: Memo/87718409.tif
#   inflating: Memo/87746801_87746802.tif
#   inflating: Memo/87800043_87800056.tif
#   inflating: Memo/87842606_2608.tif
#   inflating: Memo/87856898_87856902.tif
#   inflating: Memo/87915745_87915751.tif
#   inflating: Memo/88063780.tif
#   inflating: Memo/88116311_88116313.tif
#   inflating: Memo/88141193.tif
#   inflating: Memo/88142422.tif
#   inflating: Memo/88260444_88260447.tif
#   inflating: Memo/88889211.tif
#   inflating: Memo/88898679.tif
#   inflating: Memo/88899010.tif
#   inflating: Memo/88980966.tif
#   inflating: Memo/88990360.tif
#   inflating: Memo/89002796.tif
#   inflating: Memo/89096277_6278.tif
#   inflating: Memo/89209498_9500.tif
#   inflating: Memo/89282762.tif
#   inflating: Memo/89282835.tif
#   inflating: Memo/89286069.tif
#   inflating: Memo/89446070_89446076.tif
#   inflating: Memo/89449655.tif
#   inflating: Memo/89481112_1122.tif
#   inflating: Memo/89618674.tif
#   inflating: Memo/89678340.tif
#   inflating: Memo/89841379_1381.tif
#   inflating: Memo/89841477.tif
#   inflating: Memo/89939582.tif
#   inflating: Memo/89955590.tif
#   inflating: Memo/91288318_91288320.tif
#   inflating: Memo/91377755_91377757.tif
#   inflating: Memo/91637208_91637211.tif
#   inflating: Memo/91757213.tif
#   inflating: Memo/91765155.tif
#   inflating: Memo/91863222.tif
#   inflating: Memo/91878674_91878675.tif
#   inflating: Memo/91971720_1721.tif
#   inflating: Memo/91975408_5411.tif
#   inflating: Memo/91979761_9767.tif
#   inflating: Memo/91981329_1338.tif
#   inflating: Memo/91983999.tif
#   inflating: Memo/92064329_92064330.tif
#   inflating: Memo/92292808_2811.tif
#   inflating: Memo/92631332_1338.tif
#   inflating: Memo/92638744.tif
#   inflating: Memo/92672244.tif
#   inflating: Memo/92707788.tif
#   inflating: Memo/92757436.tif
#   inflating: Memo/93164272_93164273.tif
#   inflating: Memo/93208121.tif
#   inflating: Memo/93252933.tif
#   inflating: Memo/93299184.tif
#   inflating: Memo/93444732a.tif
#   inflating: Memo/93802240.tif
#   inflating: Memo/94011032_94011033.tif
#   inflating: Memo/95666861_6867.tif
#   inflating: Memo/96008379.tif
#   inflating: Memo/96018383.tif
#   inflating: Memo/96018853_8858.tif
#   inflating: Memo/96222726.tif
#   inflating: Memo/96630332.tif
#   inflating: Memo/96653443.tif
#   inflating: Memo/98161549.tif
#   inflating: Memo/98201361_1362.tif
#   inflating: Memo/98215328_5336.tif
#   inflating: Memo/98341362.tif
#   inflating: Memo/98416803_6804.tif
#   inflating: Memo/98419843.tif
#   inflating: Memo/98468802_8809.tif
#   inflating: Memo/98754928.tif
#   inflating: Memo/98779515.tif
#   inflating: Memo/98862271.tif
#   inflating: Memo/98864336.tif
#   inflating: Memo/99115867_5869.tif
#   inflating: Memo/dun00608.51_dun00608.52.tif
#   inflating: Memo/tcal0367773.tif
#   inflating: Memo/Thumbs.db
#   inflating: Memo/ti00290170_0176.tif
#   inflating: Memo/ti01480811_0814.tif
#   inflating: Memo/ti04960317.tif
#   inflating: Memo/ti07830376.tif
#   inflating: Memo/titx0625.92_titx0626.16.tif
#   inflating: Memo/titx1529.40_titx1529.41.tif
#   inflating: Memo/tnwl0049688_9693.tif
#   inflating: Memo/tob00500.02.tif
#   inflating: Memo/tob01919.07.tif
#   inflating: Memo/tob03508.13.tif
#   inflating: Memo/tob07006.81.tif
#   inflating: Memo/tob07720.02.tif
#   inflating: Memo/tob08906.50.tif
#   inflating: Memo/tob10601.37.tif
#   inflating: Memo/tob12300.33_tob12300.34.tif
#   inflating: Memo/tob13820.34.tif
#   inflating: Memo/tob15809.19.tif
#   inflating: Memo/tob17612.72_tob17612.74.tif
#   inflating: Memo/tob18717.65.tif
#   inflating: Memo/ton00631.03_ton00631.05.tif
#   inflating: Memo/ton05123.21.tif
#    creating: News/
#   inflating: News/0000023720.tif
#   inflating: News/0000114117.tif
#   inflating: News/0000162076.tif
#   inflating: News/0000240416.tif
#   inflating: News/0000330171.tif
#   inflating: News/0000334176.tif
#   inflating: News/0000343395.tif
#   inflating: News/0000644359.tif
#   inflating: News/0000940821.tif
#   inflating: News/0011927386.tif
#   inflating: News/00625137.tif
#   inflating: News/01138186a.tif
#   inflating: News/01182899.tif
#   inflating: News/01752917.tif
#   inflating: News/03620726.tif
#   inflating: News/03747860.tif
#   inflating: News/03754144-b.tif
#   inflating: News/04303523-a.tif
#   inflating: News/04328080.tif
#   inflating: News/1000150875-a.tif
#   inflating: News/1002402255-a.tif
#   inflating: News/1002402586.tif
#   inflating: News/1002402743a.tif
#   inflating: News/1002403141.tif
#   inflating: News/10029170.tif
#   inflating: News/10029418.tif
#   inflating: News/10029716.tif
#   inflating: News/10030014.tif
#   inflating: News/10030096.tif
#   inflating: News/10030149.tif
#   inflating: News/10030325.tif
#   inflating: News/1003042513-b.tif
#   inflating: News/1003042516-b.tif
#   inflating: News/1003043256-a.tif
#   inflating: News/1003043510-a.tif
#   inflating: News/1003044160-e.tif
#   inflating: News/1003044181.tif
#   inflating: News/1003044360-a.tif
#   inflating: News/1003044520-b.tif
#   inflating: News/1003044581-a.tif
#   inflating: News/10030463.tif
#   inflating: News/10030834.tif
#   inflating: News/1003099991.tif
#   inflating: News/10031067.tif
#   inflating: News/10031147.tif
#   inflating: News/10031350.tif
#   inflating: News/10031395.tif
#   inflating: News/10031617.tif
#   inflating: News/10032025.tif
#   inflating: News/1003537661.tif
#   inflating: News/1003537794-a.tif
#   inflating: News/1003538042-c.tif
#   inflating: News/1003538199-a.tif
#   inflating: News/1003542938.tif
#   inflating: News/1003543120.tif
#   inflating: News/1004859787.tif
#   inflating: News/1005037224-a.tif
#   inflating: News/1005125627.tif
#   inflating: News/1005150648-a.tif
#   inflating: News/1005150791.tif
#   inflating: News/1005151248.tif
#   inflating: News/10077592.tif
#   inflating: News/10226460.tif
#   inflating: News/10405567.tif
#   inflating: News/11311025.tif
#   inflating: News/2001222207.tif
#   inflating: News/2010030882.tif
#   inflating: News/2015024734.tif
#   inflating: News/2015036663.tif
#   inflating: News/2016003493.tif
#   inflating: News/2021174533_2021174534.tif
#   inflating: News/2021279291.tif
#   inflating: News/2023175414.tif
#   inflating: News/2023266800.tif
#   inflating: News/2023269862.tif
#   inflating: News/2023271099.tif
#   inflating: News/2023272505.tif
#   inflating: News/2023798955.tif
#   inflating: News/2023962145.tif
#   inflating: News/2024210851.tif
#   inflating: News/2025028269.tif
#   inflating: News/2025028443.tif
#   inflating: News/2025028501.tif
#   inflating: News/2025028644.tif
#   inflating: News/2025028981-e.tif
#   inflating: News/2025382018.tif
#   inflating: News/2025500007.tif
#   inflating: News/2025635504.tif
#   inflating: News/2025684835.tif
#   inflating: News/2025854306.tif
#   inflating: News/2025880123.tif
#   inflating: News/2026167362.tif
#   inflating: News/2026261439.tif
#   inflating: News/2040565275.tif
#   inflating: News/2044424416.tif
#   inflating: News/2044771242.tif
#   inflating: News/2046117930.tif
#   inflating: News/2046288261.tif
#   inflating: News/2046305055.tif
#   inflating: News/2046323306.tif
#   inflating: News/2046407013_7014.tif
#   inflating: News/2046468258.tif
#   inflating: News/2046546822a.tif
#   inflating: News/2046562645.tif
#   inflating: News/2046585258.tif
#   inflating: News/2046593592.tif
#   inflating: News/2047128093_8094.tif
#   inflating: News/2047564059.tif
#   inflating: News/2047577340.tif
#   inflating: News/2047870236.tif
#   inflating: News/2048270201.tif
#   inflating: News/2051807163.tif
#   inflating: News/2054406337.tif
#   inflating: News/2057077308.tif
#   inflating: News/2063832954.tif
#   inflating: News/2063887409.tif
#   inflating: News/2064814764.tif
#   inflating: News/2065214163.tif
#   inflating: News/2065340065.tif
#   inflating: News/2065594467.tif
#   inflating: News/2070051956.tif
#   inflating: News/2070109534_9535.tif
#   inflating: News/2070397531.tif
#   inflating: News/2070422690.tif
#   inflating: News/2070877098.tif
#   inflating: News/2070897169.tif
#   inflating: News/2070910722.tif
#   inflating: News/2071620452_0454.tif
#   inflating: News/2071692648.tif
#   inflating: News/2071778497.tif
#   inflating: News/2071991216.tif
#   inflating: News/2072097814_7815.tif
#   inflating: News/2072114951.tif
#   inflating: News/2072201232.tif
#   inflating: News/2072411039_1040.tif
#   inflating: News/2072552877.tif
#   inflating: News/2073204566.tif
#   inflating: News/2073415682.tif
#   inflating: News/2073582086.tif
#   inflating: News/2073724138.tif
#   inflating: News/2074121288.tif
#   inflating: News/2074288832.tif
#   inflating: News/2074404560.tif
#   inflating: News/2077070251.tif
#   inflating: News/2077315759.tif
#   inflating: News/2078115033.tif
#   inflating: News/2078115137.tif
#   inflating: News/2080714838.tif
#   inflating: News/2080721150_1153.tif
#   inflating: News/2080726921_6923.tif
#   inflating: News/2080731994.tif
#   inflating: News/2080736802.tif
#   inflating: News/2083513848.tif
#   inflating: News/2083542628.tif
#   inflating: News/2083547815_7816.tif
#   inflating: News/2083774535.tif
#   inflating: News/2083779313.tif
#   inflating: News/2083779691.tif
#   inflating: News/2083780285.tif
#   inflating: News/2083780649.tif
#   inflating: News/2083781257.tif
#   inflating: News/2083784934.tif
#   inflating: News/2083790356.tif
#   inflating: News/2083790656.tif
#   inflating: News/2085568558.tif
#   inflating: News/2085577788.tif
#   inflating: News/2501047925.tif
#   inflating: News/2501204899.tif
#   inflating: News/2501374290.tif
#   inflating: News/2505370845.tif
#   inflating: News/50265293-5293.tif
#   inflating: News/50288669-8669.tif
#   inflating: News/60000259.tif
#   inflating: News/60007601.tif
#   inflating: News/80307630a.tif
#   inflating: News/81760888.tif
#   inflating: News/85644137.tif
#   inflating: News/85650285.tif
#   inflating: News/85865251.tif
#   inflating: News/85879135_85879138.tif
#   inflating: News/87023168_3169.tif
#   inflating: News/89268210.tif
#   inflating: News/89685528.tif
#   inflating: News/91011904a.tif
#   inflating: News/91017445.tif
#   inflating: News/92859262.tif
#   inflating: News/94682942.tif
#   inflating: News/98065867.tif
#   inflating: News/Thumbs.db
#    creating: Note/
#   inflating: Note/0000002770.tif
#   inflating: Note/0000007194.tif
#   inflating: Note/0000016248.tif
#   inflating: Note/0000248859.tif
#   inflating: Note/0000628923.tif
#   inflating: Note/0000642640.tif
#   inflating: Note/00093561.tif
#   inflating: Note/01404111.tif
#   inflating: Note/03016504.tif
#   inflating: Note/03016778.tif
#   inflating: Note/03023805.tif
#   inflating: Note/03563613.tif
#   inflating: Note/03590690.tif
#   inflating: Note/03662678.tif
#   inflating: Note/1000240946.tif
#   inflating: Note/1000261527.tif
#   inflating: Note/1002465404.tif
#   inflating: Note/1003188772.tif
#   inflating: Note/1003286334.tif
#   inflating: Note/1003403894_1003403895.tif
#   inflating: Note/1003722129.tif
#   inflating: Note/1004867378.tif
#   inflating: Note/1005111374.tif
#   inflating: Note/1005127604_1005127605.tif
#   inflating: Note/10058361_10058364.tif
#   inflating: Note/10080510.tif
#   inflating: Note/10093110.tif
#   inflating: Note/10106776.tif
#   inflating: Note/1013025.tif
#   inflating: Note/10221596_10221597.tif
#   inflating: Note/10226038.tif
#   inflating: Note/10384492.tif
#   inflating: Note/11278338.tif
#   inflating: Note/11282478.tif
#   inflating: Note/12882100.tif
#   inflating: Note/12963987.tif
#   inflating: Note/13525267.tif
#   inflating: Note/2001004940.tif
#   inflating: Note/2012517041.tif
#   inflating: Note/2020102257.tif
#   inflating: Note/2020155279.tif
#   inflating: Note/2020247638.tif
#   inflating: Note/2021204574.tif
#   inflating: Note/2021327414_7415.tif
#   inflating: Note/2021333139.tif
#   inflating: Note/2021387400_7401.tif
#   inflating: Note/2021500947.tif
#   inflating: Note/2021528870.tif
#   inflating: Note/2021546486.tif
#   inflating: Note/2021596245.tif
#   inflating: Note/2021614005.tif
#   inflating: Note/2021655168.tif
#   inflating: Note/2022245046.tif
#   inflating: Note/2022916569.tif
#   inflating: Note/2023104578.tif
#   inflating: Note/2023162754.tif
#   inflating: Note/2023163743.tif
#   inflating: Note/2023192377.tif
#   inflating: Note/2023682165.tif
#   inflating: Note/2023785616.tif
#   inflating: Note/2024024233.tif
#   inflating: Note/2024255591.tif
#   inflating: Note/2024267699.tif
#   inflating: Note/2024407772.tif
#   inflating: Note/2025319413.tif
#   inflating: Note/2025325000.tif
#   inflating: Note/2025990305.tif
#   inflating: Note/2026092254.tif
#   inflating: Note/2026205216.tif
#   inflating: Note/2028589254.tif
#   inflating: Note/2028747856.tif
#   inflating: Note/2028826508.tif
#   inflating: Note/2028837643.tif
#   inflating: Note/2028838727_2028838729.tif
#   inflating: Note/2028897672.tif
#   inflating: Note/2028919119.tif
#   inflating: Note/2028980117.tif
#   inflating: Note/2028984183.tif
#   inflating: Note/2029026171.tif
#   inflating: Note/2029042370.tif
#   inflating: Note/2029129273.tif
#   inflating: Note/2029130917.tif
#   inflating: Note/2029146130.tif
#   inflating: Note/2029157248.tif
#   inflating: Note/2029157407.tif
#   inflating: Note/2029160542.tif
#   inflating: Note/2029180090.tif
#   inflating: Note/2029183905.tif
#   inflating: Note/2029204890.tif
#   inflating: Note/2029237593.tif
#   inflating: Note/2029240096.tif
#   inflating: Note/2030020255.tif
#   inflating: Note/2030053173.tif
#   inflating: Note/2030105137.tif
#   inflating: Note/2030195129.tif
#   inflating: Note/2030323138.tif
#   inflating: Note/2030353547.tif
#   inflating: Note/2030545825.tif
#   inflating: Note/2030714615.tif
#   inflating: Note/2031018769.tif
#   inflating: Note/2031367558.tif
#   inflating: Note/2037023038.tif
#   inflating: Note/2041238248.tif
#   inflating: Note/2041767269.tif
#   inflating: Note/2043246073.tif
#   inflating: Note/2043916652.tif
#   inflating: Note/2044183733.tif
#   inflating: Note/2045207751.tif
#   inflating: Note/2045518260.tif
#   inflating: Note/2048150028.tif
#   inflating: Note/2048858141.tif
#   inflating: Note/2050364687.tif
#   inflating: Note/2051800478.tif
#   inflating: Note/2056172318.tif
#   inflating: Note/2059196199.tif
#   inflating: Note/2060540658.tif
#   inflating: Note/2060570691.tif
#   inflating: Note/2062055279.tif
#   inflating: Note/2062432446.tif
#   inflating: Note/2063181986.tif
#   inflating: Note/2063603124.tif
#   inflating: Note/2063710424.tif
#   inflating: Note/2064803045.tif
#   inflating: Note/2064984702.tif
#   inflating: Note/2065023135.tif
#   inflating: Note/2065354661.tif
#   inflating: Note/2067474399.tif
#   inflating: Note/2067623583.tif
#   inflating: Note/2070159121.tif
#   inflating: Note/2070386760.tif
#   inflating: Note/2070393585.tif
#   inflating: Note/2071191029.tif
#   inflating: Note/2071226076.tif
#   inflating: Note/2071722490.tif
#   inflating: Note/2072037683.tif
#   inflating: Note/2072150072.tif
#   inflating: Note/2072237168.tif
#   inflating: Note/2072489111.tif
#   inflating: Note/2072571651.tif
#   inflating: Note/2072654561.tif
#   inflating: Note/2072821881.tif
#   inflating: Note/2073414412.tif
#   inflating: Note/2073425843.tif
#   inflating: Note/2073440248.tif
#   inflating: Note/2074071502a.tif
#   inflating: Note/2074231764.tif
#   inflating: Note/2074551872.tif
#   inflating: Note/2074784438.tif
#   inflating: Note/2075567953.tif
#   inflating: Note/2075949750.tif
#   inflating: Note/2076140545.tif
#   inflating: Note/2077122151.tif
#   inflating: Note/2078067768.tif
#   inflating: Note/2080475741.tif
#   inflating: Note/2080605718_5718a.tif
#   inflating: Note/2082206330.tif
#   inflating: Note/2082693424a.tif
#   inflating: Note/2083927405.tif
#   inflating: Note/2084568423.tif
#   inflating: Note/2085052974.tif
#   inflating: Note/2085234526.tif
#   inflating: Note/2501268920-a.tif
#   inflating: Note/2501639006.tif
#   inflating: Note/2501658355.tif
#   inflating: Note/2505291689.tif
#   inflating: Note/2505334571.tif
#   inflating: Note/2505475748.tif
#   inflating: Note/50028588.tif
#   inflating: Note/50054229.tif
#   inflating: Note/50076168.tif
#   inflating: Note/50488503-8503.tif
#   inflating: Note/60019614.tif
#   inflating: Note/60438302.tif
#   inflating: Note/70057287-7287.tif
#   inflating: Note/71194840.tif
#   inflating: Note/71206341.tif
#   inflating: Note/71221273.tif
#   inflating: Note/71369508.tif
#   inflating: Note/71432730.tif
#   inflating: Note/71460901.tif
#   inflating: Note/71826079.tif
#   inflating: Note/80191212_80191213.tif
#   inflating: Note/80405450.tif
#   inflating: Note/81071627_1629.tif
#   inflating: Note/82857902.tif
#   inflating: Note/84422713.tif
#   inflating: Note/85605325.tif
#   inflating: Note/85651109.tif
#   inflating: Note/87705667.tif
#   inflating: Note/87732150.tif
#   inflating: Note/87927212.tif
#   inflating: Note/88025179.tif
#   inflating: Note/88025410.tif
#   inflating: Note/89091669.tif
#   inflating: Note/89313371.tif
#   inflating: Note/89556237.tif
#   inflating: Note/89774046a.tif
#   inflating: Note/91771720.tif
#   inflating: Note/91783075.tif
#   inflating: Note/91985231-a_91985231.tif
#   inflating: Note/93443778.tif
#   inflating: Note/Thumbs.db
#   inflating: README.txt
#    creating: Report/
#   inflating: Report/0000958516.tif
#   inflating: Report/0000972342.tif
#   inflating: Report/0001166781.tif
#   inflating: Report/0001251167.tif
#   inflating: Report/0001414986.tif
#   inflating: Report/0011987564.tif
#   inflating: Report/10044882_10044909.tif
#   inflating: Report/10103478_10103482.tif
#   inflating: Report/10127889_10127890.tif
#   inflating: Report/10167656.tif
#   inflating: Report/10176813.tif
#   inflating: Report/10232045_10232047.tif
#   inflating: Report/10423065_10423068.tif
#   inflating: Report/11004538.tif
#   inflating: Report/11225239_11225242.tif
#   inflating: Report/11239042_11239045.tif
#   inflating: Report/11298506_11298508.tif
#   inflating: Report/12304582.tif
#   inflating: Report/13091906.tif
#   inflating: Report/24006371_24006372.tif
#   inflating: Report/24010243_24010244.tif
#   inflating: Report/500195739_500195747.tif
#   inflating: Report/500206087_500206093.tif
#   inflating: Report/500272469+-2470.tif
#   inflating: Report/500272849_500272900.tif
#   inflating: Report/50027604_50027607.tif
#   inflating: Report/500515948.tif
#   inflating: Report/500610469_500610475.tif
#   inflating: Report/500649033_500649045.tif
#   inflating: Report/500735305.tif
#   inflating: Report/500877285_500877288.tif
#   inflating: Report/500929359.tif
#   inflating: Report/500985711.tif
#   inflating: Report/501115325+-5327.tif
#   inflating: Report/50118021-8021.tif
#   inflating: Report/501263595_501263601.tif
#   inflating: Report/501326452_501326456.tif
#   inflating: Report/501557447_501557455.tif
#   inflating: Report/501620093_501620119.tif
#   inflating: Report/501656496.tif
#   inflating: Report/50168370-8370.tif
#   inflating: Report/501713950_501713953.tif
#   inflating: Report/501866197+-6204.tif
#   inflating: Report/502071859_502071866.tif
#   inflating: Report/50216661-6661.tif
#   inflating: Report/502339200+-9201.tif
#   inflating: Report/502417535.tif
#   inflating: Report/50244186-4186.tif
#   inflating: Report/50255591-5591.tif
#   inflating: Report/50258031-8032.tif
#   inflating: Report/502790213_502790214.tif
#   inflating: Report/502798863_502798869.tif
#   inflating: Report/502813081.tif
#   inflating: Report/502829678_502829693.tif
#   inflating: Report/502853056+-3063.tif
#   inflating: Report/502980775_502980776.tif
#   inflating: Report/503026367_503026370.tif
#   inflating: Report/503117428_503117430.tif
#   inflating: Report/503165138.tif
#   inflating: Report/503276148_503276153.tif
#   inflating: Report/503428622.tif
#   inflating: Report/503445062_503445063.tif
#   inflating: Report/503478032+-8034.tif
#   inflating: Report/503565734+-5736.tif
#   inflating: Report/503646128+-6129.tif
#   inflating: Report/503958547_503958548.tif
#   inflating: Report/503983498.tif
#   inflating: Report/503999149+-9150.tif
#   inflating: Report/504164620_504164624.tif
#   inflating: Report/504168509_504168510.tif
#   inflating: Report/504221495_504221497.tif
#   inflating: Report/504239537+-9540.tif
#   inflating: Report/504310925.tif
#   inflating: Report/504330344_504330348.tif
#   inflating: Report/504641839_504641846.tif
#   inflating: Report/504783010_504783011.tif
#   inflating: Report/504805602_504805609.tif
#   inflating: Report/504841352.tif
#   inflating: Report/504855605+-5605.tif
#   inflating: Report/504988903+-8904.tif
#   inflating: Report/505016658_505016663.tif
#   inflating: Report/505026775.tif
#   inflating: Report/505127415_505127418.tif
#   inflating: Report/505136134_505136135.tif
#   inflating: Report/505228919.tif
#   inflating: Report/505375034_505375035.tif
#   inflating: Report/505515167_505515171.tif
#   inflating: Report/505683667+-3670.tif
#   inflating: Report/505706456+-6459.tif
#   inflating: Report/505731955+-1955.tif
#   inflating: Report/505798058.tif
#   inflating: Report/505830872+-0875.tif
#   inflating: Report/505835991_505835992.tif
#   inflating: Report/505856025_505856027.tif
#   inflating: Report/505869261_505869265.tif
#   inflating: Report/505938120+-8126.tif
#   inflating: Report/505939350.tif
#   inflating: Report/505968942.tif
#   inflating: Report/505983529_505983530.tif
#   inflating: Report/506023805_506023808.tif
#   inflating: Report/506030259.tif
#   inflating: Report/506040089_506040092.tif
#   inflating: Report/506131656_506131659.tif
#   inflating: Report/506135672_506135674.tif
#   inflating: Report/506153379_506153380.tif
#   inflating: Report/506173089.tif
#   inflating: Report/506176307_506176326.tif
#   inflating: Report/506189288_506189298.tif
#   inflating: Report/506233399+-3399.tif
#   inflating: Report/506238235_506238236.tif
#   inflating: Report/506247497_506247498.tif
#   inflating: Report/506252257_506252258.tif
#   inflating: Report/506296226+-6227.tif
#   inflating: Report/506297104_506297105.tif
#   inflating: Report/506316706_506316722.tif
#   inflating: Report/506348523_506348524.tif
#   inflating: Report/506521794_506521796.tif
#   inflating: Report/506583220_506583221.tif
#   inflating: Report/506631896.tif
#   inflating: Report/506650717+-0718.tif
#   inflating: Report/506767138_506767143.tif
#   inflating: Report/506812605.tif
#   inflating: Report/506875666_506875672.tif
#   inflating: Report/506888300_506888301.tif
#   inflating: Report/506934156_506934157.tif
#   inflating: Report/506992129.tif
#   inflating: Report/507017446+-7455.tif
#   inflating: Report/507061337+-1350.tif
#   inflating: Report/507181418_507181422.tif
#   inflating: Report/507240573_507240574.tif
#   inflating: Report/507320874+-0882.tif
#   inflating: Report/507367473e_507367473f.tif
#   inflating: Report/507523129+-3129.tif
#   inflating: Report/507676370+-6377.tif
#   inflating: Report/507692234+-2243.tif
#   inflating: Report/507745286_507745288.tif
#   inflating: Report/507767713_507767722.tif
#   inflating: Report/507778811_507778812.tif
#   inflating: Report/507783114+-3116.tif
#   inflating: Report/507786984_507786991.tif
#   inflating: Report/507828129_507828145.tif
#   inflating: Report/507838537_507838544.tif
#   inflating: Report/507896104_507896105.tif
#   inflating: Report/507963083_507963090.tif
#   inflating: Report/507975870_507975893.tif
#   inflating: Report/507995082_507995083.tif
#   inflating: Report/508032020_508032021.tif
#   inflating: Report/508270873_508270880.tif
#   inflating: Report/508301539.tif
#   inflating: Report/508536414+-6418.tif
#   inflating: Report/508599869_508599898.tif
#   inflating: Report/508757575_508757594.tif
#   inflating: Report/509227491+-7492.tif
#   inflating: Report/509468162_509468163.tif
#   inflating: Report/509611113_509611115.tif
#   inflating: Report/509808805+-8811.tif
#   inflating: Report/509823077.tif
#   inflating: Report/509847620_509847621.tif
#   inflating: Report/510809052_510809074.tif
#   inflating: Report/510832749.tif
#   inflating: Report/510907182_510907183.tif
#   inflating: Report/511052379_511052380.tif
#   inflating: Report/511085054_511085060.tif
#   inflating: Report/511188446+-8449.tif
#   inflating: Report/511408565+-8565.tif
#   inflating: Report/511421807.tif
#   inflating: Report/511440042_511440053.tif
#   inflating: Report/511988428_511988437.tif
#   inflating: Report/512377084_512377092.tif
#   inflating: Report/512481148_512481149.tif
#   inflating: Report/512687521+-7522.tif
#   inflating: Report/512697956_512697958.tif
#   inflating: Report/512974158_512974160.tif
#   inflating: Report/513103226+-3228.tif
#   inflating: Report/513206103+-6103.tif
#   inflating: Report/513904111+-4118.tif
#   inflating: Report/513966426+-6429.tif
#   inflating: Report/514120277.tif
#   inflating: Report/514217348+-7349.tif
#   inflating: Report/514725860_514725861.tif
#   inflating: Report/514948201+-8201.tif
#   inflating: Report/515242497_515242498.tif
#   inflating: Report/515245506+-5506.tif
#   inflating: Report/515321531+-1533.tif
#   inflating: Report/515395510_515395524.tif
#   inflating: Report/515575465+-5466.tif
#   inflating: Report/515610282+-0283.tif
# ...
#   inflating: Letter/50343351-3351.tif
#   inflating: Letter/503500305_503500306.tif
#   inflating: Letter/503584077.tif
#   inflating: Letter/50361273-1273.tif
#   inflating: Letter/50365515-5515.tif
#   inflating: Letter/503664474_503664475.tif
#   inflating: Letter/503673274_503673275.tif
#   inflating: Letter/50370017-0018.tif
#   inflating: Letter/50373820-3820.tif
#   inflating: Letter/50375676-5676.tif
#   inflating: Letter/503808253.tif
#   inflating: Letter/50382699-2699.tif
#   inflating: Letter/503856809_503856811.tif
#   inflating: Letter/503864315_503864318.tif
#   inflating: Letter/503885478.tif
#   inflating: Letter/504009806.tif
#   inflating: Letter/504013747+-3748.tif
#   inflating: Letter/504033154+-3154.tif
#   inflating: Letter/504034961_504034962.tif
#   inflating: Letter/50404285-4285.tif
#   inflating: Letter/504081353_504081354.tif
#   inflating: Letter/504115148.tif
#   inflating: Letter/50419732-9732.tif
#   inflating: Letter/504210190_504210191.tif
#   inflating: Letter/504213969+-3971.tif
#   inflating: Letter/504236557.tif
#   inflating: Letter/504262724_504262728.tif
#   inflating: Letter/504275731.tif
#   inflating: Letter/504301618+-1618.tif
#   inflating: Letter/504334188_504334189.tif
#   inflating: Letter/504361271_504361273.tif
#   inflating: Letter/50436174-6174.tif
#   inflating: Letter/50437836-7836.tif
#   inflating: Letter/504381073.tif
#   inflating: Letter/504409810_504409811.tif
#   inflating: Letter/504419327_504419329.tif
#   inflating: Letter/504441998_504442001.tif
#   inflating: Letter/50445206-5206.tif
#   inflating: Letter/504463629_504463631.tif
#   inflating: Letter/504473130.tif
#   inflating: Letter/50450839-0839.tif
#   inflating: Letter/50462735-2735.tif
#   inflating: Letter/504660175+-0176.tif
#   inflating: Letter/50467771-7771.tif
#   inflating: Letter/504732186+-2187.tif
#   inflating: Letter/504739223+-9228.tif
#   inflating: Letter/504740366.tif
#   inflating: Letter/504774700_504774702.tif
#   inflating: Letter/504789202_504789204.tif
#   inflating: Letter/504880625_504880626.tif
#   inflating: Letter/504923090_504923091.tif
#   inflating: Letter/50499170-9170.tif
#   inflating: Letter/50500997-0997.tif
#   inflating: Letter/505031983_505031985.tif
#   inflating: Letter/505051340_505051343.tif
#   inflating: Letter/505081291+-1291.tif
#   inflating: Letter/50519386-9386.tif
#   inflating: Letter/505239182+-9182.tif
#   inflating: Letter/505278562.tif
#   inflating: Letter/505311822.tif
#   inflating: Letter/505316432+-6432.tif
#   inflating: Letter/50534026-4026.tif
#   inflating: Letter/505354097_505354098.tif
#   inflating: Letter/505449159_505449162.tif
#   inflating: Letter/505454926h_505454926i.tif
#   inflating: Letter/505486448_505486456.tif
#   inflating: Letter/505492811_505492812.tif
#   inflating: Letter/505499053_505499060.tif
#   inflating: Letter/50551250-1251.tif
#   inflating: Letter/50554660-4660.tif
#   inflating: Letter/505575420_505575421.tif
#   inflating: Letter/505601044_505601051.tif
#   inflating: Letter/505622748_505622751.tif
#   inflating: Letter/505632516_505632517.tif
#   inflating: Letter/505649215_505649221.tif
#   inflating: Letter/505688958+-8963.tif
#   inflating: Letter/50572661-2661.tif
#   inflating: Letter/505802830.tif
#   inflating: Letter/505815955_505815972.tif
#   inflating: Letter/505828969.tif
#   inflating: Letter/50585499-5499.tif
#   inflating: Letter/505876423.tif
#   inflating: Letter/505889574+-9575.tif
#   inflating: Letter/505954765_505954768.tif
#   inflating: Letter/505966068_505966069.tif
#   inflating: Letter/505988421_505988422.tif
#   inflating: Letter/505993188_505993190.tif
#   inflating: Letter/506010719.tif
#   inflating: Letter/506014187.tif
#   inflating: Letter/506028258.tif
#   inflating: Letter/506050726_506050727.tif
#   inflating: Letter/506063133_506063136.tif
#   inflating: Letter/50606546-6546.tif
#   inflating: Letter/506079937.tif
#   inflating: Letter/506080143+-0149.tif
#   inflating: Letter/506121204.tif
#   inflating: Letter/50615547-5548.tif
#   inflating: Letter/506163412_506163415.tif
#   inflating: Letter/506193791+-3792.tif
#   inflating: Letter/506226060_506226061.tif
#   inflating: Letter/506263567_506263572.tif
#   inflating: Letter/506279786_506279793.tif
#   inflating: Letter/506354567_506354570.tif
#   inflating: Letter/506366336.tif
#   inflating: Letter/506434158_506434163.tif
#   inflating: Letter/506453583+-3584.tif
#   inflating: Letter/506464139.tif
#   inflating: Letter/506538874_506538875.tif
#   inflating: Letter/50661869-1869.tif
#   inflating: Letter/506623600_506623602.tif
#   inflating: Letter/506658322+-8323.tif
#   inflating: Letter/506718643_506718644.tif
#   inflating: Letter/50673098-3098.tif
#   inflating: Letter/506873664.tif
#   inflating: Letter/506881197_506881198.tif
#   inflating: Letter/506913284.tif
#   inflating: Letter/507007456.tif
#   inflating: Letter/50704129-4129.tif
#   inflating: Letter/507051676.tif
#   inflating: Letter/507056895.tif
#   inflating: Letter/507063202_507063206.tif
#   inflating: Letter/507084664_507084673.tif
#   inflating: Letter/50708841-8841.tif
#   inflating: Letter/507124268+-4270.tif
#   inflating: Letter/507135769_507135770.tif
#   inflating: Letter/507198806+-8809.tif
#   inflating: Letter/507360836+-0837.tif
#   inflating: Letter/50737588-7588.tif
#   inflating: Letter/507386652+-6652.tif
#   inflating: Letter/507387897_507387901.tif
#   inflating: Letter/50739956-9956.tif
#   inflating: Letter/507404690_507404692.tif
#   inflating: Letter/507407645.tif
#   inflating: Letter/507419113.tif
#   inflating: Letter/507608307_507608308.tif
#   inflating: Letter/507622558+-2558.tif
#   inflating: Letter/507724696.tif
#   inflating: Letter/507966367+-6367.tif
#   inflating: Letter/507995262.tif
#   inflating: Letter/508046753.tif
#   inflating: Letter/508047850+-7850.tif
#   inflating: Letter/508063247.tif
#   inflating: Letter/508077193.tif
#   inflating: Letter/508131603_508131608.tif
#   inflating: Letter/508146503+-6507.tif
#   inflating: Letter/508161842.tif
#   inflating: Letter/508217217_508217221.tif
#   inflating: Letter/508228211_508228220.tif
#   inflating: Letter/508232590.tif
#   inflating: Letter/508407516_508407518.tif
#   inflating: Letter/508500970.tif
#   inflating: Letter/508511388.tif
#   inflating: Letter/508542996_508542997.tif
#   inflating: Letter/508847380.tif
#   inflating: Letter/508865270+-5274.tif
#   inflating: Letter/508904759_508904761.tif
#   inflating: Letter/508923688.tif
#   inflating: Letter/508951029+-1033.tif
#   inflating: Letter/508976810_508976811.tif
#   inflating: Letter/509104355+-4360.tif
#   inflating: Letter/509153956.tif
#   inflating: Letter/509157078+-7082.tif
#   inflating: Letter/509158416+-8419.tif
#   inflating: Letter/509244518.tif
#   inflating: Letter/509282179_509282180.tif
#   inflating: Letter/509452348+-2348.tif
#   inflating: Letter/509559488.tif
#   inflating: Letter/509666724_509666725.tif
#   inflating: Letter/509696284+-6284.tif
#   inflating: Letter/509793995_509793996.tif
#   inflating: Letter/509887153.tif
#   inflating: Letter/510017822.tif
#   inflating: Letter/510072684_510072685.tif
#   inflating: Letter/510112796+-2797.tif
#   inflating: Letter/510221250_510221253.tif
#   inflating: Letter/510336889.tif
#   inflating: Letter/510623450.tif
#   inflating: Letter/510700728.tif
#   inflating: Letter/511011264_511011268.tif
#   inflating: Letter/511023955.tif
#   inflating: Letter/511111743+-1743.tif
#   inflating: Letter/511241254.tif
#   inflating: Letter/511397696.tif
#   inflating: Letter/511406901+-6901.tif
#   inflating: Letter/511994948+-4948.tif
#   inflating: Letter/512011799+-1799.tif
#   inflating: Letter/512015167+-5168.tif
#   inflating: Letter/512077487+-7488.tif
#   inflating: Letter/512088115.tif
#   inflating: Letter/512195767_512195769.tif
#   inflating: Letter/512245743_512245744.tif
#   inflating: Letter/512289677+-9679.tif
#   inflating: Letter/512291680.tif
#   inflating: Letter/512315558.tif
#   inflating: Letter/512330245_512330247.tif
#   inflating: Letter/512452246.tif
#   inflating: Letter/512540914_512540915.tif
#   inflating: Letter/512609438_512609439.tif
#   inflating: Letter/512753125.tif
#   inflating: Letter/512760291.tif
#   inflating: Letter/512948144.tif
#   inflating: Letter/512997470.tif
#   inflating: Letter/513130256.tif
#   inflating: Letter/513160165.tif
#   inflating: Letter/513206214_513206217.tif
#   inflating: Letter/513232721_513232722.tif
#   inflating: Letter/513262199.tif
#   inflating: Letter/513292964_513292967.tif
#   inflating: Letter/513415616.tif
#   inflating: Letter/513421755+-1755.tif
#   inflating: Letter/513901494_513901500.tif
#   inflating: Letter/513988895_513988898.tif
#   inflating: Letter/514116293+-6293.tif
#   inflating: Letter/514421927+-1927.tif
#   inflating: Letter/514839018+-9019.tif
#   inflating: Letter/514963180+-3180.tif
#   inflating: Letter/515034743+-4743.tif
#   inflating: Letter/515121473+-1475.tif
#   inflating: Letter/515360458.tif
#   inflating: Letter/515682605.tif
#   inflating: Letter/515766856+-6858.tif
#   inflating: Letter/515792806+-2806.tif
#   inflating: Letter/515809872_515809874.tif
#   inflating: Letter/515842254.tif
#   inflating: Letter/516015914+-5914.tif
#   inflating: Letter/516028154+-8154.tif
#   inflating: Letter/516394905_516394908.tif
#   inflating: Letter/516465142_516465144.tif
#   inflating: Letter/516628601+-8601.tif
#   inflating: Letter/516695861+-5861.tif
#   inflating: Letter/516737076+-7077.tif
#   inflating: Letter/516889156+-9156.tif
#   inflating: Letter/517098140_517098145.tif
#   inflating: Letter/517444539+-4540.tif
#   inflating: Letter/517572982+-2983.tif
#   inflating: Letter/517591807+-1809.tif
#   inflating: Letter/517600807+-0807.tif
#   inflating: Letter/517783754+-3754.tif
#   inflating: Letter/518036678+-6680.tif
#   inflating: Letter/518057258_518057259.tif
#   inflating: Letter/518074129_518074130.tif
#   inflating: Letter/518193540.tif
#   inflating: Letter/518203735.tif
#   inflating: Letter/518241192+-1192.tif
#   inflating: Letter/518288917+-8918.tif
#   inflating: Letter/518424618+-4618.tif
#   inflating: Letter/518445181+-5181.tif
#   inflating: Letter/518451410.tif
#   inflating: Letter/518476232+-6232.tif
#   inflating: Letter/518500076+-0077.tif
#   inflating: Letter/518519963+-9966.tif
#   inflating: Letter/518532897+-2897.tif
#   inflating: Letter/518533499+-3499.tif
#   inflating: Letter/518617506+-7506.tif
#   inflating: Letter/518630372+-0375.tif
#   inflating: Letter/518641553_518641555.tif
#   inflating: Letter/518654143_518654144.tif
#   inflating: Letter/518695806+-5806.tif
#   inflating: Letter/518768911+-8911.tif
#   inflating: Letter/519585825+-5829.tif
#   inflating: Letter/519878148+-8149.tif
#   inflating: Letter/520070902+-0902.tif
#   inflating: Letter/520140971+-0972.tif
#   inflating: Letter/520222764+-2764.tif
#   inflating: Letter/520527284+-7285.tif
#   inflating: Letter/520546820+-6823.tif
#   inflating: Letter/520693484+-3486.tif
#   inflating: Letter/520709850+-9850.tif
#   inflating: Letter/520815209+-5209.tif
#   inflating: Letter/520865580+-5583.tif
#   inflating: Letter/521115354+-5356.tif
#   inflating: Letter/521431153+-1153.tif
#   inflating: Letter/521435346+-5346.tif
#   inflating: Letter/521479934+-9934.tif
#   inflating: Letter/522028451+-8451.tif
#   inflating: Letter/522046763+-6770.tif
#   inflating: Letter/522305211+-5211.tif
#   inflating: Letter/522399399+-9399.tif
#   inflating: Letter/522612220+-2222.tif
#   inflating: Letter/523170476+-0476.tif
#   inflating: Letter/523186064+-6066.tif
#   inflating: Letter/524237789+-7789.tif
#   inflating: Letter/524413197+-3197.tif
#   inflating: Letter/524569241+-9242.tif
#   inflating: Letter/524945610+-5611.tif
#   inflating: Letter/525022027+-2027.tif
#   inflating: Letter/586670.tif
#   inflating: Letter/60006786.tif
#   inflating: Letter/60006851.tif
#   inflating: Letter/60007551.tif
#   inflating: Letter/60008309.tif
#   inflating: Letter/60009061.tif
#   inflating: Letter/60009710.tif
#   inflating: Letter/60010441.tif
#   inflating: Letter/60012400.tif
#   inflating: Letter/60012482_60012483.tif
#   inflating: Letter/60013409.tif
#   inflating: Letter/60015620.tif
#   inflating: Letter/60015669.tif
#   inflating: Letter/60016059.tif
#   inflating: Letter/60017528.tif
#   inflating: Letter/60018214.tif
#   inflating: Letter/60018901.tif
#   inflating: Letter/60020317.tif
#   inflating: Letter/60021014.tif
#   inflating: Letter/60021705.tif
#   inflating: Letter/60022426.tif
#   inflating: Letter/60023115.tif
#   inflating: Letter/60023807.tif
#   inflating: Letter/60024487.tif
#   inflating: Letter/600552.tif
#   inflating: Letter/628017.tif
#   inflating: Letter/653346.tif
#   inflating: Letter/656421.tif
#   inflating: Letter/674889.tif
#   inflating: Letter/679995.tif
#   inflating: Letter/689417.tif
#   inflating: Letter/70013040-3040.tif
#   inflating: Letter/70015348-5349.tif
#   inflating: Letter/70118949-8950.tif
#   inflating: Letter/71119336.tif
#   inflating: Letter/71153406.tif
#   inflating: Letter/71210664.tif
#   inflating: Letter/713402.tif
#   inflating: Letter/727296.tif
#   inflating: Letter/870648.tif
#   inflating: Letter/94000570.tif
#   inflating: Letter/94002714.tif
#   inflating: Letter/CTRCONTRACTS009745-9.tif
#   inflating: Letter/CTRCONTRACTS015206-5.tif
#   inflating: Letter/CTRCONTRACTS026722-6.tif
#   inflating: Letter/CTRSP-FILES003409-34.tif
#   inflating: Letter/CTRSP-FILES014766-47.tif
#   inflating: Letter/CTRSP-FILES026390-63.tif
#   inflating: Letter/CTRSP-FILES026628-66.tif
#   inflating: Letter/CTRSP-FILES027316-73.tif
#   inflating: Letter/dun00318.93_dun00318.93.tif
#   inflating: Letter/tcal0173460.tif
#   inflating: Letter/tcal0447628.tif
#   inflating: Letter/Thumbs.db
#   inflating: Letter/ti03840086_0087.tif
#   inflating: Letter/ti04111260_1261.tif
#   inflating: Letter/ti06390634.tif
#   inflating: Letter/ti11211794_1795.tif
#   inflating: Letter/ti11491978.tif
#   inflating: Letter/ti14861233.tif
#   inflating: Letter/ti15732103.tif
#   inflating: Letter/ti16310640.tif
#   inflating: Letter/ti16321601.tif
#   inflating: Letter/ti16400391.tif
#   inflating: Letter/ti16570359.tif
#   inflating: Letter/ti16601162.tif
#   inflating: Letter/ti16671221_1223.tif
#   inflating: Letter/ti16860527_0528.tif
#   inflating: Letter/ti17120611_0612.tif
#   inflating: Letter/ti31110620.tif
#   inflating: Letter/timo0003651_3652.tif
#   inflating: Letter/titl0003493_3506.tif
#   inflating: Letter/titx0100.29.tif
#   inflating: Letter/titx0224.70.tif
#   inflating: Letter/titx0320.20.tif
#   inflating: Letter/titx0417.71.tif
#   inflating: Letter/tnjb0007854.tif
#   inflating: Letter/tnwl0002422.tif
#   inflating: Letter/tnwl0019853.tif
#   inflating: Letter/tnwl0028046.tif
#   inflating: Letter/tnwl0029158.tif
#   inflating: Letter/tnwl0035736.tif
#   inflating: Letter/tob02614.42.tif
#   inflating: Letter/tob02711.67.tif
#   inflating: Letter/tob03000.60.tif
#   inflating: Letter/tob07201.29.tif
#   inflating: Letter/tob07507.45.tif
#   inflating: Letter/tob08602.49.tif
#   inflating: Letter/tob10623.04.tif
#   inflating: Letter/tob12322.82.tif
#   inflating: Letter/tob13613.26.tif
#   inflating: Letter/tob14232.72_tob14232.73.tif
#   inflating: Letter/tob16529.92.tif
#   inflating: Letter/tob17621.69.tif
#   inflating: Letter/ton00908.15.tif
#   inflating: Letter/ton01402.63_ton01402.65.tif
#   inflating: Letter/ton02314.98.tif
#   inflating: Letter/ton03017.04_ton03017.05.tif
#   inflating: Letter/ton04021.20.tif
#   inflating: Letter/ton04200.95.tif

# %%
ls
# Out:
# ADVE/   Form/    Memo/  Note/       Report/  sample_data/  Tobacco3482_1.zip
# Email/  Letter/  News/  README.txt  Resume/  Scientific/   Tobacco3482_2.zip

# %% [markdown]
# **Exercise 1:**
#
# We need to convert the dataset from the image format (.tiff) into a format that can be imported to our python script so that we can feed it to a neural network. In addition, we also have to create a vector assigning an integer to each class, which is going to act as labels. For example, "0" for advertisement, "1" for email, "2" for form, etc. For this exercise, create a script to convert the input images from .tiff into the hdf5 format. For convenience, save only 100 samples for each of the 10 classes. You should also specify a resolution of 227 pixels in both x and y directions. That means that the final dimension of your dataset will be 1000 (samplex) x 227 x 227 (image resolution).

# %%
from skimage.transform import resize
import os
import numpy as np
import matplotlib.pyplot as plt
import glob
import h5py

ls_labels = [ 'ADVE', 'Email' , 'Form' , 'Letter' , 'Memo' , 'News' , 'Note' , 'Report', 'Resume' ,'Scientific'  ]

size = 227
maxS = 100

train_x = np.zeros((10*maxS,size,size))
train_y = np.ones((10*maxS,1))

count = 0
for i in range(len(ls_labels)):
  directory_in_str='./'+ls_labels[i]
  print(directory_in_str)
  directory = os.fsencode(directory_in_str)

  for file in os.listdir(directory):
      filename = os.fsdecode(file)
      if filename.endswith(".tif"):
        if count < maxS:
           I = plt.imread(directory_in_str+'/'+filename)
           img = I[:,:,0]
           img = resize(img, (size, size), anti_aliasing=True)
           train_x[maxS*i+count,:,:] = img
           train_y[maxS*i+count,:] = int((maxS*i+count)/maxS)
           count = count + 1
        else:
           count = 0
           break

h5_tr_x = h5py.File("train_x.h5", 'w')
h5_tr_x.create_dataset("train_x", data=np.array(train_x))
print(h5_tr_x)
h5_tr_x.close()

h5_tr_y = h5py.File("train_y.h5", 'w')
h5_tr_y.create_dataset("train_y", data=np.array(train_y))
print(h5_tr_y)
h5_tr_y.close()
# Out:
# ./ADVE
# ./Email
# ./Form
# ./Letter
# ./Memo
# ./News
# ./Note
# ./Report
# ./Resume
# ./Scientific
# <HDF5 file "train_x.h5" (mode r+)>
# <HDF5 file "train_y.h5" (mode r+)>

# %% [markdown]
# We also need to download some supplementary files, including convnets and pre-trained imagenet weights.
#
# The credit for this goes to heuritech: https://github.com/heuritech/convnets-keras

# %%
# !git clone https://git.opendfki.de/mateus.dias_ribeiro/supplementary.git
# Out:
# Cloning into 'supplementary'...
# remote: Enumerating objects: 69, done.
# remote: Total 69 (delta 0), reused 0 (delta 0), pack-reused 69
# Unpacking objects: 100% (69/69), done.
# Checking out files: 100% (25/25), done.

# %% [markdown]
# Now, let's import necessary dependencies (ignore it if you get warnings about outdated Tensorflow version).

# %%
import numpy as np
import keras
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
import pickle
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from sklearn.metrics import confusion_matrix
import itertools
from supplementary.convnetskeras.customlayers import splittensor
from keras.layers import concatenate
from keras import backend as K

# %% [markdown]
# Load the dataset to the environment and make necessary adaptations. For example, the figures of the dataset are in black and white (1 gray-scale channel), but the AlexNet architecture expects an input with 3 channels (RGB). Therefore we need to stack copies of each sample of the dataset three by three in order to follow these requirements.
#
# Furthermore, the dataset dimensions follow the rule (Ns, Nc, Nx, Ny), in which:
#
# Ns: Number of samples = 1000
#
# Nc: Number of channels = 3 (after adaptation)
#
# Nx: Number of horizontal points = 227
#
# Ny: Number of vertical points = 227
#
# Therefore, we have to tell the Keras environment that the dimension "number of channels" comes first in regard to the 2D x-y pixels.
#
# In a last step, we shuffle the dataset. Shuffling the dataset can improve the training performance.

# %%
# Convert hdf5 to array
with h5py.File('./train_x.h5', 'r') as f:
    train_x = f['train_x'][()]

with h5py.File('./train_y.h5', 'r') as f:
    train_y = f['train_y'][()]

# %%
train_x.shape, train_y.shape
# Out:
# ((1000, 227, 227), (1000, 1))

# %%
# Tell Keras to use first dimension of the tensor for the number of channels
K.set_image_data_format('channels_first')

# Loading figures in the dataset
# AlexNet assumes input with 3 channels (RGB). Since the figures of the Tobbaco
# dataset are grey-scale (1 black/white channel), we stack three copies of each
# figure for each sample of our input data
data_x = np.zeros((1000,3,227,227))
data_x[:,0,:,:] = train_x[:,:,:]
data_x[:,1,:,:] = train_x[:,:,:]
data_x[:,2,:,:] = train_x[:,:,:]

# Loading labels of the dataset
# 0 Ad
# 1 Email
# 2 Form
# 3 Letter
# 4 Memo
# 5 News
# 6 Note
# 7 Report
# 8 Resume
# 9 Scientific
data_y = train_y[:,:]

# Shuffling dataset
indices = np.arange(1000)
np.random.shuffle(indices)
data_x = data_x[indices,:,:,:]
data_y = data_y[indices,:]

# %% [markdown]
# First, let's plot a random sample of each class:

# %%
lsy = []
for i in range(10):
    ind = np.where( data_y[:] == i)
    lsy.append(ind[0])

plt.figure()
fig = plt.gcf()
fig.set_size_inches(30, 10)
for i in range(2):
    for j in range(1,6):
        plt.subplot(2, 5, 5*i+j)
        plt.title(str(ls_labels[5*i+j-1]), fontsize=18) 
        imshow(data_x[lsy[5*i+j-1][np.random.randint(100)],0])
plt.show()

# %% [markdown]
# Now let's create some data train/test splits:
#
# 1) 200 (train) / 800 (test) - 20 samples per class for training
#
# 2) 400 (train) / 600 (test) - 40 samples per class for training
#
# 3) 600 (train) / 400 (test) - 60 samples per class for training
#
# 4) 800 (train) / 200 (test) - 80 samples per class for training

# %%
img_rows, img_cols = 227, 227
num_classes = 10

lim = 800    #200  400  600 800
x_train = data_x[0:lim,:,:]
x_test = data_x[lim:1000,:,:]

y_train = data_y[0:lim,:]
y_test = data_y[lim:1000,:]

tr_sz = lim
ts_sz = 1000 - lim

x_train = x_train.reshape(tr_sz,3,img_rows,img_cols)
x_test =  x_test.reshape(ts_sz,3,img_rows,img_cols)

# convert class vectors to binary class matrices(one hot vector)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# **AlexNet architecture**
#
# At this point, we are ready to define our Deep CNN architecture (AlexNet) using Keras. There is one important observation about the code in the next cell. The convolutional layers with highest number of parameters have been split in 2. We need to do this because this was also done in the architecture used to pre-train the weights on the ImageNet dataset. The main motivation for such a setup was that two GPUs were used for training, and splitting the parameters equally between them can improve parallelization efficiency. Even though this is likely not our case (unless you have two GPUs for the training), we need to do the same because the weights of our architecture need to be consistent with the pre-trained weights, so that transfer learning can be employed.

# %%
def DeepDoc(weights_path=None):

    inputs = Input(shape=(3, 227, 227))

    conv_1 = Conv2D(96, (11, 11), strides=(4, 4), activation='relu', name='conv_1')(inputs)
    max_1 = MaxPooling2D((3, 3), strides=(2, 2))(conv_1)
    pad_1 = ZeroPadding2D((2, 2))(max_1)

    conv_2 = concatenate([
                      Conv2D(128, (5, 5), activation='relu', name='conv_2_' + str(i + 1))(
                          splittensor(ratio_split=2, id_split=i)(pad_1)
                      ) for i in range(2)], axis=1, name='conv_2')
    max_2 = MaxPooling2D((3, 3), strides=(2, 2))(conv_2)
    pad_2 = ZeroPadding2D((1, 1))(max_2)
    
    conv_3 = Conv2D(384, (3, 3), activation='relu', name='conv_3')(pad_2)
    pad_3 = ZeroPadding2D((1, 1))(conv_3)
    
    conv_4 = concatenate([
                       Conv2D(192, (3, 3), activation='relu', name='conv_4_' + str(i + 1))(
                           splittensor(ratio_split=2, id_split=i)(pad_3)
                       ) for i in range(2)], axis=1, name='conv_4')
    pad_4 = ZeroPadding2D((1, 1))(conv_4)
    
    conv_5 = concatenate([
                       Conv2D(128, (3, 3), activation='relu', name='conv_5_' + str(i + 1))(
                           splittensor(ratio_split=2, id_split=i)(pad_4)
                       ) for i in range(2)], axis=1, name='conv_5')
    max_5 = MaxPooling2D((3, 3), strides=(2, 2), name='convpool_5')(conv_5)

    fc_0 = Flatten(name='flatten')(max_5)
    fc_0 = Dropout(0.2)(fc_0)
    fc_1 = Dense(4096, activation='relu', name='dense_1')(fc_0)
    fc_1 = Dropout(0.2)(fc_1)
    fc_2 = Dense(4096, activation='relu', name='dense_2')(fc_1)
    fc_2 = Dropout(0.2)(fc_2)
    out = Dense(10, name='dense_out')(fc_2)
    prediction = Activation('softmax', name='softmax_out')(out)

    model = Model(inputs, prediction)

    # If pre-trained weights are provided, we add them to the network at this step
    if weights_path:
        model.load_weights(weights_path, by_name=True)

    return model

# %% [markdown]
# **Exercise 2**
#
# Now that our Keras model has been loaded, there are a few interesting questions we can make. For example, use the formulas presented in the class to answer how many ***parameters*** there are in the following parts of the model (tip: don't forget the bias):
#
# a) conv_1
#
# b) conv_3
#
# c) max_2
#
# d) max_5
#
# e) fc_1
#
# f) fc_2
#
# **Answer:**
#
# Convolutional layers
#
# (( f[l] x f[l] ) x nc[l-1] + 1 (bias) ) x nc[l]
#
# a) ((11x11)x3+1)x96 = 34944
#
# b) ((3x3)x256+1)x384 = 885120
#
# c) 0 - pooling layers have no parameters. No learning involved!
#
# d) 0 - pooling layers have no parameters. No learning involved!
#
# Fully-connected layers
#
# activation[l] x activation[l-1] + 1 x activation[l] (bias)
#
# e) 4096x9216 + 4096 = 37752832
#
# e) 4096x4096 + 4096 = 16781312
#
#
# **Exercise 3**
#
# In addition, calculate how many ***activations*** we will have in each of the parts of exercise 3:
#
# a) conv_1
#
# b) conv_3
#
# c) max_2
#
# d) max_5
#
# e) fc_1
#
# f) fc_2
#
# **Answer:**
#
# Convolutional layers
#
# Nx x Ny x Nc
#
# a) 55 x 55 x 96 = 290400
#
# b) 13 x 13 x 384 = 64896
#
# c) 13 x 13 x 256 = 43264
#
# d) 6 x 6 x 256 = 9216
#
# Fully-connected layers
#
# Number of nodes
#
# e) 4096
#
# f) 4096
#
# **Exercise 4**
#
# Please explain what the following parts of the code are and what purpose do they serve?
#
# a) *activation='relu'*
#
# b) *Dropout(0.5)*
#
# c) *Flatten(name='flatten')*
#
# d) *MaxPooling2D*
#
# e) *Activation('softmax', name='softmax_out')*
#
# **Answer:**
#
# a) rELU (rectified linear unit) activation function: a(x) = max(0,x). It forces sparsity by ignoring negative activations.
#
# b) Dropout regularization. It assigns a certain probability of a given node to exist. If probability is lower than inputted value, the node is dropped out. It simplifies the model during training to avoid over-fitting.
#
# c) Flattening of the convolutional layer. It unrolls the convolutional volume into an 1D vector for the fully-connected layer part of the network.
#
# d) Max pooling. It forces reduction of the resolution by getting the max value of a sub-sample of given size (normally 2x2) along the entire matrix.
#
# e) Softmax activation function. It normalizes the values of each node in the output layer so that it represents a certain probability for each class (the sum of all values must be equal to 1). The class with highest probability will be the one selected by the network.
#
# **Train model**
#
# We can now finally go ahead and train the model. A few important remarks:
#
# In the first line we call the architecture we defined above ("DeepDoc") and assign it to an object called "deepDoc". During this call, we input the path of the pre-trained weights in order to leverage from the parameters learned on the ImageNet dataset. This action is known as "transfer learning". If we wish to train the model without transfer learning, we can simply call the model and leave the input empty, such as in:
#
# *deepDoc = DeepDoc()*
#
# We also need to define the hyper-parameters of the model. We are using a *batch size* of 10, which means that we perform forward and back propagation in groups or mini batches of 10. The choice of mini batch size needs to be carefully chosen, especially for big datasets. On one hand, we normally don't want to use huge batches, such as the entire dataset, because of memory constraints (especially running on GPUs) and/or because this may give the optimizer a hard time. On the other hand, we also don't want to use very small batches, such as 1 because it would not be very efficient. The optimizer would have to work too many repeated times at every Epoch.
#
# For optimization of the parameters, we use the Stochastic Gradient Descent algorithm, together with weight decay and momentum. A straight forward explanation was given in https://stats.stackexchange.com/questions/70101/neural-networks-weight-change-momentum-and-weight-decay, which we reproduce here. One step of gradient descent has the following form:
#
# \begin{equation}
# \Delta\omega_i(t+1) = - \eta\frac{\partial E}{\partial w_i} + \alpha \Delta \omega_i(t) - \lambda\eta\omega_i
# \end{equation}
#
# in which $\eta$ is the learning rate, $E(w)$ is the cost function, and $w$ the tensor of weights. Momentum $\alpha$ is used to diminish the fluctuations in weight changes over consecutive iterations, and weight decay $\lambda$ penalizes the weight changes.
#
# One way to think about it is that weight decay changes the function that's being optimized, while momentum changes the path you take to the optimum. Weight decay, by shrinking your coefficients toward zero, ensures that you find a local optimum with small-magnitude parameters. This is usually crucial for avoiding overfitting (although other kinds of constraints on the weights can work too). As a side benefit, it can also make the model easier to optimize, by making the objective function more convex.
#
# Once you have an objective function, you have to decide how to move around on it. Steepest descent on the gradient is the simplest approach, but fluctuations can be a big problem. Adding momentum helps solve that problem. If you're working with batch updates (which is usually a bad idea with neural networks) Newton-type steps are another option. The new "hot" approaches are based on Nesterov's accelerated gradient and so-called "Hessian-Free" optimization.
#
# Finally, we run the training loop for a total of 50 iterations (epochs), and we use the categorical cross-entropy loss function. We input our train dataset (x_train and y_train), as well as our testset (x_test and y_test) to the fit function of our deepDoc object from our DeepDoc model class. We use the metric "accuracy" on the testset to evaluate how well our model is performing.
#
# **Exercise 5**
#
# Train the model by executing the next cell using all the four splits you created before. Report the accuracy on the testset for each of these runs.

# %%
deepDoc = DeepDoc('./supplementary/trainedWeights/alexnet_weights.h5')
#deepDoc = DeepDoc()

batch_size = 10
epochs = 50  #100  50  30

deepDoc.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.SGD(lr=0.0001, decay=0.0005, momentum=0.9, nesterov=True),
              metrics=['accuracy'])

deepDoc.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = deepDoc.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 80/80 [==============================] - 2s 23ms/step - loss: 2.2692 - accuracy: 0.1800 - val_loss: 2.2189 - val_accuracy: 0.2450
# Epoch 2/50
# 80/80 [==============================] - 1s 19ms/step - loss: 2.1267 - accuracy: 0.3262 - val_loss: 2.0723 - val_accuracy: 0.2750
# Epoch 3/50
# 80/80 [==============================] - 1s 18ms/step - loss: 1.9364 - accuracy: 0.3963 - val_loss: 1.8969 - val_accuracy: 0.3250
# Epoch 4/50
# 80/80 [==============================] - 1s 18ms/step - loss: 1.7203 - accuracy: 0.4688 - val_loss: 1.7254 - val_accuracy: 0.3750
# Epoch 5/50
# 80/80 [==============================] - 1s 18ms/step - loss: 1.5397 - accuracy: 0.4850 - val_loss: 1.5683 - val_accuracy: 0.4650
# Epoch 6/50
# 80/80 [==============================] - 1s 18ms/step - loss: 1.3790 - accuracy: 0.5650 - val_loss: 1.5081 - val_accuracy: 0.4550
# Epoch 7/50
# 80/80 [==============================] - 1s 18ms/step - loss: 1.2790 - accuracy: 0.5825 - val_loss: 1.4024 - val_accuracy: 0.5100
# Epoch 8/50
# 80/80 [==============================] - 1s 18ms/step - loss: 1.1822 - accuracy: 0.6050 - val_loss: 1.3499 - val_accuracy: 0.5400
# Epoch 9/50
# 80/80 [==============================] - 1s 18ms/step - loss: 1.0944 - accuracy: 0.6400 - val_loss: 1.3409 - val_accuracy: 0.5250
# Epoch 10/50
# 80/80 [==============================] - 1s 18ms/step - loss: 1.0282 - accuracy: 0.6488 - val_loss: 1.2887 - val_accuracy: 0.5600
# Epoch 11/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.9690 - accuracy: 0.6800 - val_loss: 1.1934 - val_accuracy: 0.6150
# Epoch 12/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.8899 - accuracy: 0.7237 - val_loss: 1.1496 - val_accuracy: 0.6100
# Epoch 13/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.8349 - accuracy: 0.7262 - val_loss: 1.1339 - val_accuracy: 0.6400
# Epoch 14/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.7666 - accuracy: 0.7650 - val_loss: 1.0994 - val_accuracy: 0.6550
# Epoch 15/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.7298 - accuracy: 0.7800 - val_loss: 1.1125 - val_accuracy: 0.6650
# Epoch 16/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.6959 - accuracy: 0.7638 - val_loss: 1.0448 - val_accuracy: 0.6600
# Epoch 17/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.6568 - accuracy: 0.7937 - val_loss: 1.0305 - val_accuracy: 0.6800
# Epoch 18/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.6179 - accuracy: 0.8050 - val_loss: 1.0570 - val_accuracy: 0.6550
# Epoch 19/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.5904 - accuracy: 0.8112 - val_loss: 1.0037 - val_accuracy: 0.6900
# Epoch 20/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.5635 - accuracy: 0.8263 - val_loss: 0.9935 - val_accuracy: 0.7050
# Epoch 21/50
# 80/80 [==============================] - 1s 19ms/step - loss: 0.5335 - accuracy: 0.8213 - val_loss: 1.0102 - val_accuracy: 0.7000
# Epoch 22/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.5038 - accuracy: 0.8438 - val_loss: 0.9615 - val_accuracy: 0.7300
# Epoch 23/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.4722 - accuracy: 0.8625 - val_loss: 1.0018 - val_accuracy: 0.6750
# Epoch 24/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.4542 - accuracy: 0.8525 - val_loss: 0.9813 - val_accuracy: 0.7300
# Epoch 25/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.4482 - accuracy: 0.8600 - val_loss: 0.9150 - val_accuracy: 0.7300
# Epoch 26/50
# 80/80 [==============================] - 1s 19ms/step - loss: 0.4202 - accuracy: 0.8662 - val_loss: 0.9864 - val_accuracy: 0.7100
# Epoch 27/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3989 - accuracy: 0.8775 - val_loss: 0.9373 - val_accuracy: 0.7100
# Epoch 28/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3742 - accuracy: 0.8813 - val_loss: 1.0130 - val_accuracy: 0.6850
# Epoch 29/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3584 - accuracy: 0.8838 - val_loss: 0.9785 - val_accuracy: 0.7150
# Epoch 30/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3473 - accuracy: 0.8888 - val_loss: 0.9906 - val_accuracy: 0.7300
# Epoch 31/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3450 - accuracy: 0.8875 - val_loss: 0.9572 - val_accuracy: 0.7300
# Epoch 32/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3147 - accuracy: 0.9075 - val_loss: 0.9538 - val_accuracy: 0.7500
# Epoch 33/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2978 - accuracy: 0.9100 - val_loss: 0.9938 - val_accuracy: 0.7450
# Epoch 34/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2798 - accuracy: 0.9175 - val_loss: 0.9840 - val_accuracy: 0.7300
# Epoch 35/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2701 - accuracy: 0.9212 - val_loss: 0.9736 - val_accuracy: 0.7350
# Epoch 36/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2567 - accuracy: 0.9250 - val_loss: 0.9949 - val_accuracy: 0.7300
# Epoch 37/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2454 - accuracy: 0.9325 - val_loss: 0.9993 - val_accuracy: 0.7600
# Epoch 38/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2464 - accuracy: 0.9287 - val_loss: 0.9659 - val_accuracy: 0.7400
# Epoch 39/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2342 - accuracy: 0.9350 - val_loss: 0.9999 - val_accuracy: 0.7250
# Epoch 40/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2161 - accuracy: 0.9413 - val_loss: 0.9705 - val_accuracy: 0.7400
# Epoch 41/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2349 - accuracy: 0.9375 - val_loss: 0.9747 - val_accuracy: 0.7400
# Epoch 42/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2027 - accuracy: 0.9500 - val_loss: 1.0172 - val_accuracy: 0.7400
# Epoch 43/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1941 - accuracy: 0.9488 - val_loss: 1.0024 - val_accuracy: 0.7500
# Epoch 44/50
# 80/80 [==============================] - 1s 19ms/step - loss: 0.1914 - accuracy: 0.9538 - val_loss: 1.0129 - val_accuracy: 0.7300
# Epoch 45/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1848 - accuracy: 0.9475 - val_loss: 1.0351 - val_accuracy: 0.7100
# Epoch 46/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1704 - accuracy: 0.9538 - val_loss: 1.0174 - val_accuracy: 0.7400
# Epoch 47/50
# 80/80 [==============================] - 1s 19ms/step - loss: 0.1703 - accuracy: 0.9575 - val_loss: 1.0042 - val_accuracy: 0.7300
# Epoch 48/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1671 - accuracy: 0.9600 - val_loss: 1.0556 - val_accuracy: 0.7250
# Epoch 49/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1568 - accuracy: 0.9663 - val_loss: 1.0324 - val_accuracy: 0.7450
# Epoch 50/50
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1564 - accuracy: 0.9588 - val_loss: 1.0462 - val_accuracy: 0.7350
# Test loss: 1.046156406402588
# Test accuracy: 0.7350000143051147

# %% [markdown]
# **Exercise 6:**
#
# In order to have a better intuition of the performance of the model on the testset, we can use a little bit of a visual aid by plotting the so called "confusion matrix". Create a confusion matrix such as the one shown in the second theory class:

# %%
y_test_non_category = [ np.argmax(t) for t in y_test ]
y_pred = deepDoc.predict(x_test)
y_predict_non_category = [ np.argmax(t) for t in y_pred ]

conf_mat = confusion_matrix(y_test_non_category, y_predict_non_category)

conf_mat2 = np.zeros((10,10))
for i in np.arange(10):
    conf_mat2[i,:] = 100*conf_mat[i,:]/np.sum(conf_mat[i,:])
    
classes_names = ['Ad','Email','Form','Letter','Memo','News','Note','Report','Resume','Scientific']

def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=20)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45 , fontsize=20)
    plt.yticks(tick_marks, classes , fontsize=20)

    fmt = '.1f' 
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 fontsize=15,
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=20)
    plt.xlabel('Predicted label', fontsize=20)
    
    plt.tight_layout()


plt.subplots(figsize=(10, 10)), plot_confusion_matrix(conf_mat2, classes=classes_names,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues)
# Out:
# ((<Figure size 720x720 with 2 Axes>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x7f000e4fe550>),
#  None)

# %% [markdown]
# **Exercise 7**
#
# About the confusion matrix plotted above, answer the following questions:
#
# a) What do the vertical and horizontal axis mean?
#
# b) What are the highest accuracies obtained and for which labels?
#
# c) What are the lowest accuracies obtained and for which labels?
#
# d) What are, in your opinion, the reasons for missclassification in these classes?
#
# **Answer:**
#
# a) Vertical axis represents the true label and horizontal axis represents the predicted label by model. The values at positions where true label == predicted value give us the percentage of samples that were correctly classifier for that particular label. The values in the other columns give us the percentage of samples that were misclassified as other labels.
#
# b) The Resume class with 100% accuracy, and Emails with 94% accuracy. (for my run)
#
# c) Report with 40.9% accuracy and Scientific with 45.8% accuracy. (for my run)
#
# d) Misclassification my happen when two or more classes share similar hidden features that creates confusion for the classifier to perform its task. For example, 20% of the samples in the Scientific class were misclassified as Form because some samples of these classes share similar features, such as two-column text, tables, etc...
#
# **Exercise 8**
#
# Try training the model again for the last split (800/200), but this time without using transfer learning. In this case you should do the following call:
#
# deepDoc = DeepDoc()
#
# What happens to the accuracy in this case?
#
# **Answer:**
#
# The accuracy will be very negatively affected because we won't leverage from the pre-trained weights on the ImageNet. We would have to train the model for way longer and even so we would probably not achieve similar accuracies as the one we achieved with transfer learning.
