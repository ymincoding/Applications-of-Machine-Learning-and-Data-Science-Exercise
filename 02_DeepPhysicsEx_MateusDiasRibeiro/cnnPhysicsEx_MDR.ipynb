# %% [markdown]
# **Exercise lecture 2 (Mateus Dias Ribeiro)**
#
# **ML for the solution of physics problems:**
#
# Computational Fluid Dynamics (CFD) simulation by the numerical solution of the Navier-Stokes equations is an essential tool in a wide range of applications from engineering design to climate modeling. However, the computational cost and memory demand required by CFD codes may become very high for flows of practical interest, such as in aerodynamic shape optimization. This expense is associated with the complexity of the fluid flow governing equations, which include non-linear partial derivative terms that are of difficult solution, leading to long computational times and limiting the number of hypotheses that can be tested during the process of iterative design. Therefore, we propose DeepCFD: a convolutional neural network (CNN) based model that efficiently approximates solutions for the problem of non-uniform steady laminar flows. The proposed model is able to learn complete solutions of the Navier-Stokes equations, for both velocity and pressure fields, directly from ground-truth data generated using a state-of-the-art CFD code. Using DeepCFD, we found a speedup of up to 3 orders of magnitude compared to the standard CFD approach at a cost of low error rates.
#
# **Dataset and code:**
#
# A toy dataset and the code for this project can be downloaded using the following https://zenodo.org/record/3666056/files/DeepCFD.zip
#
# The folder includes the files dataX and dataY, in which the first file provides the input information on the geometry of 981 channel flow samples, whereas the dataY file provides their ground-truth CFD solution for the velocity (Ux and Uy) and thepressure (p) fields using the simpleFOAM solver. Figure 1 describes the structure of each of these files in detail:
#
# ![CFDAI](https://raw.githubusercontent.com/mdribeiro/DeepCFD/master/ReadmeFiles/DataStruct.png)
# > Figure 1. DeepCFD toy dataset structure.
#
# Both dataX and dataY have the same number of dimensions (Ns, Nc, Nx, Ny), in which the first axis is the number of samples (Ns), the second axis is the number of channels (Nc), and third and fourth axes are the number of elements in x and y (Nx and Ny). Regarding the input dataX, the first channel is the SDF calculated from the obstacle's surface, the second channel is the multi-label flow region channel, and the third channel is the SDF from the top/bottom surfaces. For the output dataY file, the first channel is the Ux horizontal velocity component, the second channel is the Uy vertical velocity component, and the third channel is the pressure field.

# %% [markdown]
# First, let's load some necessary dependencies:

# %%
# !git clone https://git.opendfki.de/mateus.dias_ribeiro/supplementaryphysics.git
# !mv supplementaryphysics/*  .
# !rm -r supplementaryphysics
# !pip install scikit-fmm==0.0.7
# Out:
# Cloning into 'supplementaryphysics'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 33 (delta 11), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (33/33), done.
# Collecting scikit-fmm==0.0.7
#   Downloading https://files.pythonhosted.org/packages/95/d7/19ad23766b5b2c34a64576f66bae46acf4b8da30d20269b31ef7122d958c/scikit-fmm-0.0.7.zip (230kB)
#      |████████████████████████████████| 235kB 5.2MB/s
# Requirement already satisfied: numpy>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from scikit-fmm==0.0.7) (1.18.5)
# Building wheels for collected packages: scikit-fmm
#   Building wheel for scikit-fmm (setup.py) ... done
#   Created wheel for scikit-fmm: filename=scikit_fmm-0.0.7-cp36-cp36m-linux_x86_64.whl size=155169 sha256=f2bab4ed470bc92525773b3a5e5a1e26ed4ccdee1b973547fdf51fcc217d923d
#   Stored in directory: /root/.cache/pip/wheels/15/b6/5b/131eca30948459595b3a336a3425d3f824a8b22f23bb979d47
# Successfully built scikit-fmm
# Installing collected packages: scikit-fmm
# Successfully installed scikit-fmm-0.0.7

# %% [markdown]
# **Exercise 1:**
#
# In the next code snippet, you will learn the first step of our CNN for fluids application, which involves converting the data obtained by the solution of the Navier-Stokes equations from a tabular format (as produced by the CFD code) into a tensor format, which can be later read by our CNN network. As discussed in the class, in order to give the CNN network the understanding about the geometry of the domain to be able to find a mapping between the geometry information (X) and the desired outputs (velocity fields ux, uy, and pressure field, Y), we need to calculate the SDF (signed distance function) field around the obstacle for each training sample. The script below shows us how to do this for 10 training samples. First, we create a tensor/numpy array to store the information about the calculated velocity and pressure at each grid location. It is important to notice that at this point we do a down sampling step, meaning that the number of data points to be used for training of the CNN is smaller than the number of points calculated in the simulation (this will make things faster to train). The tensor will have dimensions (Ns, Nx, Ny, Nc), in which Ns represents the number of samples, Nx/Ny the number of points in x and y, and Nc the number of variables we are saving (x, y information, velocity field, pressure field, etc.
#
# For this exercise, use the skfmm package, which is an implementation of the fast marching method, to calculate the desired SDF fields from the tensor named grid. After that, create a plot function to plot both input and output tensors that we need to train our CNN model. Plot both X (SFD, binary mask) and Y (velocity, pressure) channels as shown in the Figure 1, i.e. use the first column for the 3 channels in X and the second column for the 3 channels in Y.

# %%
import torch
import pandas as pd
import numpy as np

import skfmm
import pickle

import matplotlib.pyplot as plt

def load_data(file, max_rows=1024 * 1024 * 2):
    return pd.read_csv(file, nrows=max_rows)

n_samples = 10
   
Xs = []    
Ys = []

dataAll = []
for i in range(n_samples):

    device = "cpu"
    x_col = "x"
    y_col = "y"
    z_col = "z"
    target_col = "U:0"
      
    data_i = load_data("./Data/cfdSample_" + str(i) + ".csv", max_rows=100000000000)
    dataAll.append(data_i)
    print("Data " + str(i) +  " loaded!")
    
print("All data loaded!")
for i in range(n_samples):

    data = dataAll[i]
    
    x, y, z, target = data[x_col].values, data[y_col].values, data[z_col].values, data[target_col].values
    x, y, z, target = torch.FloatTensor(x).to(device), torch.FloatTensor(y).to(device), torch.FloatTensor(z).to(device), torch.FloatTensor(target)
    features = [torch.FloatTensor(data[p]).to(device) for p in data.keys()]

    print("Mesh: " + str(i))

    x_sorted, x_index = torch.sort(x)
    y_sorted, y_index = torch.sort(y)
    z_sorted, z_index = torch.sort(z)

    min_x, max_x = float(x_sorted[0]), float(x_sorted[-1])
    min_y, max_y = float(y_sorted[0]), float(y_sorted[-1])
    min_z, max_z = float(z_sorted[0]), float(z_sorted[-1])
    
    cell_x, cell_y, cell_z = 0.0015,0.0015,0.0015
    x_diff, y_diff, z_diff = x_sorted[1:] - x_sorted[:-1], y_sorted[1:] - y_sorted[:-1],  torch.FloatTensor(np.array( [0, cell_z])).to(device) 


    len_x, len_y, len_z = (max_x - min_x) / cell_x, (max_y - min_y) / cell_y, (max_z - min_z) / cell_z
    len_x, len_y, len_z = int(len_x), int(len_y), 1

    print("Grid dimensions: " + str((len_x, len_y, len_z)))     
    
    const = 0.01
    lpos = 1.0 + const
    lneg = 1.0 - const
    
    grid = torch.zeros(len_x, len_y, len_z, len(features)).to(device)
    
    for _x in range(len_x):
        for _y in range(len_y):
            for _z in range(len_z):
                
                cell_space = ( x >= 10000000000000000) # Just create a vector with Falses
                
                const = cell_x/2
                for i in range(1):
                    const = const + const*i
                    cell_min_x, cell_max_x = -const + min_x + cell_x * _x, const + min_x + cell_x * (_x + 1)
                    cell_min_y, cell_max_y = -const + min_y + cell_y * _y, const + min_y + cell_y * (_y + 1)
                    cell_min_z, cell_max_z = -const + min_z + cell_z * _z, const + min_z + cell_z * (_z + 1)
                    cell_space_i = (x >= cell_min_x) & (x < cell_max_x) & (y >= cell_min_y) & (y < cell_max_y)
                    cell_space = cell_space + cell_space_i                  

                pcell = int(torch.sum(cell_space.type(torch.int)))
                cell_features = torch.stack([torch.mean(feature[cell_space]) for feature in features])                       
                grid[_x, _y, _z, :] = cell_features
                
    grid = grid.cpu().detach().numpy()

    ###############################################################
    ##### Your code to calculate SDF using skfmm package here #####
    ###############################################################
    
Xsn = np.asarray(Xs)
Ysn = np.asarray(Ys)

pickle.dump( Xsn, open( "xCylinder.pkl", "wb" ) )
pickle.dump( Ysn, open( "yCylinder.pkl", "wb" ) )
# Out:
# Data 0 loaded!
# Data 1 loaded!
# Data 2 loaded!
# Data 3 loaded!
# Data 4 loaded!
# Data 5 loaded!
# Data 6 loaded!
# Data 7 loaded!
# Data 8 loaded!
# Data 9 loaded!
# All data loaded!
# Mesh: 0
# Grid dimensions: (172, 79, 1)
# Mesh: 1
# Grid dimensions: (172, 79, 1)
# Mesh: 2
# Grid dimensions: (172, 79, 1)
# Mesh: 3
# Grid dimensions: (172, 79, 1)
# Mesh: 4
# Grid dimensions: (172, 79, 1)
# Mesh: 5
# Grid dimensions: (172, 79, 1)
# Mesh: 6
# Grid dimensions: (172, 79, 1)
# Mesh: 7
# Grid dimensions: (172, 79, 1)
# Mesh: 8
# Grid dimensions: (172, 79, 1)
# Mesh: 9
# Grid dimensions: (172, 79, 1)

# %%
##########################################
##### Your code to plot X and Y here #####
##########################################

# %% [markdown]
# Load some other packages we are going to need to train our model:

# %%
import os
import json
import torch
import pickle
from train_functions import *
from functions import *
import torch.optim as optim
from torch.utils.data import TensorDataset
from Models.UNetEx import UNetEx

# %% [markdown]
# Now let's download the entired dataset (already post-processed with 981 samples for X and Y) and load it to our colab environment:

# %%
# !wget https://zenodo.org/record/3665511/files/dataX.pkl
# !wget https://zenodo.org/record/3665511/files/dataY.pkl
# Out:
# --2020-11-12 08:01:12--  https://zenodo.org/record/3665511/files/dataX.pkl
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159958102 (153M) [application/octet-stream]
# Saving to: ‘dataX.pkl’
#
# dataX.pkl           100%[===================>] 152.55M  3.09MB/s    in 89s
#
# 2020-11-12 08:02:43 (1.72 MB/s) - ‘dataX.pkl’ saved [159958102/159958102]
#
# --2020-11-12 08:02:43--  https://zenodo.org/record/3665511/files/dataY.pkl
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159958102 (153M) [application/octet-stream]
# Saving to: ‘dataY.pkl’
#
# dataY.pkl           100%[===================>] 152.55M  7.05MB/s    in 88s
#
# 2020-11-12 08:04:13 (1.73 MB/s) - ‘dataY.pkl’ saved [159958102/159958102]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
x = pickle.load(open("./dataX.pkl", "rb"))
y = pickle.load(open("./dataY.pkl", "rb"))

# %% [markdown]
# **Exercise 2:**
#
# In this exercise we would like you to setup the problem. Modify the code snippet below to call the UNetEx architecture we discussed in the class with the following hyperparmeters:
#
# lr = 0.001
#
# CNN filtre size = 5
#
# Number of CNN layers in each encoding/decoding part = 4
#
# Number of filters in each layer at Encoder = 8 in 1st layer, 16 in 2nd layer, 32 in 3rd layer and 32 in 4th layer
#
# Number of filters in each layer at Decoder = 32 in 1st layer, 32 in 2nd layer, 16 in 3rd layer and 8 in 4th layer
#
# Weight decay = 0.005
#
# Batch norm = False
#
# Weight norm = False
#
# Optimizer = AdamW

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
x = torch.FloatTensor(x)
y = torch.FloatTensor(y)    
channels_weights = torch.sqrt(torch.mean(y.permute(0, 2, 3, 1).reshape((981*172*79,3)) ** 2, dim=0)).view(1, -1, 1, 1).to(device)
print(channels_weights)

simulation_directory = "./Run/"
if not os.path.exists(simulation_directory):
    os.makedirs(simulation_directory)
    
# Spliting dataset into 70% train and 30% test
train_data, test_data = split_tensors(x, y, ratio=0.7)

train_dataset, test_dataset = TensorDataset(*train_data), TensorDataset(*test_data)        
test_x, test_y = test_dataset[:]

##########################
##### Your code here #####
##########################

torch.manual_seed(0)

lr =##### Your code here #####
kernel_size = ##### Your code here #####
filters = ##### Your code here #####
bn = ##### Your code here #####
wn = ##### Your code here #####
wd = 0.005
model = ##### Your code here #####
# Define opotimizer
optimizer = ##### Your code here #####
# Out:
# tensor([[[[0.1153]],
#
#          [[0.0175]],
#
#          [[0.0135]]]], device='cuda:0')

# %% [markdown]
# **Exercise 3:**
#
# In this exercise, define the loss function for each of the outputs (ux, uy, p). For ux and uy, use the L2-norm. For the pressure p, use the L1-norm. Sum all three error values to one single "loss" variable. Normalize the loss by dividing it by the channel weights calculated in previous cell.

# %%
def loss_func(model, batch):
    x, y = batch
    output = model(x)
    lossu = ##### Your code here #####
    lossv = ##### Your code here #####
    lossp = ##### Your code here #####
    loss = (lossu + lossv + lossp)/channels_weights
    return torch.sum(loss), output

# %% [markdown]
# In the next cell we train the model for 300 epochs:

# %%
config = {}        
train_loss_curve = []
test_loss_curve = []
train_mse_curve = []
test_mse_curve = []
train_ux_curve = []
test_ux_curve = []
train_uy_curve = []
test_uy_curve = []
train_p_curve = []
test_p_curve = []

def after_epoch(scope):
    train_loss_curve.append(scope["train_loss"])
    test_loss_curve.append(scope["val_loss"])
    train_mse_curve.append(scope["train_metrics"]["mse"])
    test_mse_curve.append(scope["val_metrics"]["mse"])
    train_ux_curve.append(scope["train_metrics"]["ux"])
    test_ux_curve.append(scope["val_metrics"]["ux"])
    train_uy_curve.append(scope["train_metrics"]["uy"])
    test_uy_curve.append(scope["val_metrics"]["uy"])
    train_p_curve.append(scope["train_metrics"]["p"])
    test_p_curve.append(scope["val_metrics"]["p"])

# Training model
DeepCFD, train_metrics, train_loss, test_metrics, test_loss = train_model(model, loss_func, train_dataset, test_dataset, optimizer,
    epochs=300, batch_size=64, device=device,    #epochs=1000, batch_size=64, device=device,
    m_mse_name="Total MSE",
    m_mse_on_batch=lambda scope: float(torch.sum((scope["output"] - scope["batch"][1]) ** 2)),
    m_mse_on_epoch=lambda scope: sum(scope["list"]) / len(scope["dataset"]),
    m_ux_name="Ux MSE",
    m_ux_on_batch=lambda scope: float(torch.sum((scope["output"][:,0,:,:] - scope["batch"][1][:,0,:,:]) ** 2)),
    m_ux_on_epoch=lambda scope: sum(scope["list"]) / len(scope["dataset"]),
    m_uy_name="Uy MSE",
    m_uy_on_batch=lambda scope: float(torch.sum((scope["output"][:,1,:,:] - scope["batch"][1][:,1,:,:]) ** 2)),
    m_uy_on_epoch=lambda scope: sum(scope["list"]) / len(scope["dataset"]),
    m_p_name="p MSE",
    m_p_on_batch=lambda scope: float(torch.sum((scope["output"][:,2,:,:] - scope["batch"][1][:,2,:,:]) ** 2)),
    m_p_on_epoch=lambda scope: sum(scope["list"]) / len(scope["dataset"]), patience=25, after_epoch=after_epoch
    )
    
metrics = {}
metrics["train_metrics"] = train_metrics
metrics["train_loss"] = train_loss
metrics["test_metrics"] = test_metrics
metrics["test_loss"] = test_loss
curves = {}
curves["train_loss_curve"] = train_loss_curve
curves["test_loss_curve"] = test_loss_curve
curves["train_mse_curve"] = train_mse_curve
curves["test_mse_curve"] = test_mse_curve
curves["train_ux_curve"] = train_ux_curve
curves["test_ux_curve"] = test_ux_curve
curves["train_uy_curve"] = train_uy_curve
curves["test_uy_curve"] = test_uy_curve
curves["train_p_curve"] = train_p_curve
curves["test_p_curve"] = test_p_curve
config["metrics"] = metrics
config["curves"] = curves
with open(simulation_directory + "results.json", "w") as file:
    json.dump(config, file)
# Out:
# Epoch #1
# 	Train Loss = 212702229.0
# 	Train Total MSE = 1957.538100173105
# 	Train Ux MSE = 1830.112976608054
# 	Train Uy MSE = 113.35812938456633
# 	Train p MSE = 14.067018225311191
# 	Validation Loss = 49701615.0
# 	Validation Total MSE = 1052.9387447033898
# 	Validation Ux MSE = 1029.8884004237289
# 	Validation Uy MSE = 19.50826850503178
# 	Validation p MSE = 3.5420682745464775
# Model saved!
# Epoch #2
# 	Train Loss = 107379016.0
# 	Train Total MSE = 985.4617233053935
# 	Train Ux MSE = 965.617523460277
# 	Train Uy MSE = 16.884986899684538
# 	Train p MSE = 2.959219696222867
# 	Validation Loss = 41857769.0
# 	Validation Total MSE = 891.8731991525424
# 	Validation Ux MSE = 873.3876721398306
# 	Validation Uy MSE = 15.708639267743644
# 	Validation p MSE = 2.776904296875
# Model saved!
# Epoch #3
# 	Train Loss = 88494700.0
# 	Train Total MSE = 808.6637891763849
# 	Train Ux MSE = 791.8979933491254
# 	Train Uy MSE = 14.372330201262983
# 	Train p MSE = 2.3934936745868827
# 	Validation Loss = 32662893.0
# 	Validation Total MSE = 695.6262976694916
# 	Validation Ux MSE = 680.1325079449152
# 	Validation Uy MSE = 13.424331096067267
# 	Validation p MSE = 2.0694551629535223
# Model saved!
# Epoch #4
# 	Train Loss = 62702325.75
# 	Train Total MSE = 578.418953853863
# 	Train Ux MSE = 563.7041414221939
# 	Train Uy MSE = 12.937926712258564
# 	Train p MSE = 1.7768713948330448
# 	Validation Loss = 18352099.25
# 	Validation Total MSE = 388.47562235169494
# 	Validation Ux MSE = 374.4156878972458
# 	Validation Uy MSE = 12.517748195842161
# 	Validation p MSE = 1.542202655339645
# Model saved!
# Epoch #5
# 	Train Loss = 23751100.875
# 	Train Total MSE = 192.34391798013849
# 	Train Ux MSE = 178.7344700226631
# 	Train Uy MSE = 12.114067678201303
# 	Train p MSE = 1.4953810828072684
# 	Validation Loss = 7739118.4375
# 	Validation Total MSE = 137.2147543697034
# 	Validation Ux MSE = 123.99662506620763
# 	Validation Uy MSE = 11.758067709712659
# 	Validation p MSE = 1.4600678136793233
# Model saved!
# Epoch #6
# 	Train Loss = 12276288.625
# 	Train Total MSE = 79.27188795440051
# 	Train Ux MSE = 66.51942946542457
# 	Train Uy MSE = 11.345831289930873
# 	Train p MSE = 1.4066264705824782
# 	Validation Loss = 4789044.6875
# 	Validation Total MSE = 68.57506289724576
# 	Validation Ux MSE = 56.2303413003178
# 	Validation Uy MSE = 10.948250670352225
# 	Validation p MSE = 1.396472652887894
# Model saved!
# Epoch #7
# 	Train Loss = 10113783.6875
# 	Train Total MSE = 59.87757593271684
# 	Train Ux MSE = 48.03290915975765
# 	Train Uy MSE = 10.502155670966768
# 	Train p MSE = 1.3425122475137516
# 	Validation Loss = 3967418.0625
# 	Validation Total MSE = 51.77428868180614
# 	Validation Ux MSE = 40.324629237288136
# 	Validation Uy MSE = 10.1056080963652
# 	Validation p MSE = 1.344052317991095
# Model saved!
# Epoch #8
# 	Train Loss = 9075739.5625
# 	Train Total MSE = 51.66714450847303
# 	Train Ux MSE = 40.80393158937682
# 	Train Uy MSE = 9.571880818803526
# 	Train p MSE = 1.2913313259536254
# 	Validation Loss = 3778133.21875
# 	Validation Total MSE = 49.34917902542373
# 	Validation Ux MSE = 39.07239266088453
# 	Validation Uy MSE = 8.975421039128708
# 	Validation p MSE = 1.301366812495862
# Model saved!
# Epoch #9
# 	Train Loss = 8548470.6875
# 	Train Total MSE = 48.352730887276785
# 	Train Ux MSE = 38.90913982780612
# 	Train Uy MSE = 8.195676620083022
# 	Train p MSE = 1.2479151191933857
# 	Validation Loss = 3610381.875
# 	Validation Total MSE = 47.18187152409958
# 	Validation Ux MSE = 38.449434752383475
# 	Validation Uy MSE = 7.474374751721398
# 	Validation p MSE = 1.2580605393749171
# Model saved!
# Epoch #10
# 	Train Loss = 8171859.5625
# 	Train Total MSE = 45.92466428884612
# 	Train Ux MSE = 37.781780632174744
# 	Train Uy MSE = 6.924882671923401
# 	Train p MSE = 1.2179996126247217
# 	Validation Loss = 3492696.0625
# 	Validation Total MSE = 45.32132795948093
# 	Validation Ux MSE = 37.649294061175844
# 	Validation Uy MSE = 6.444009037341102
# 	Validation p MSE = 1.2280251939417952
# Model saved!
# Epoch #11
# 	Train Loss = 7859365.59375
# 	Train Total MSE = 43.98651781443604
# 	Train Ux MSE = 36.869134752812954
# 	Train Uy MSE = 5.932370822561726
# 	Train p MSE = 1.1850128034808545
# 	Validation Loss = 3337770.125
# 	Validation Total MSE = 43.18972954184322
# 	Validation Ux MSE = 36.58824938757945
# 	Validation Uy MSE = 5.408728130793167
# 	Validation p MSE = 1.1927530353352176
# Model saved!
# Epoch #12
# 	Train Loss = 7480915.4375
# 	Train Total MSE = 41.845964170405885
# 	Train Ux MSE = 35.76064841045235
# 	Train Uy MSE = 4.9286346435546875
# 	Train p MSE = 1.156680525565634
# 	Validation Loss = 3187799.625
# 	Validation Total MSE = 41.03405596199682
# 	Validation Ux MSE = 35.449487718485166
# 	Validation Uy MSE = 4.408501162771452
# 	Validation p MSE = 1.1760680150177518
# Model saved!
# Epoch #13
# 	Train Loss = 7185946.40625
# 	Train Total MSE = 39.72575107051749
# 	Train Ux MSE = 34.502737862723215
# 	Train Uy MSE = 4.081644597623508
# 	Train p MSE = 1.141368257061038
# 	Validation Loss = 3055837.625
# 	Validation Total MSE = 38.81058411679025
# 	Validation Ux MSE = 33.984043134269065
# 	Validation Uy MSE = 3.6616503699351166
# 	Validation p MSE = 1.1648904541791496
# Model saved!
# Epoch #14
# 	Train Loss = 6969814.71875
# 	Train Total MSE = 37.570664831222665
# 	Train Ux MSE = 33.12389638472577
# 	Train Uy MSE = 3.3093405631818853
# 	Train p MSE = 1.137427506571956
# 	Validation Loss = 2963528.84375
# 	Validation Total MSE = 36.81883193193856
# 	Validation Ux MSE = 32.74416628045551
# 	Validation Uy MSE = 2.921003024860964
# 	Validation p MSE = 1.1536631050756423
# Model saved!
# Epoch #15
# 	Train Loss = 6701699.9375
# 	Train Total MSE = 35.8086994493668
# 	Train Ux MSE = 31.931324772515033
# 	Train Uy MSE = 2.7551847963917013
# 	Train p MSE = 1.1221891492170772
# 	Validation Loss = 2862913.25
# 	Validation Total MSE = 35.45606379104873
# 	Validation Ux MSE = 31.677389267743646
# 	Validation Uy MSE = 2.63384616657839
# 	Validation p MSE = 1.144828269441249
# Model saved!
# Epoch #16
# 	Train Loss = 6554565.9375
# 	Train Total MSE = 34.66141663487382
# 	Train Ux MSE = 30.99235761547923
# 	Train Uy MSE = 2.552267758561293
# 	Train p MSE = 1.1167918669586627
# 	Validation Loss = 2796833.5625
# 	Validation Total MSE = 34.59981213585805
# 	Validation Ux MSE = 30.89596961069915
# 	Validation Uy MSE = 2.5680209402310648
# 	Validation p MSE = 1.135822383428024
# Model saved!
# Epoch #17
# 	Train Loss = 6382543.25
# 	Train Total MSE = 33.81694150874635
# 	Train Ux MSE = 30.329775084559493
# 	Train Uy MSE = 2.383354943278232
# 	Train p MSE = 1.103811995281075
# 	Validation Loss = 2768770.125
# 	Validation Total MSE = 33.79740300582627
# 	Validation Ux MSE = 30.362860831567797
# 	Validation Uy MSE = 2.3027227369405456
# 	Validation p MSE = 1.1318179486161573
# Model saved!
# Epoch #18
# 	Train Loss = 6324751.15625
# 	Train Total MSE = 33.10145288584184
# 	Train Ux MSE = 29.818704410475128
# 	Train Uy MSE = 2.1836691097337373
# 	Train p MSE = 1.0990790862036168
# 	Validation Loss = 2730602.40625
# 	Validation Total MSE = 33.15757622153072
# 	Validation Ux MSE = 29.840443342823093
# 	Validation Uy MSE = 2.190176572638043
# 	Validation p MSE = 1.1269582392805713
# Model saved!
# Epoch #19
# 	Train Loss = 6142061.9375
# 	Train Total MSE = 32.40474938929255
# 	Train Ux MSE = 29.246277211358873
# 	Train Uy MSE = 2.0701889727623053
# 	Train p MSE = 1.0882840100947344
# 	Validation Loss = 2682429.96875
# 	Validation Total MSE = 32.386909096927965
# 	Validation Ux MSE = 29.180162539724577
# 	Validation Uy MSE = 2.085480201850503
# 	Validation p MSE = 1.1212674448045634
# Model saved!
# Epoch #20
# 	Train Loss = 6172383.28125
# 	Train Total MSE = 31.6651611328125
# 	Train Ux MSE = 28.56302760710869
# 	Train Uy MSE = 2.0124882400557182
# 	Train p MSE = 1.0896459571126598
# 	Validation Loss = 2709104.65625
# 	Validation Total MSE = 31.55100925251589
# 	Validation Ux MSE = 28.437389102224575
# 	Validation Uy MSE = 1.9936575679455772
# 	Validation p MSE = 1.119962315640207
# Epoch #21
# 	Train Loss = 6181380.375
# 	Train Total MSE = 30.782071928241162
# 	Train Ux MSE = 27.728085175895135
# 	Train Uy MSE = 1.9572663154268404
# 	Train p MSE = 1.0967201637457134
# 	Validation Loss = 2596811.53125
# 	Validation Total MSE = 30.627468303098517
# 	Validation Ux MSE = 27.518508755958685
# 	Validation Uy MSE = 1.9926947383557336
# 	Validation p MSE = 1.1162648782891742
# Model saved!
# Epoch #22
# 	Train Loss = 5952913.0625
# 	Train Total MSE = 29.8291179334457
# 	Train Ux MSE = 26.83309553941554
# 	Train Uy MSE = 1.9134898616690676
# 	Train p MSE = 1.0825323217464258
# 	Validation Loss = 2527795.125
# 	Validation Total MSE = 29.54654147907839
# 	Validation Ux MSE = 26.563769324351167
# 	Validation Uy MSE = 1.877127644167108
# 	Validation p MSE = 1.1056452589519954
# Model saved!
# Epoch #23
# 	Train Loss = 5787280.09375
# 	Train Total MSE = 28.414820190073797
# 	Train Ux MSE = 25.576711938263028
# 	Train Uy MSE = 1.7599163111027754
# 	Train p MSE = 1.0781927206078354
# 	Validation Loss = 2474083.125
# 	Validation Total MSE = 27.737389929819916
# 	Validation Ux MSE = 24.89599526615466
# 	Validation Uy MSE = 1.7350584903005826
# 	Validation p MSE = 1.1063360165741485
# Model saved!
# Epoch #24
# 	Train Loss = 5759500.125
# 	Train Total MSE = 26.37143967520044
# 	Train Ux MSE = 23.455582421305575
# 	Train Uy MSE = 1.8304770778288995
# 	Train p MSE = 1.0853792912063376
# 	Validation Loss = 2297115.84375
# 	Validation Total MSE = 24.40497964115466
# 	Validation Ux MSE = 21.614790370100636
# 	Validation Uy MSE = 1.687352377681409
# 	Validation p MSE = 1.102836447247004
# Model saved!
# Epoch #25
# 	Train Loss = 5221591.78125
# 	Train Total MSE = 22.166048900726587
# 	Train Ux MSE = 19.397667353771865
# 	Train Uy MSE = 1.698777246058161
# 	Train p MSE = 1.0696043571994882
# 	Validation Loss = 2137482.59375
# 	Validation Total MSE = 19.862958487817796
# 	Validation Ux MSE = 17.19735459149894
# 	Validation Uy MSE = 1.5649406821040783
# 	Validation p MSE = 1.1006631010669774
# Model saved!
# Epoch #26
# 	Train Loss = 4662558.515625
# 	Train Total MSE = 18.12475577040247
# 	Train Ux MSE = 15.534425251685496
# 	Train Uy MSE = 1.5231303445799358
# 	Train p MSE = 1.0672001414674364
# 	Validation Loss = 1954609.5
# 	Validation Total MSE = 16.475951527740996
# 	Validation Ux MSE = 13.802085540254238
# 	Validation Uy MSE = 1.573968053268174
# 	Validation p MSE = 1.0998980708041433
# Model saved!
# Epoch #27
# 	Train Loss = 4346561.609375
# 	Train Total MSE = 15.516184014412126
# 	Train Ux MSE = 13.062160347362996
# 	Train Uy MSE = 1.3917941769079982
# 	Train p MSE = 1.062229645843061
# 	Validation Loss = 1953191.109375
# 	Validation Total MSE = 16.236651300979872
# 	Validation Ux MSE = 13.722974460407839
# 	Validation Uy MSE = 1.4177734762935315
# 	Validation p MSE = 1.0959040698358569
# Model saved!
# Epoch #28
# 	Train Loss = 4172506.3125
# 	Train Total MSE = 13.750962148949982
# 	Train Ux MSE = 11.373919695528881
# 	Train Uy MSE = 1.3192817087423696
# 	Train p MSE = 1.0577606362434588
# 	Validation Loss = 1763049.4375
# 	Validation Total MSE = 12.784737900556143
# 	Validation Ux MSE = 10.360766187764831
# 	Validation Uy MSE = 1.3344086339918233
# 	Validation p MSE = 1.0895626892477779
# Model saved!
# Epoch #29
# 	Train Loss = 3907037.1875
# 	Train Total MSE = 11.629854786152743
# 	Train Ux MSE = 9.355807913288084
# 	Train Uy MSE = 1.2208037251286188
# 	Train p MSE = 1.0532432526958233
# 	Validation Loss = 1659576.59375
# 	Validation Total MSE = 11.081939904164459
# 	Validation Ux MSE = 8.753787386619438
# 	Validation Uy MSE = 1.2439677351612155
# 	Validation p MSE = 1.084184323327016
# Model saved!
# Epoch #30
# 	Train Loss = 3699055.5
# 	Train Total MSE = 10.180298830260341
# 	Train Ux MSE = 7.967210552782776
# 	Train Uy MSE = 1.1626435160289352
# 	Train p MSE = 1.0504451006564037
# 	Validation Loss = 1595317.34375
# 	Validation Total MSE = 9.785243250960011
# 	Validation Ux MSE = 7.5036980063228285
# 	Validation Uy MSE = 1.200020263154628
# 	Validation p MSE = 1.0815252724340407
# Model saved!
# Epoch #31
# 	Train Loss = 3694901.71875
# 	Train Total MSE = 9.435398602277127
# 	Train Ux MSE = 7.246735775783527
# 	Train Uy MSE = 1.1418968790126611
# 	Train p MSE = 1.0467662567995033
# 	Validation Loss = 1583742.59375
# 	Validation Total MSE = 9.496352994239937
# 	Validation Ux MSE = 7.202634908385196
# 	Validation Uy MSE = 1.2130309024099577
# 	Validation p MSE = 1.0806870840363583
# Model saved!
# Epoch #32
# 	Train Loss = 3529110.25
# 	Train Total MSE = 8.907936073948273
# 	Train Ux MSE = 6.775953776634817
# 	Train Uy MSE = 1.088718720149716
# 	Train p MSE = 1.043263699500971
# 	Validation Loss = 1532451.078125
# 	Validation Total MSE = 8.923277774099576
# 	Validation Ux MSE = 6.772174227439751
# 	Validation Uy MSE = 1.0735514624644134
# 	Validation p MSE = 1.0775522417941337
# Model saved!
# Epoch #33
# 	Train Loss = 3471010.40625
# 	Train Total MSE = 8.59756376305405
# 	Train Ux MSE = 6.538557047051522
# 	Train Uy MSE = 1.0155948383119988
# 	Train p MSE = 1.0434118373748513
# 	Validation Loss = 1508297.5
# 	Validation Total MSE = 8.887363239870233
# 	Validation Ux MSE = 6.7473102116988874
# 	Validation Uy MSE = 1.0664783154503774
# 	Validation p MSE = 1.0735748525393212
# Model saved!
# Epoch #34
# 	Train Loss = 3464519.546875
# 	Train Total MSE = 8.163457219871766
# 	Train Ux MSE = 6.134841029220003
# 	Train Uy MSE = 0.9804038556602189
# 	Train p MSE = 1.048212061470521
# 	Validation Loss = 1538723.453125
# 	Validation Total MSE = 8.03349495580641
# 	Validation Ux MSE = 5.940592516882945
# 	Validation Uy MSE = 1.0135652833065745
# 	Validation p MSE = 1.0793373786796958
# Epoch #35
# 	Train Loss = 3603553.4375
# 	Train Total MSE = 7.684692916647686
# 	Train Ux MSE = 5.691766633236721
# 	Train Uy MSE = 0.9542038697890568
# 	Train p MSE = 1.0387224393405303
# 	Validation Loss = 1503777.171875
# 	Validation Total MSE = 7.9296316373146185
# 	Validation Ux MSE = 5.757636532541048
# 	Validation Uy MSE = 1.089790693380065
# 	Validation p MSE = 1.0822045083773337
# Model saved!
# Epoch #36
# 	Train Loss = 3439616.390625
# 	Train Total MSE = 7.486447882026694
# 	Train Ux MSE = 5.421783625210687
# 	Train Uy MSE = 1.0227828512386399
# 	Train p MSE = 1.0418814024494272
# 	Validation Loss = 1492504.96875
# 	Validation Total MSE = 7.610688445527675
# 	Validation Ux MSE = 5.514966441009004
# 	Validation Uy MSE = 1.0167833489886784
# 	Validation p MSE = 1.0789388155533095
# Model saved!
# Epoch #37
# 	Train Loss = 3375692.328125
# 	Train Total MSE = 7.349520758359147
# 	Train Ux MSE = 5.3360054972567985
# 	Train Uy MSE = 0.9686925626704713
# 	Train p MSE = 1.0448226949563875
# 	Validation Loss = 1487803.90625
# 	Validation Total MSE = 7.669742390260858
# 	Validation Ux MSE = 5.605435232388771
# 	Validation Uy MSE = 0.9864895190222789
# 	Validation p MSE = 1.0778176073300636
# Model saved!
# Epoch #38
# 	Train Loss = 3297925.484375
# 	Train Total MSE = 7.26082008295087
# 	Train Ux MSE = 5.275338064477325
# 	Train Uy MSE = 0.9483399683115433
# 	Train p MSE = 1.0371421419149238
# 	Validation Loss = 1464617.984375
# 	Validation Total MSE = 7.112273549225371
# 	Validation Ux MSE = 5.147058157193459
# 	Validation Uy MSE = 0.8916098837125099
# 	Validation p MSE = 1.0736056101524223
# Model saved!
# Epoch #39
# 	Train Loss = 3212580.390625
# 	Train Total MSE = 6.7449997215159785
# 	Train Ux MSE = 4.886458438617495
# 	Train Uy MSE = 0.82426430393586
# 	Train p MSE = 1.034276854540099
# 	Validation Loss = 1376515.328125
# 	Validation Total MSE = 6.797673112255032
# 	Validation Ux MSE = 4.874992655091367
# 	Validation Uy MSE = 0.8556997008242849
# 	Validation p MSE = 1.0669809341430665
# Model saved!
# Epoch #40
# 	Train Loss = 3158088.21875
# 	Train Total MSE = 6.46631726857177
# 	Train Ux MSE = 4.671332667937432
# 	Train Uy MSE = 0.7585376539313758
# 	Train p MSE = 1.0364468535598443
# 	Validation Loss = 1358303.21875
# 	Validation Total MSE = 6.644286540403204
# 	Validation Ux MSE = 4.79269667803231
# 	Validation Uy MSE = 0.7858828463796842
# 	Validation p MSE = 1.0657068996106165
# Model saved!
# Epoch #41
# 	Train Loss = 3049105.40625
# 	Train Total MSE = 6.159568252785908
# 	Train Ux MSE = 4.416080841865206
# 	Train Uy MSE = 0.7086091833976546
# 	Train p MSE = 1.0348782563696102
# 	Validation Loss = 1314279.53125
# 	Validation Total MSE = 6.238334733348782
# 	Validation Ux MSE = 4.415559826867055
# 	Validation Uy MSE = 0.7600723007978019
# 	Validation p MSE = 1.0627028481434968
# Model saved!
# Epoch #42
# 	Train Loss = 2990967.28125
# 	Train Total MSE = 5.826825400483156
# 	Train Ux MSE = 4.126081994949208
# 	Train Uy MSE = 0.6748197850263501
# 	Train p MSE = 1.0259236170321095
# 	Validation Loss = 1265444.484375
# 	Validation Total MSE = 5.843302167472193
# 	Validation Ux MSE = 4.065141994670286
# 	Validation Uy MSE = 0.7191193014888441
# 	Validation p MSE = 1.0590408608064814
# Model saved!
# Epoch #43
# 	Train Loss = 2861918.640625
# 	Train Total MSE = 5.523380201690051
# 	Train Ux MSE = 3.85551203513632
# 	Train Uy MSE = 0.6467089750328843
# 	Train p MSE = 1.021159139736053
# 	Validation Loss = 1298392.5
# 	Validation Total MSE = 5.624525943044889
# 	Validation Ux MSE = 3.8567965491343355
# 	Validation Uy MSE = 0.7029107821189751
# 	Validation p MSE = 1.0648183467024463
# Epoch #44
# 	Train Loss = 3004429.3125
# 	Train Total MSE = 5.2979044121834
# 	Train Ux MSE = 3.6354561852991756
# 	Train Uy MSE = 0.63172280336608
# 	Train p MSE = 1.0307254481941202
# 	Validation Loss = 1314800.0625
# 	Validation Total MSE = 5.507538565942797
# 	Validation Ux MSE = 3.6872980667372883
# 	Validation Uy MSE = 0.760468731896352
# 	Validation p MSE = 1.0597718642929852
# Epoch #45
# 	Train Loss = 2930814.984375
# 	Train Total MSE = 5.156573059259976
# 	Train Ux MSE = 3.4860172549767676
# 	Train Uy MSE = 0.6471961163223311
# 	Train p MSE = 1.0233596055917769
# 	Validation Loss = 1356462.484375
# 	Validation Total MSE = 5.277615201271186
# 	Validation Ux MSE = 3.5331501071735962
# 	Validation Uy MSE = 0.6799148171634998
# 	Validation p MSE = 1.06455011852717
# Epoch #46
# 	Train Loss = 2948713.484375
# 	Train Total MSE = 4.989180829017572
# 	Train Ux MSE = 3.3779494394018768
# 	Train Uy MSE = 0.5905799365252169
# 	Train p MSE = 1.020651606707114
# 	Validation Loss = 1349510.25
# 	Validation Total MSE = 5.156492744057865
# 	Validation Ux MSE = 3.457733826718088
# 	Validation Uy MSE = 0.6377091617907508
# 	Validation p MSE = 1.0610496997833252
# Epoch #47
# 	Train Loss = 2820782.140625
# 	Train Total MSE = 4.870727450089969
# 	Train Ux MSE = 3.2892778691327953
# 	Train Uy MSE = 0.5657118916859084
# 	Train p MSE = 1.0157377122094957
# 	Validation Loss = 1209656.796875
# 	Validation Total MSE = 5.109611330193989
# 	Validation Ux MSE = 3.4297472937632416
# 	Validation Uy MSE = 0.6259400901147875
# 	Validation p MSE = 1.0539237976074218
# Model saved!
# Epoch #48
# 	Train Loss = 2731980.6875
# 	Train Total MSE = 4.738492648733601
# 	Train Ux MSE = 3.1783792923907845
# 	Train Uy MSE = 0.5494592905739654
# 	Train p MSE = 1.010654193666864
# 	Validation Loss = 1319376.4375
# 	Validation Total MSE = 5.152807720636917
# 	Validation Ux MSE = 3.49342475503178
# 	Validation Uy MSE = 0.5996161574024265
# 	Validation p MSE = 1.0597669092275328
# Epoch #49
# 	Train Loss = 3153802.59375
# 	Train Total MSE = 4.797237918953853
# 	Train Ux MSE = 3.1234962307676977
# 	Train Uy MSE = 0.6378573982083068
# 	Train p MSE = 1.035884387986653
# 	Validation Loss = 1515803.703125
# 	Validation Total MSE = 5.1248225842492054
# 	Validation Ux MSE = 3.284435931706833
# 	Validation Uy MSE = 0.761989457728499
# 	Validation p MSE = 1.0783972465385825
# Epoch #50
# 	Train Loss = 3091550.1875
# 	Train Total MSE = 4.789944729374032
# 	Train Ux MSE = 3.055630197330397
# 	Train Uy MSE = 0.6932864842539973
# 	Train p MSE = 1.0410280432715013
# 	Validation Loss = 1250684.8125
# 	Validation Total MSE = 4.804465523412672
# 	Validation Ux MSE = 3.1339358054985436
# 	Validation Uy MSE = 0.6125623218083786
# 	Validation p MSE = 1.0579674373238774
# Epoch #51
# 	Train Loss = 2792761.109375
# 	Train Total MSE = 4.718570275487427
# 	Train Ux MSE = 3.1326226548620286
# 	Train Uy MSE = 0.5596071526886075
# 	Train p MSE = 1.02634044847405
# 	Validation Loss = 1235565.4296875
# 	Validation Total MSE = 5.8853200104277015
# 	Validation Ux MSE = 4.24108059123411
# 	Validation Uy MSE = 0.5913627301232289
# 	Validation p MSE = 1.0528765722856683
# Epoch #52
# 	Train Loss = 2662912.9296875
# 	Train Total MSE = 4.770957546400954
# 	Train Ux MSE = 3.2310369174612505
# 	Train Uy MSE = 0.5286271259318983
# 	Train p MSE = 1.0112935063095203
# 	Validation Loss = 1155096.046875
# 	Validation Total MSE = 4.583347876597259
# 	Validation Ux MSE = 2.971338356147378
# 	Validation Uy MSE = 0.5619014287399033
# 	Validation p MSE = 1.0501079914933544
# Model saved!
# Epoch #53
# 	Train Loss = 2602703.34375
# 	Train Total MSE = 4.323625458920315
# 	Train Ux MSE = 2.81571082957632
# 	Train Uy MSE = 0.4999038401567554
# 	Train p MSE = 1.0080108381916413
# 	Validation Loss = 1156424.265625
# 	Validation Total MSE = 4.674478821835275
# 	Validation Ux MSE = 3.075182019249868
# 	Validation Uy MSE = 0.551042841248593
# 	Validation p MSE = 1.048253944768744
# Epoch #54
# 	Train Loss = 2581562.34375
# 	Train Total MSE = 4.4030132682956
# 	Train Ux MSE = 2.908161241181043
# 	Train Uy MSE = 0.48671508321956714
# 	Train p MSE = 1.0081369296454827
# 	Validation Loss = 1135981.9765625
# 	Validation Total MSE = 4.681712987867452
# 	Validation Ux MSE = 3.091752184851695
# 	Validation Uy MSE = 0.5446094739235053
# 	Validation p MSE = 1.045351287874125
# Model saved!
# Epoch #55
# 	Train Loss = 2663091.0
# 	Train Total MSE = 4.3975389886528
# 	Train Ux MSE = 2.901633593500877
# 	Train Uy MSE = 0.47537965329673476
# 	Train p MSE = 1.0205257036248032
# 	Validation Loss = 1134937.90625
# 	Validation Total MSE = 5.216002693822828
# 	Validation Ux MSE = 3.6267315363479873
# 	Validation Uy MSE = 0.5452838736065363
# 	Validation p MSE = 1.0439872184042203
# Model saved!
# Epoch #56
# 	Train Loss = 2544280.28125
# 	Train Total MSE = 4.535524106929323
# 	Train Ux MSE = 3.037756427731528
# 	Train Uy MSE = 0.4854503192289925
# 	Train p MSE = 1.0123173763036033
# 	Validation Loss = 1093074.6015625
# 	Validation Total MSE = 4.359581872972392
# 	Validation Ux MSE = 2.783024700617386
# 	Validation Uy MSE = 0.5336995593572067
# 	Validation p MSE = 1.0428574210506374
# Model saved!
# Epoch #57
# 	Train Loss = 2626427.28125
# 	Train Total MSE = 4.136867845718784
# 	Train Ux MSE = 2.6524202886197727
# 	Train Uy MSE = 0.4830292793474114
# 	Train p MSE = 1.0014181793952475
# 	Validation Loss = 1337979.734375
# 	Validation Total MSE = 4.804994770631952
# 	Validation Ux MSE = 3.1952820341465835
# 	Validation Uy MSE = 0.5444534075462212
# 	Validation p MSE = 1.0652592925702111
# Epoch #58
# 	Train Loss = 2705588.0
# 	Train Total MSE = 4.264277599990889
# 	Train Ux MSE = 2.773849743100714
# 	Train Uy MSE = 0.47661407904444214
# 	Train p MSE = 1.0138138244172923
# 	Validation Loss = 1153690.5546875
# 	Validation Total MSE = 4.852547441902807
# 	Validation Ux MSE = 3.2772195589744437
# 	Validation Uy MSE = 0.529659432879949
# 	Validation p MSE = 1.0456686565431499
# Epoch #59
# 	Train Loss = 2588836.484375
# 	Train Total MSE = 4.319488859037616
# 	Train Ux MSE = 2.8476986231678776
# 	Train Uy MSE = 0.4639767571718978
# 	Train p MSE = 1.0078135204037146
# 	Validation Loss = 1096502.859375
# 	Validation Total MSE = 4.463723677295749
# 	Validation Ux MSE = 2.9032412512827728
# 	Validation Uy MSE = 0.5161988468493446
# 	Validation p MSE = 1.0442834991519734
# Epoch #60
# 	Train Loss = 2567348.8828125
# 	Train Total MSE = 4.123863609469667
# 	Train Ux MSE = 2.6584255785705744
# 	Train Uy MSE = 0.4510181026625564
# 	Train p MSE = 1.0144199233708506
# 	Validation Loss = 1124000.3203125
# 	Validation Total MSE = 4.139095086566472
# 	Validation Ux MSE = 2.5778868335788534
# 	Validation Uy MSE = 0.5148515959917489
# 	Validation p MSE = 1.046356638407303
# Epoch #61
# 	Train Loss = 2539833.34375
# 	Train Total MSE = 3.950476465697886
# 	Train Ux MSE = 2.491824158426624
# 	Train Uy MSE = 0.4472755398764207
# 	Train p MSE = 1.0113767204757333
# 	Validation Loss = 1049949.8046875
# 	Validation Total MSE = 4.068959407483117
# 	Validation Ux MSE = 2.530108746027542
# 	Validation Uy MSE = 0.4978145340741691
# 	Validation p MSE = 1.0410361540519586
# Model saved!
# Epoch #62
# 	Train Loss = 2430270.3125
# 	Train Total MSE = 3.8728417265867003
# 	Train Ux MSE = 2.435964133927148
# 	Train Uy MSE = 0.44160761986112457
# 	Train p MSE = 0.9952699540307849
# 	Validation Loss = 1059459.140625
# 	Validation Total MSE = 4.13183218745862
# 	Validation Ux MSE = 2.5950959803694387
# 	Validation Uy MSE = 0.49482252476579053
# 	Validation p MSE = 1.0419137756703263
# Epoch #63
# 	Train Loss = 2662179.0234375
# 	Train Total MSE = 3.980367721691076
# 	Train Ux MSE = 2.5118327571768804
# 	Train Uy MSE = 0.4536797715345555
# 	Train p MSE = 1.0148551012267177
# 	Validation Loss = 1162656.265625
# 	Validation Total MSE = 4.0618239321951135
# 	Validation Ux MSE = 2.5160709704382946
# 	Validation Uy MSE = 0.49926312980005294
# 	Validation p MSE = 1.046489745479519
# Epoch #64
# 	Train Loss = 2474735.71875
# 	Train Total MSE = 3.750160484202749
# 	Train Ux MSE = 2.3257758471430563
# 	Train Uy MSE = 0.42562046134437137
# 	Train p MSE = 0.9987641642462061
# 	Validation Loss = 1048123.5
# 	Validation Total MSE = 3.9648037668001854
# 	Validation Ux MSE = 2.431300922975702
# 	Validation Uy MSE = 0.48883272591283766
# 	Validation p MSE = 1.0446699465735485
# Model saved!
# Epoch #65
# 	Train Loss = 2515847.15625
# 	Train Total MSE = 3.827803030653528
# 	Train Ux MSE = 2.351687261731562
# 	Train Uy MSE = 0.47309006615908433
# 	Train p MSE = 1.003025738734198
# 	Validation Loss = 1017745.5234375
# 	Validation Total MSE = 4.121062818624205
# 	Validation Ux MSE = 2.4615546533616923
# 	Validation Uy MSE = 0.6202212317515228
# 	Validation p MSE = 1.03928678076146
# Model saved!
# Epoch #66
# 	Train Loss = 2415148.1875
# 	Train Total MSE = 3.9487198142894155
# 	Train Ux MSE = 2.4485493206769315
# 	Train Uy MSE = 0.5040026183726141
# 	Train p MSE = 0.9961679527432856
# 	Validation Loss = 1140338.703125
# 	Validation Total MSE = 4.263845282085871
# 	Validation Ux MSE = 2.6912795503260725
# 	Validation Uy MSE = 0.5265878839007879
# 	Validation p MSE = 1.0459778692762731
# Epoch #67
# 	Train Loss = 2607294.234375
# 	Train Total MSE = 4.163565899818353
# 	Train Ux MSE = 2.7128764894891413
# 	Train Uy MSE = 0.4450074757500918
# 	Train p MSE = 1.0056819919246973
# 	Validation Loss = 1204867.4375
# 	Validation Total MSE = 4.202263524976828
# 	Validation Ux MSE = 2.670696245613745
# 	Validation Uy MSE = 0.48147982581187104
# 	Validation p MSE = 1.0500872725147312
# Epoch #68
# 	Train Loss = 2570533.1171875
# 	Train Total MSE = 3.849659310833011
# 	Train Ux MSE = 2.437209793847087
# 	Train Uy MSE = 0.4152495409239833
# 	Train p MSE = 0.9971999833604684
# 	Validation Loss = 1133441.734375
# 	Validation Total MSE = 3.9709128428313694
# 	Validation Ux MSE = 2.4505327644994703
# 	Validation Uy MSE = 0.46953284700038067
# 	Validation p MSE = 1.050847339630127
# Epoch #69
# 	Train Loss = 2475211.84375
# 	Train Total MSE = 3.6675349977899225
# 	Train Ux MSE = 2.264133308788778
# 	Train Uy MSE = 0.4005595560324088
# 	Train p MSE = 1.0028420617212013
# 	Validation Loss = 1103418.2578125
# 	Validation Total MSE = 4.002644968841035
# 	Validation Ux MSE = 2.491653313071041
# 	Validation Uy MSE = 0.46102962817175913
# 	Validation p MSE = 1.0499620372966185
# Epoch #70
# 	Train Loss = 2457941.8828125
# 	Train Total MSE = 3.759448159887909
# 	Train Ux MSE = 2.361069070354495
# 	Train Uy MSE = 0.3969696311839468
# 	Train p MSE = 1.0014094837205403
# 	Validation Loss = 1120667.453125
# 	Validation Total MSE = 4.198215497550318
# 	Validation Ux MSE = 2.6691255213850638
# 	Validation Uy MSE = 0.4811619548474328
# 	Validation p MSE = 1.047927795022221
# Epoch #71
# 	Train Loss = 2362245.0625
# 	Train Total MSE = 3.789293094557159
# 	Train Ux MSE = 2.3978425518069253
# 	Train Uy MSE = 0.4009864712595592
# 	Train p MSE = 0.9904640655823421
# 	Validation Loss = 1014617.3203125
# 	Validation Total MSE = 3.8197720285189356
# 	Validation Ux MSE = 2.324883955616062
# 	Validation Uy MSE = 0.4574526124081369
# 	Validation p MSE = 1.0374355857655153
# Model saved!
# Epoch #72
# 	Train Loss = 2234191.375
# 	Train Total MSE = 3.5138027758361994
# 	Train Ux MSE = 2.132801478527725
# 	Train Uy MSE = 0.39088744394285685
# 	Train p MSE = 0.9901138978518828
# 	Validation Loss = 962951.5
# 	Validation Total MSE = 3.9115095494157175
# 	Validation Ux MSE = 2.4048283463817532
# 	Validation Uy MSE = 0.4684210308527542
# 	Validation p MSE = 1.038260184304189
# Model saved!
# Epoch #73
# 	Train Loss = 2178702.3046875
# 	Train Total MSE = 3.6111721116669324
# 	Train Ux MSE = 2.1908014036128542
# 	Train Uy MSE = 0.43725480282619467
# 	Train p MSE = 0.9831158397149067
# 	Validation Loss = 979097.0703125
# 	Validation Total MSE = 4.0160768929174395
# 	Validation Ux MSE = 2.4174452442233845
# 	Validation Uy MSE = 0.5592631517830542
# 	Validation p MSE = 1.039368597935822
# Epoch #74
# 	Train Loss = 2136901.515625
# 	Train Total MSE = 3.5593538645752667
# 	Train Ux MSE = 2.1033486458024897
# 	Train Uy MSE = 0.46891251944939527
# 	Train p MSE = 0.9870925816780625
# 	Validation Loss = 949774.4453125
# 	Validation Total MSE = 3.997207770913334
# 	Validation Ux MSE = 2.467998207221597
# 	Validation Uy MSE = 0.48886724569029727
# 	Validation p MSE = 1.0403423483088865
# Model saved!
# Epoch #75
# 	Train Loss = 2294252.71875
# 	Train Total MSE = 3.4719255074815223
# 	Train Ux MSE = 2.0764665186578957
# 	Train Uy MSE = 0.40736944682396536
# 	Train p MSE = 0.9880895260124095
# 	Validation Loss = 1032712.484375
# 	Validation Total MSE = 3.6217973353499073
# 	Validation Ux MSE = 2.1368805578199486
# 	Validation Uy MSE = 0.4455377611063294
# 	Validation p MSE = 1.0393789711645094
# Epoch #76
# 	Train Loss = 2309367.40625
# 	Train Total MSE = 3.403234220454714
# 	Train Ux MSE = 2.034396658138353
# 	Train Uy MSE = 0.37867345337269953
# 	Train p MSE = 0.9901640297025007
# 	Validation Loss = 1001766.1484375
# 	Validation Total MSE = 3.676938900705111
# 	Validation Ux MSE = 2.20556307000629
# 	Validation Uy MSE = 0.43392113507804225
# 	Validation p MSE = 1.0374549324229612
# Epoch #77
# 	Train Loss = 2310136.828125
# 	Train Total MSE = 3.330981930212794
# 	Train Ux MSE = 1.9635258777496072
# 	Train Uy MSE = 0.38244435390995124
# 	Train p MSE = 0.9850117093272529
# 	Validation Loss = 1271042.28125
# 	Validation Total MSE = 3.7104961071984244
# 	Validation Ux MSE = 2.1863212197513904
# 	Validation Uy MSE = 0.4573076474464546
# 	Validation p MSE = 1.066867022595163
# Epoch #78
# 	Train Loss = 2634415.8125
# 	Train Total MSE = 3.8621363848360915
# 	Train Ux MSE = 2.4603660405551033
# 	Train Uy MSE = 0.4046647625136306
# 	Train p MSE = 0.9971055325891812
# 	Validation Loss = 1016269.25
# 	Validation Total MSE = 3.750558678578522
# 	Validation Ux MSE = 2.2359755952479476
# 	Validation Uy MSE = 0.4750599877308991
# 	Validation p MSE = 1.0395230123552226
# Epoch #79
# 	Train Loss = 2322983.25
# 	Train Total MSE = 3.3978582777017756
# 	Train Ux MSE = 2.019865030449959
# 	Train Uy MSE = 0.38253025132782603
# 	Train p MSE = 0.9954630268558469
# 	Validation Loss = 1290218.21875
# 	Validation Total MSE = 3.6719613026764435
# 	Validation Ux MSE = 2.159764952578787
# 	Validation Uy MSE = 0.44931177688857254
# 	Validation p MSE = 1.0628846467551538
# Epoch #80
# 	Train Loss = 2609804.609375
# 	Train Total MSE = 3.3686919698909836
# 	Train Ux MSE = 1.9886600616721997
# 	Train Uy MSE = 0.3691053557326425
# 	Train p MSE = 1.0109266150449525
# 	Validation Loss = 1134874.09375
# 	Validation Total MSE = 3.603232975329383
# 	Validation Ux MSE = 2.1474860110525356
# 	Validation Uy MSE = 0.4084703510090456
# 	Validation p MSE = 1.0472766585269218
# Epoch #81
# 	Train Loss = 2303143.921875
# 	Train Total MSE = 3.25055045080602
# 	Train Ux MSE = 1.909174371391274
# 	Train Uy MSE = 0.3521973176183228
# 	Train p MSE = 0.9891787120969233
# 	Validation Loss = 973335.15625
# 	Validation Total MSE = 3.476705673993644
# 	Validation Ux MSE = 2.0101866770598846
# 	Validation Uy MSE = 0.431001113632978
# 	Validation p MSE = 1.035517842082654
# Epoch #82
# 	Train Loss = 2168601.4609375
# 	Train Total MSE = 3.3484465929926657
# 	Train Ux MSE = 1.9909269260595561
# 	Train Uy MSE = 0.3722916956198111
# 	Train p MSE = 0.9852280507282335
# 	Validation Loss = 1209892.6875
# 	Validation Total MSE = 4.858900012000133
# 	Validation Ux MSE = 3.259790504584878
# 	Validation Uy MSE = 0.5399818582049871
# 	Validation p MSE = 1.059127452818014
# Epoch #83
# 	Train Loss = 2245750.296875
# 	Train Total MSE = 3.435686517387368
# 	Train Ux MSE = 2.072109088953313
# 	Train Uy MSE = 0.37691912220101315
# 	Train p MSE = 0.9866582709568235
# 	Validation Loss = 969734.375
# 	Validation Total MSE = 3.5280294903254106
# 	Validation Ux MSE = 2.0718708878856593
# 	Validation Uy MSE = 0.41734388319112486
# 	Validation p MSE = 1.0388147806717178
# Epoch #84
# 	Train Loss = 2078424.5078125
# 	Train Total MSE = 3.144749866630176
# 	Train Ux MSE = 1.8093438774086643
# 	Train Uy MSE = 0.35906901512479644
# 	Train p MSE = 0.9763369144920705
# 	Validation Loss = 947552.25
# 	Validation Total MSE = 3.5447662353515623
# 	Validation Ux MSE = 2.071084206791247
# 	Validation Uy MSE = 0.4363802150144415
# 	Validation p MSE = 1.0373017484858884
# Model saved!
# Epoch #85
# 	Train Loss = 2197162.5390625
# 	Train Total MSE = 3.1394723163749316
# 	Train Ux MSE = 1.7981555037873826
# 	Train Uy MSE = 0.36032444951138065
# 	Train p MSE = 0.98099226993305
# 	Validation Loss = 1065494.0390625
# 	Validation Total MSE = 3.6123145410570046
# 	Validation Ux MSE = 2.1333387213238213
# 	Validation Uy MSE = 0.4319291842185845
# 	Validation p MSE = 1.0470466840065131
# Epoch #86
# 	Train Loss = 2144465.8203125
# 	Train Total MSE = 3.1143686833951634
# 	Train Ux MSE = 1.7906125238268438
# 	Train Uy MSE = 0.34973154123600997
# 	Train p MSE = 0.9740246468313234
# 	Validation Loss = 1036534.640625
# 	Validation Total MSE = 3.303174655720339
# 	Validation Ux MSE = 1.8534310292389433
# 	Validation Uy MSE = 0.40773331270379537
# 	Validation p MSE = 1.042010575633938
# Epoch #87
# 	Train Loss = 2265741.5
# 	Train Total MSE = 3.1108682593520807
# 	Train Ux MSE = 1.772692410660902
# 	Train Uy MSE = 0.36206036614954645
# 	Train p MSE = 0.9761154523048734
# 	Validation Loss = 918697.7890625
# 	Validation Total MSE = 3.5247100054207494
# 	Validation Ux MSE = 1.9930877168299788
# 	Validation Uy MSE = 0.497247689457263
# 	Validation p MSE = 1.0343747098567122
# Model saved!
# Epoch #88
# 	Train Loss = 2113192.9921875
# 	Train Total MSE = 3.1294057862751687
# 	Train Ux MSE = 1.7684455626907571
# 	Train Uy MSE = 0.37624854040562933
# 	Train p MSE = 0.9847117156746089
# 	Validation Loss = 882013.125
# 	Validation Total MSE = 3.3601662328687767
# 	Validation Ux MSE = 1.8959339465125133
# 	Validation Uy MSE = 0.4298295813091731
# 	Validation p MSE = 1.0344027377791325
# Model saved!
# Epoch #89
# 	Train Loss = 2314753.171875
# 	Train Total MSE = 3.2312298877593726
# 	Train Ux MSE = 1.9085915457055451
# 	Train Uy MSE = 0.35156323124298894
# 	Train p MSE = 0.9710751483461252
# 	Validation Loss = 1094213.78125
# 	Validation Total MSE = 3.6901127443475237
# 	Validation Ux MSE = 2.2418243408203127
# 	Validation Uy MSE = 0.404703625177933
# 	Validation p MSE = 1.043584755315619
# Epoch #90
# 	Train Loss = 2022197.578125
# 	Train Total MSE = 3.097025712794535
# 	Train Ux MSE = 1.7764538022589058
# 	Train Uy MSE = 0.3440023330488288
# 	Train p MSE = 0.9765694077091384
# 	Validation Loss = 857735.25
# 	Validation Total MSE = 3.246022085416115
# 	Validation Ux MSE = 1.7988758927684718
# 	Validation Uy MSE = 0.4144473997213073
# 	Validation p MSE = 1.0326986072427136
# Model saved!
# Epoch #91
# 	Train Loss = 1933691.890625
# 	Train Total MSE = 2.9038923947526136
# 	Train Ux MSE = 1.5909434727260046
# 	Train Uy MSE = 0.3337235297823091
# 	Train p MSE = 0.9792254238712544
# 	Validation Loss = 841262.57421875
# 	Validation Total MSE = 3.0807365029545153
# 	Validation Ux MSE = 1.6650135751497948
# 	Validation Uy MSE = 0.38529884532346564
# 	Validation p MSE = 1.030424103494418
# Model saved!
# Epoch #92
# 	Train Loss = 2258256.1484375
# 	Train Total MSE = 3.0858404309687044
# 	Train Ux MSE = 1.7905960694693963
# 	Train Uy MSE = 0.32529047557285856
# 	Train p MSE = 0.9699540084374542
# 	Validation Loss = 1207890.546875
# 	Validation Total MSE = 5.259047427419889
# 	Validation Ux MSE = 3.728357243942002
# 	Validation Uy MSE = 0.4848950660834878
# 	Validation p MSE = 1.045795065265591
# Epoch #93
# 	Train Loss = 2315088.015625
# 	Train Total MSE = 3.8017566002492655
# 	Train Ux MSE = 2.470441256598203
# 	Train Uy MSE = 0.3411006232392336
# 	Train p MSE = 0.9902147638554476
# 	Validation Loss = 958860.9765625
# 	Validation Total MSE = 3.2767228078033965
# 	Validation Ux MSE = 1.8516193325236692
# 	Validation Uy MSE = 0.3887920767573987
# 	Validation p MSE = 1.03631142600108
# Epoch #94
# 	Train Loss = 1998053.7734375
# 	Train Total MSE = 3.094751997522293
# 	Train Ux MSE = 1.7961916965228824
# 	Train Uy MSE = 0.32978862923713886
# 	Train p MSE = 0.9687716378762493
# 	Validation Loss = 936990.5625
# 	Validation Total MSE = 3.5395195395259536
# 	Validation Ux MSE = 2.097660711256124
# 	Validation Uy MSE = 0.4042180724063162
# 	Validation p MSE = 1.037640737679045
# Epoch #95
# 	Train Loss = 1882895.8984375
# 	Train Total MSE = 2.9264330516403687
# 	Train Ux MSE = 1.6513515394561145
# 	Train Uy MSE = 0.3149769007290765
# 	Train p MSE = 0.9601046528135028
# 	Validation Loss = 853725.6796875
# 	Validation Total MSE = 3.194473292463917
# 	Validation Ux MSE = 1.7750853974940413
# 	Validation Uy MSE = 0.3886658167434951
# 	Validation p MSE = 1.0307218878956164
# Epoch #96
# 	Train Loss = 1872728.5625
# 	Train Total MSE = 2.7681500515506845
# 	Train Ux MSE = 1.4876766872127967
# 	Train Uy MSE = 0.30692602246565304
# 	Train p MSE = 0.9735473321408642
# 	Validation Loss = 838637.8515625
# 	Validation Total MSE = 3.0409555208885064
# 	Validation Ux MSE = 1.652075647903701
# 	Validation Uy MSE = 0.3587952048091565
# 	Validation p MSE = 1.0300845267408985
# Model saved!
# Epoch #97
# 	Train Loss = 1860175.953125
# 	Train Total MSE = 2.6884631943772206
# 	Train Ux MSE = 1.4301714438391149
# 	Train Uy MSE = 0.29269238741682846
# 	Train p MSE = 0.965599375806814
# 	Validation Loss = 774365.67578125
# 	Validation Total MSE = 2.9494222350039725
# 	Validation Ux MSE = 1.5620749909999008
# 	Validation Uy MSE = 0.3619874792583918
# 	Validation p MSE = 1.0253597651497792
# Model saved!
# Epoch #98
# 	Train Loss = 2028480.6015625
# 	Train Total MSE = 2.7420021702179755
# 	Train Ux MSE = 1.4850109422867221
# 	Train Uy MSE = 0.30031590002966346
# 	Train p MSE = 0.9566753610925146
# 	Validation Loss = 955930.078125
# 	Validation Total MSE = 3.223566294524629
# 	Validation Ux MSE = 1.8203027628235897
# 	Validation Uy MSE = 0.36983130180229573
# 	Validation p MSE = 1.033432231515141
# Epoch #99
# 	Train Loss = 2089358.671875
# 	Train Total MSE = 2.776736712664279
# 	Train Ux MSE = 1.5192959009732172
# 	Train Uy MSE = 0.2876400447100314
# 	Train p MSE = 0.9698008213724408
# 	Validation Loss = 849671.4609375
# 	Validation Total MSE = 2.9831810773429224
# 	Validation Ux MSE = 1.6037010322182865
# 	Validation Uy MSE = 0.3526745812367585
# 	Validation p MSE = 1.0268055713782875
# Epoch #100
# 	Train Loss = 1883343.359375
# 	Train Total MSE = 2.7062388828822543
# 	Train Ux MSE = 1.453567699510224
# 	Train Uy MSE = 0.2893908837098769
# 	Train p MSE = 0.9632803747327265
# 	Validation Loss = 802675.84375
# 	Validation Total MSE = 2.9753155336541646
# 	Validation Ux MSE = 1.599943413168697
# 	Validation Uy MSE = 0.3493585182448565
# 	Validation p MSE = 1.0260134478746834
# Epoch #101
# 	Train Loss = 1923686.3984375
# 	Train Total MSE = 2.6752411978585378
# 	Train Ux MSE = 1.4201507623967207
# 	Train Uy MSE = 0.2905250089161598
# 	Train p MSE = 0.9645653846660092
# 	Validation Loss = 887345.546875
# 	Validation Total MSE = 2.9815022355419094
# 	Validation Ux MSE = 1.5805679579912606
# 	Validation Uy MSE = 0.367972425687111
# 	Validation p MSE = 1.0329620240098338
# Epoch #102
# 	Train Loss = 2103739.359375
# 	Train Total MSE = 3.038901448597366
# 	Train Ux MSE = 1.765549284376139
# 	Train Uy MSE = 0.3044799632303221
# 	Train p MSE = 0.9688722671989797
# 	Validation Loss = 951264.25
# 	Validation Total MSE = 3.4585949396683
# 	Validation Ux MSE = 2.0544022640939485
# 	Validation Uy MSE = 0.3715903298329499
# 	Validation p MSE = 1.0326021893549773
# Epoch #103
# 	Train Loss = 1764748.9765625
# 	Train Total MSE = 2.728273041394292
# 	Train Ux MSE = 1.490964016483407
# 	Train Uy MSE = 0.27690846579415457
# 	Train p MSE = 0.960400634013529
# 	Validation Loss = 776322.8984375
# 	Validation Total MSE = 3.0318202907756224
# 	Validation Ux MSE = 1.6565167960474048
# 	Validation Uy MSE = 0.34810911598852123
# 	Validation p MSE = 1.0271943500486471
# Epoch #104
# 	Train Loss = 1817809.703125
# 	Train Total MSE = 2.645436790177148
# 	Train Ux MSE = 1.4096048149353562
# 	Train Uy MSE = 0.27636923386821244
# 	Train p MSE = 0.9594626744704066
# 	Validation Loss = 999638.3125
# 	Validation Total MSE = 3.562340196512513
# 	Validation Ux MSE = 2.1148104910123147
# 	Validation Uy MSE = 0.41140972072795284
# 	Validation p MSE = 1.0361199742656644
# Epoch #105
# 	Train Loss = 1928498.4765625
# 	Train Total MSE = 2.77357152599635
# 	Train Ux MSE = 1.5133539539036875
# 	Train Uy MSE = 0.2966214964063105
# 	Train p MSE = 0.9635960084356302
# 	Validation Loss = 993528.9296875
# 	Validation Total MSE = 3.171312390343618
# 	Validation Ux MSE = 1.7636037794210142
# 	Validation Uy MSE = 0.36982138197300796
# 	Validation p MSE = 1.0378872382438789
# Epoch #106
# 	Train Loss = 2095169.5
# 	Train Total MSE = 2.7731277643765373
# 	Train Ux MSE = 1.4608768040515243
# 	Train Uy MSE = 0.3507044113759744
# 	Train p MSE = 0.9615466125504963
# 	Validation Loss = 1014836.078125
# 	Validation Total MSE = 3.195536687818624
# 	Validation Ux MSE = 1.6869795071876654
# 	Validation Uy MSE = 0.4684057429685431
# 	Validation p MSE = 1.0401514744354508
# Epoch #107
# 	Train Loss = 2090874.0234375
# 	Train Total MSE = 2.849039439209696
# 	Train Ux MSE = 1.5530858276189243
# 	Train Uy MSE = 0.32474936410219957
# 	Train p MSE = 0.9712042514853853
# 	Validation Loss = 1053634.03125
# 	Validation Total MSE = 3.122212568380065
# 	Validation Ux MSE = 1.7203790179753709
# 	Validation Uy MSE = 0.367246802378509
# 	Validation p MSE = 1.034586719739235
# Epoch #108
# 	Train Loss = 2074305.2265625
# 	Train Total MSE = 2.783803111262641
# 	Train Ux MSE = 1.5324839600321156
# 	Train Uy MSE = 0.2806964511426475
# 	Train p MSE = 0.9706226783660689
# 	Validation Loss = 1034519.25
# 	Validation Total MSE = 3.0717265888796015
# 	Validation Ux MSE = 1.6924065541412872
# 	Validation Uy MSE = 0.3393946890103615
# 	Validation p MSE = 1.039925226114564
# Epoch #109
# 	Train Loss = 1950437.3515625
# 	Train Total MSE = 2.6256994019444413
# 	Train Ux MSE = 1.3941645497135797
# 	Train Uy MSE = 0.2637914777149612
# 	Train p MSE = 0.9677433524465422
# 	Validation Loss = 1089776.25
# 	Validation Total MSE = 3.319929504394531
# 	Validation Ux MSE = 1.8982518858828787
# 	Validation Uy MSE = 0.37840251276048564
# 	Validation p MSE = 1.0432751138331526
# Epoch #110
# 	Train Loss = 2053850.0078125
# 	Train Total MSE = 2.629141754728712
# 	Train Ux MSE = 1.393037323353937
# 	Train Uy MSE = 0.27043173264484016
# 	Train p MSE = 0.9656726737064105
# 	Validation Loss = 1036327.390625
# 	Validation Total MSE = 3.421030387231859
# 	Validation Ux MSE = 2.004710569220074
# 	Validation Uy MSE = 0.3751743122682733
# 	Validation p MSE = 1.0411455223115824
# Epoch #111
# 	Train Loss = 1923480.59375
# 	Train Total MSE = 2.573012593883815
# 	Train Ux MSE = 1.351949691772461
# 	Train Uy MSE = 0.267295138828956
# 	Train p MSE = 0.9537677306996838
# 	Validation Loss = 847841.7890625
# 	Validation Total MSE = 2.834484333102986
# 	Validation Ux MSE = 1.4798757908707958
# 	Validation Uy MSE = 0.3226719064227605
# 	Validation p MSE = 1.0319365133673457
# Epoch #112
# 	Train Loss = 1643743.85546875
# 	Train Total MSE = 2.4241949476236506
# 	Train Ux MSE = 1.210046184306242
# 	Train Uy MSE = 0.26393118544153155
# 	Train p MSE = 0.9502176306164299
# 	Validation Loss = 753520.3828125
# 	Validation Total MSE = 2.8593348616260594
# 	Validation Ux MSE = 1.4545294292902542
# 	Validation Uy MSE = 0.37909812603966664
# 	Validation p MSE = 1.025707123037112
# Model saved!
# Epoch #113
# 	Train Loss = 1645235.7265625
# 	Train Total MSE = 2.4072244494023893
# 	Train Ux MSE = 1.1840874585743897
# 	Train Uy MSE = 0.26796666804277514
# 	Train p MSE = 0.9551703857784716
# 	Validation Loss = 754681.86328125
# 	Validation Total MSE = 2.7055796348442467
# 	Validation Ux MSE = 1.368082609014996
# 	Validation Uy MSE = 0.3143958172555697
# 	Validation p MSE = 1.0231011604858657
# Epoch #114
# 	Train Loss = 1810642.8984375
# 	Train Total MSE = 2.4587570779872707
# 	Train Ux MSE = 1.2456722926815467
# 	Train Uy MSE = 0.2536355733176362
# 	Train p MSE = 0.9594492687254536
# 	Validation Loss = 1121207.8671875
# 	Validation Total MSE = 3.468295857057733
# 	Validation Ux MSE = 2.033461308883408
# 	Validation Uy MSE = 0.3897321086818889
# 	Validation p MSE = 1.0451024544441094
# Epoch #115
# 	Train Loss = 1870550.4765625
# 	Train Total MSE = 2.768343188672302
# 	Train Ux MSE = 1.5403971991803138
# 	Train Uy MSE = 0.27057286045641665
# 	Train p MSE = 0.9573731516262532
# 	Validation Loss = 820002.1640625
# 	Validation Total MSE = 2.917630806615797
# 	Validation Ux MSE = 1.559834651623742
# 	Validation Uy MSE = 0.33304376440533134
# 	Validation p MSE = 1.0247523239103413
# Epoch #116
# 	Train Loss = 1781249.796875
# 	Train Total MSE = 2.613205956995661
# 	Train Ux MSE = 1.3920389848269805
# 	Train Uy MSE = 0.2608684860930151
# 	Train p MSE = 0.9602983708631888
# 	Validation Loss = 892958.4296875
# 	Validation Total MSE = 2.956153080827099
# 	Validation Ux MSE = 1.5975752749685515
# 	Validation Uy MSE = 0.33009683802976447
# 	Validation p MSE = 1.0284810571347254
# Epoch #117
# 	Train Loss = 1872979.328125
# 	Train Total MSE = 2.5288691061926305
# 	Train Ux MSE = 1.3222765130134784
# 	Train Uy MSE = 0.25351707302794163
# 	Train p MSE = 0.9530754856569774
# 	Validation Loss = 799771.296875
# 	Validation Total MSE = 2.8940155029296877
# 	Validation Ux MSE = 1.5619704941571768
# 	Validation Uy MSE = 0.3069333642216052
# 	Validation p MSE = 1.0251115675699913
# Epoch #118
# 	Train Loss = 1953601.01953125
# 	Train Total MSE = 2.661673809974604
# 	Train Ux MSE = 1.4467839277172923
# 	Train Uy MSE = 0.2484303007320482
# 	Train p MSE = 0.9664595101039541
# 	Validation Loss = 870436.203125
# 	Validation Total MSE = 3.081159740383342
# 	Validation Ux MSE = 1.739620557882018
# 	Validation Uy MSE = 0.31431833525835456
# 	Validation p MSE = 1.0272210278753506
# Epoch #119
# 	Train Loss = 1679968.7421875
# 	Train Total MSE = 2.480653773938949
# 	Train Ux MSE = 1.2901708975477746
# 	Train Uy MSE = 0.23727451538553043
# 	Train p MSE = 0.9532082816775964
# 	Validation Loss = 870986.375
# 	Validation Total MSE = 2.8967525934768936
# 	Validation Ux MSE = 1.5558438058626853
# 	Validation Uy MSE = 0.3139750125044483
# 	Validation p MSE = 1.026933866234149
# Epoch #120
# 	Train Loss = 1865701.796875
# 	Train Total MSE = 2.428274154663086
# 	Train Ux MSE = 1.2329728262765067
# 	Train Uy MSE = 0.2382683809575117
# 	Train p MSE = 0.9570329184087303
# 	Validation Loss = 735964.578125
# 	Validation Total MSE = 2.669534793142545
# 	Validation Ux MSE = 1.3392468209994042
# 	Validation Uy MSE = 0.30780658883563544
# 	Validation p MSE = 1.0224814216969378
# Model saved!
# Epoch #121
# 	Train Loss = 1664731.5078125
# 	Train Total MSE = 2.3536626076211733
# 	Train Ux MSE = 1.1695532284394645
# 	Train Uy MSE = 0.23254233546576764
# 	Train p MSE = 0.9515669581320126
# 	Validation Loss = 806335.59375
# 	Validation Total MSE = 2.760274027161679
# 	Validation Ux MSE = 1.422553408347954
# 	Validation Uy MSE = 0.3108872947046312
# 	Validation p MSE = 1.0268333515878452
# Epoch #122
# 	Train Loss = 1981527.828125
# 	Train Total MSE = 2.542001740925514
# 	Train Ux MSE = 1.3452215667368719
# 	Train Uy MSE = 0.23771273220940858
# 	Train p MSE = 0.9590675161809338
# 	Validation Loss = 809543.96875
# 	Validation Total MSE = 2.918828156034825
# 	Validation Ux MSE = 1.5938088109937765
# 	Validation Uy MSE = 0.300423437862073
# 	Validation p MSE = 1.0245957221015025
# Epoch #123
# 	Train Loss = 1718181.09375
# 	Train Total MSE = 2.446189379900607
# 	Train Ux MSE = 1.2682759198781006
# 	Train Uy MSE = 0.2317645904274098
# 	Train p MSE = 0.9461487681108035
# 	Validation Loss = 749427.421875
# 	Validation Total MSE = 2.7326831494347523
# 	Validation Ux MSE = 1.399860899327165
# 	Validation Uy MSE = 0.30915267103809424
# 	Validation p MSE = 1.023669702117726
# Epoch #124
# 	Train Loss = 1813676.1640625
# 	Train Total MSE = 2.4393578965879392
# 	Train Ux MSE = 1.240806585150627
# 	Train Uy MSE = 0.23682355324658985
# 	Train p MSE = 0.961727793988264
# 	Validation Loss = 1063821.09375
# 	Validation Total MSE = 2.7217574038748014
# 	Validation Ux MSE = 1.3827775082345737
# 	Validation Uy MSE = 0.3019419783252781
# 	Validation p MSE = 1.0370378203311208
# Epoch #125
# 	Train Loss = 1894578.46875
# 	Train Total MSE = 2.4437261420158185
# 	Train Ux MSE = 1.2441881530138912
# 	Train Uy MSE = 0.24510933289374973
# 	Train p MSE = 0.954428625784532
# 	Validation Loss = 821358.75
# 	Validation Total MSE = 2.9528353674937105
# 	Validation Ux MSE = 1.6016979928744042
# 	Validation Uy MSE = 0.32672617960784395
# 	Validation p MSE = 1.0244112586571
# Epoch #126
# 	Train Loss = 1602156.7734375
# 	Train Total MSE = 2.3576963663796295
# 	Train Ux MSE = 1.1739265953486584
# 	Train Uy MSE = 0.2380624116335944
# 	Train p MSE = 0.9457073876357287
# 	Validation Loss = 711029.59375
# 	Validation Total MSE = 2.687607458082296
# 	Validation Ux MSE = 1.368973722296246
# 	Validation Uy MSE = 0.2982190471584514
# 	Validation p MSE = 1.020414510015714
# Model saved!
# Epoch #127
# 	Train Loss = 1563759.453125
# 	Train Total MSE = 2.2835128661842456
# 	Train Ux MSE = 1.1076222022142772
# 	Train Uy MSE = 0.22956442624417409
# 	Train p MSE = 0.9463262332076582
# 	Validation Loss = 699824.0
# 	Validation Total MSE = 2.6896230923927438
# ...
# 	Validation p MSE = 1.0297914282750276
# Epoch #259
# 	Train Loss = 1433247.03515625
# 	Train Total MSE = 1.7673235412241766
# 	Train Ux MSE = 0.7029221565313312
# 	Train Uy MSE = 0.1485019366178151
# 	Train p MSE = 0.9158994024592307
# 	Validation Loss = 661515.375
# 	Validation Total MSE = 2.3330122349625926
# 	Validation Ux MSE = 1.0432814581919525
# 	Validation Uy MSE = 0.27208725072569767
# 	Validation p MSE = 1.0176434632075035
# Epoch #260
# 	Train Loss = 1190160.0703125
# 	Train Total MSE = 1.6407474762496725
# 	Train Ux MSE = 0.5931121114391628
# 	Train Uy MSE = 0.1410107327619725
# 	Train p MSE = 0.9066246025068767
# 	Validation Loss = 614207.66015625
# 	Validation Total MSE = 2.245800302796445
# 	Validation Ux MSE = 0.9791568368168201
# 	Validation Uy MSE = 0.2514344069917323
# 	Validation p MSE = 1.0152089856438717
# Epoch #261
# 	Train Loss = 1251387.7421875
# 	Train Total MSE = 1.5997465539604165
# 	Train Ux MSE = 0.5762681571804747
# 	Train Uy MSE = 0.11679983208547876
# 	Train p MSE = 0.90667855409422
# 	Validation Loss = 681206.328125
# 	Validation Total MSE = 2.271894603664592
# 	Validation Ux MSE = 0.9993922023449914
# 	Validation Uy MSE = 0.25449990417997714
# 	Validation p MSE = 1.018002542802843
# Epoch #262
# 	Train Loss = 1334583.8046875
# 	Train Total MSE = 1.6134415451361208
# 	Train Ux MSE = 0.5830760460900843
# 	Train Uy MSE = 0.11908238552749678
# 	Train p MSE = 0.9112831284631445
# 	Validation Loss = 630201.6484375
# 	Validation Total MSE = 2.2066406637935314
# 	Validation Ux MSE = 0.9480264696024232
# 	Validation Uy MSE = 0.24426531225948012
# 	Validation p MSE = 1.014348938707578
# Epoch #263
# 	Train Loss = 1299287.2265625
# 	Train Total MSE = 1.5989120083022048
# 	Train Ux MSE = 0.5763026201342702
# 	Train Uy MSE = 0.1199214972838021
# 	Train p MSE = 0.9026878661647135
# 	Validation Loss = 789988.2734375
# 	Validation Total MSE = 2.3528366864737817
# 	Validation Ux MSE = 1.0857200557902709
# 	Validation Uy MSE = 0.2470508971456754
# 	Validation p MSE = 1.020065817186388
# Epoch #264
# 	Train Loss = 1407849.4296875
# 	Train Total MSE = 1.6380818286373038
# 	Train Ux MSE = 0.6180137072638242
# 	Train Uy MSE = 0.10871754026273944
# 	Train p MSE = 0.9113506232510503
# 	Validation Loss = 704495.7578125
# 	Validation Total MSE = 2.24431015273272
# 	Validation Ux MSE = 0.9899811631542141
# 	Validation Uy MSE = 0.23621070425389176
# 	Validation p MSE = 1.0181182034945084
# Epoch #265
# 	Train Loss = 1438965.89453125
# 	Train Total MSE = 1.6628719947080919
# 	Train Ux MSE = 0.631031987270878
# 	Train Uy MSE = 0.12433285268333145
# 	Train p MSE = 0.9075071534071302
# 	Validation Loss = 610874.56640625
# 	Validation Total MSE = 2.2918790073718056
# 	Validation Ux MSE = 1.0247356220827264
# 	Validation Uy MSE = 0.2530020835035938
# 	Validation p MSE = 1.0141412876420102
# Epoch #266
# 	Train Loss = 1423056.3515625
# 	Train Total MSE = 1.6888356806585463
# 	Train Ux MSE = 0.638818649091804
# 	Train Uy MSE = 0.13772867650401835
# 	Train p MSE = 0.9122884220527838
# 	Validation Loss = 701462.7265625
# 	Validation Total MSE = 2.4231644905219643
# 	Validation Ux MSE = 1.1458955021227821
# 	Validation Uy MSE = 0.2602256483950857
# 	Validation p MSE = 1.0170433248503734
# Epoch #267
# 	Train Loss = 1366334.546875
# 	Train Total MSE = 1.6798915251350959
# 	Train Ux MSE = 0.6319672220302393
# 	Train Uy MSE = 0.13808131356976122
# 	Train p MSE = 0.9098430033936097
# 	Validation Loss = 692479.734375
# 	Validation Total MSE = 2.2735077680167506
# 	Validation Ux MSE = 1.000713160886603
# 	Validation Uy MSE = 0.2535792528572729
# 	Validation p MSE = 1.0192153284105203
# Epoch #268
# 	Train Loss = 1380905.48046875
# 	Train Total MSE = 1.6374280334561628
# 	Train Ux MSE = 0.5914233877777011
# 	Train Uy MSE = 0.13495732187877243
# 	Train p MSE = 0.9110474452680472
# 	Validation Loss = 607526.95703125
# 	Validation Total MSE = 2.19783432524083
# 	Validation Ux MSE = 0.9432202613959878
# 	Validation Uy MSE = 0.24327258578801558
# 	Validation p MSE = 1.0113414572457136
# Epoch #269
# 	Train Loss = 1240562.0859375
# 	Train Total MSE = 1.5812814562383268
# 	Train Ux MSE = 0.5527888122869997
# 	Train Uy MSE = 0.12493816061548171
# 	Train p MSE = 0.9035545408117528
# 	Validation Loss = 668508.43359375
# 	Validation Total MSE = 2.255248396275407
# 	Validation Ux MSE = 0.9803559125480005
# 	Validation Uy MSE = 0.2600309194144556
# 	Validation p MSE = 1.0148615978531919
# Epoch #270
# 	Train Loss = 1336046.859375
# 	Train Total MSE = 1.5523814571147063
# 	Train Ux MSE = 0.5446318495725404
# 	Train Uy MSE = 0.10459414272197134
# 	Train p MSE = 0.9031554200732673
# 	Validation Loss = 619330.84375
# 	Validation Total MSE = 2.209700387211169
# 	Validation Ux MSE = 0.9490111658128642
# 	Validation Uy MSE = 0.24696189589419607
# 	Validation p MSE = 1.0137273426783286
# Epoch #271
# 	Train Loss = 1219633.546875
# 	Train Total MSE = 1.560441937460496
# 	Train Ux MSE = 0.5641370917895793
# 	Train Uy MSE = 0.09926330591429774
# 	Train p MSE = 0.8970415031770923
# 	Validation Loss = 612603.19921875
# 	Validation Total MSE = 2.2984576597052104
# 	Validation Ux MSE = 1.0455961453712592
# 	Validation Uy MSE = 0.24002892445709745
# 	Validation p MSE = 1.0128325815928185
# Epoch #272
# 	Train Loss = 1172827.65625
# 	Train Total MSE = 1.5880013846794996
# 	Train Ux MSE = 0.5917546325105272
# 	Train Uy MSE = 0.10012903957255728
# 	Train p MSE = 0.8961177456135653
# 	Validation Loss = 585875.36328125
# 	Validation Total MSE = 2.2758359488794357
# 	Validation Ux MSE = 1.0226849701444982
# 	Validation Uy MSE = 0.24027189157776913
# 	Validation p MSE = 1.0128790986739984
# Model saved!
# Epoch #273
# 	Train Loss = 1146733.70703125
# 	Train Total MSE = 1.5609190137323763
# 	Train Ux MSE = 0.5724978933528978
# 	Train Uy MSE = 0.09912793247067199
# 	Train p MSE = 0.8892931692280506
# 	Validation Loss = 599775.7109375
# 	Validation Total MSE = 2.2428936715853416
# 	Validation Ux MSE = 0.9882310834981627
# 	Validation Uy MSE = 0.2399995254257978
# 	Validation p MSE = 1.0146630369000516
# Epoch #274
# 	Train Loss = 1475562.703125
# 	Train Total MSE = 1.5799557238209003
# 	Train Ux MSE = 0.5798676298936671
# 	Train Uy MSE = 0.10966464416626244
# 	Train p MSE = 0.8904234960284247
# 	Validation Loss = 689833.859375
# 	Validation Total MSE = 2.320280307834431
# 	Validation Ux MSE = 1.0716097686250332
# 	Validation Uy MSE = 0.2338715868481135
# 	Validation p MSE = 1.0147988993232533
# Epoch #275
# 	Train Loss = 1312014.2109375
# 	Train Total MSE = 1.6127789945018536
# 	Train Ux MSE = 0.6042765292064789
# 	Train Uy MSE = 0.11697540582095221
# 	Train p MSE = 0.8915270946203099
# 	Validation Loss = 654405.1875
# 	Validation Total MSE = 2.22539766602597
# 	Validation Ux MSE = 0.9714441073142877
# 	Validation Uy MSE = 0.23983126414024225
# 	Validation p MSE = 1.0141224032741483
# Epoch #276
# 	Train Loss = 1209320.21484375
# 	Train Total MSE = 1.579836464484301
# 	Train Ux MSE = 0.5690437127827903
# 	Train Uy MSE = 0.1183928480648786
# 	Train p MSE = 0.8923999796629647
# 	Validation Loss = 580814.89453125
# 	Validation Total MSE = 2.196461583800235
# 	Validation Ux MSE = 0.9493736525713388
# 	Validation Uy MSE = 0.23406071339623402
# 	Validation p MSE = 1.0130272928941049
# Model saved!
# Epoch #277
# 	Train Loss = 1154921.4609375
# 	Train Total MSE = 1.5530429734433011
# 	Train Ux MSE = 0.5626006668580169
# 	Train Uy MSE = 0.10318460235095232
# 	Train p MSE = 0.8872577091869043
# 	Validation Loss = 584916.50390625
# 	Validation Total MSE = 2.198090349617651
# 	Validation Ux MSE = 0.9388402647891287
# 	Validation Uy MSE = 0.24615029157218288
# 	Validation p MSE = 1.013099803156772
# Epoch #278
# 	Train Loss = 1186770.00390625
# 	Train Total MSE = 1.5148588603161515
# 	Train Ux MSE = 0.5304942283964018
# 	Train Uy MSE = 0.10264213926243017
# 	Train p MSE = 0.8817224834907159
# 	Validation Loss = 656582.94140625
# 	Validation Total MSE = 2.2021872956874007
# 	Validation Ux MSE = 0.9528321605617717
# 	Validation Uy MSE = 0.23147487802020575
# 	Validation p MSE = 1.017880229424622
# Epoch #279
# 	Train Loss = 1173245.6953125
# 	Train Total MSE = 1.5192041814153465
# 	Train Ux MSE = 0.534220698275997
# 	Train Uy MSE = 0.09325696845096332
# 	Train p MSE = 0.8917264320586236
# 	Validation Loss = 583921.0703125
# 	Validation Total MSE = 2.2060223918850137
# 	Validation Ux MSE = 0.961230501077943
# 	Validation Uy MSE = 0.22987605191893495
# 	Validation p MSE = 1.0149156932103431
# Epoch #280
# 	Train Loss = 1191472.125
# 	Train Total MSE = 1.5138296650032956
# 	Train Ux MSE = 0.5391012419764571
# 	Train Uy MSE = 0.09864794234840238
# 	Train p MSE = 0.8760804189884975
# 	Validation Loss = 587014.90234375
# 	Validation Total MSE = 2.177346840551344
# 	Validation Ux MSE = 0.9263031587762348
# 	Validation Uy MSE = 0.23588676695096292
# 	Validation p MSE = 1.0151568928007353
# Epoch #281
# 	Train Loss = 1184167.08984375
# 	Train Total MSE = 1.5352285262794605
# 	Train Ux MSE = 0.5600031972279006
# 	Train Uy MSE = 0.10019266640132092
# 	Train p MSE = 0.875032655351711
# 	Validation Loss = 594469.4921875
# 	Validation Total MSE = 2.2296428745075807
# 	Validation Ux MSE = 0.9810833688509666
# 	Validation Uy MSE = 0.23426123635243562
# 	Validation p MSE = 1.0142984620595383
# Epoch #282
# 	Train Loss = 1435828.515625
# 	Train Total MSE = 1.6262136687342696
# 	Train Ux MSE = 0.6595186116744061
# 	Train Uy MSE = 0.09539327885597162
# 	Train p MSE = 0.8713016989627316
# 	Validation Loss = 723460.4765625
# 	Validation Total MSE = 2.282387891866393
# 	Validation Ux MSE = 1.0285760782532773
# 	Validation Uy MSE = 0.23766682269209521
# 	Validation p MSE = 1.0161449903148716
# Epoch #283
# 	Train Loss = 1447473.171875
# 	Train Total MSE = 1.7061950694715315
# 	Train Ux MSE = 0.722723112857029
# 	Train Uy MSE = 0.09855614806750773
# 	Train p MSE = 0.8849157819160567
# 	Validation Loss = 782838.7890625
# 	Validation Total MSE = 2.284856072118727
# 	Validation Ux MSE = 1.0330146983518438
# 	Validation Uy MSE = 0.23336245811591713
# 	Validation p MSE = 1.0184789615162348
# Epoch #284
# 	Train Loss = 1365695.26953125
# 	Train Total MSE = 1.6489742128911589
# 	Train Ux MSE = 0.6526678268832994
# 	Train Uy MSE = 0.11753148865769278
# 	Train p MSE = 0.8787749317140691
# 	Validation Loss = 660831.28125
# 	Validation Total MSE = 2.2549252978825973
# 	Validation Ux MSE = 1.006904136528403
# 	Validation Uy MSE = 0.23305998656709315
# 	Validation p MSE = 1.0149610870975558
# Epoch #285
# 	Train Loss = 1403040.27734375
# 	Train Total MSE = 1.5747641265913628
# 	Train Ux MSE = 0.5652675406230782
# 	Train Uy MSE = 0.12779320572277547
# 	Train p MSE = 0.8817034137839826
# 	Validation Loss = 703022.41015625
# 	Validation Total MSE = 2.23714343572067
# 	Validation Ux MSE = 0.9852442854541843
# 	Validation Uy MSE = 0.2346023026159254
# 	Validation p MSE = 1.0172967825905752
# Epoch #286
# 	Train Loss = 1287373.01171875
# 	Train Total MSE = 1.5273510346259738
# 	Train Ux MSE = 0.5570371116215564
# 	Train Uy MSE = 0.10617928810786922
# 	Train p MSE = 0.8641346410655419
# 	Validation Loss = 591103.54296875
# 	Validation Total MSE = 2.211005828340175
# 	Validation Ux MSE = 0.95635858309471
# 	Validation Uy MSE = 0.240190623978437
# 	Validation p MSE = 1.0144566909741548
# Epoch #287
# 	Train Loss = 1158754.390625
# 	Train Total MSE = 1.4885536950114169
# 	Train Ux MSE = 0.5240455883237433
# 	Train Uy MSE = 0.11366045162212049
# 	Train p MSE = 0.8508476755274975
# 	Validation Loss = 585275.859375
# 	Validation Total MSE = 2.16591540837692
# 	Validation Ux MSE = 0.9153505454629155
# 	Validation Uy MSE = 0.2362077090699794
# 	Validation p MSE = 1.0143570800959054
# Epoch #288
# 	Train Loss = 1193069.52734375
# 	Train Total MSE = 1.5223586580148591
# 	Train Ux MSE = 0.5581330947208683
# 	Train Uy MSE = 0.12325208805740401
# 	Train p MSE = 0.8409735374478488
# 	Validation Loss = 656683.484375
# 	Validation Total MSE = 2.248444185418598
# 	Validation Ux MSE = 0.9784156670004635
# 	Validation Uy MSE = 0.2522764650441833
# 	Validation p MSE = 1.017752163288957
# Epoch #289
# 	Train Loss = 1340689.67578125
# 	Train Total MSE = 1.453021102326952
# 	Train Ux MSE = 0.554443776433739
# 	Train Uy MSE = 0.10019257708124099
# 	Train p MSE = 0.7983847687960366
# 	Validation Loss = 765649.65625
# 	Validation Total MSE = 2.4892471572100106
# 	Validation Ux MSE = 1.2128552582304357
# 	Validation Uy MSE = 0.2526698411521265
# 	Validation p MSE = 1.0237220576253987
# Epoch #290
# 	Train Loss = 1351813.2890625
# 	Train Total MSE = 1.6633806367657276
# 	Train Ux MSE = 0.7561072774948253
# 	Train Uy MSE = 0.12064069283599409
# 	Train p MSE = 0.786632581111641
# 	Validation Loss = 667152.046875
# 	Validation Total MSE = 2.3028664928371625
# 	Validation Ux MSE = 1.0436301409187962
# 	Validation Uy MSE = 0.24175534490811623
# 	Validation p MSE = 1.017481068029242
# Epoch #291
# 	Train Loss = 1259810.75390625
# 	Train Total MSE = 1.5648611558074506
# 	Train Ux MSE = 0.6739483880579645
# 	Train Uy MSE = 0.10579878978061955
# 	Train p MSE = 0.7851140888369813
# 	Validation Loss = 779084.59375
# 	Validation Total MSE = 2.388198425810216
# 	Validation Ux MSE = 1.116212637949798
# 	Validation Uy MSE = 0.2509936575162209
# 	Validation p MSE = 1.0209920323501198
# Epoch #292
# 	Train Loss = 1369098.34375
# 	Train Total MSE = 1.5142381323322263
# 	Train Ux MSE = 0.6292860987582638
# 	Train Uy MSE = 0.0967658191658665
# 	Train p MSE = 0.7881862396488384
# 	Validation Loss = 662038.8359375
# 	Validation Total MSE = 2.2862299773652675
# 	Validation Ux MSE = 1.0377251964504437
# 	Validation Uy MSE = 0.23511459221274167
# 	Validation p MSE = 1.0133901697094159
# Epoch #293
# 	Train Loss = 1287934.03125
# 	Train Total MSE = 1.5729564299736356
# 	Train Ux MSE = 0.6010070500498957
# 	Train Uy MSE = 0.09649392884257237
# 	Train p MSE = 0.8754554280994933
# 	Validation Loss = 702698.5703125
# 	Validation Total MSE = 2.203682928570246
# 	Validation Ux MSE = 0.9545946024231992
# 	Validation Uy MSE = 0.23406504776518225
# 	Validation p MSE = 1.015023284645404
# Epoch #294
# 	Train Loss = 1263782.3046875
# 	Train Total MSE = 1.4980673192193834
# 	Train Ux MSE = 0.5200915281001055
# 	Train Uy MSE = 0.09079920133418314
# 	Train p MSE = 0.8871765997771272
# 	Validation Loss = 670083.55859375
# 	Validation Total MSE = 2.25965379617982
# 	Validation Ux MSE = 1.010870270809885
# 	Validation Uy MSE = 0.23454747280832064
# 	Validation p MSE = 1.0142360357914941
# Epoch #295
# 	Train Loss = 1203518.2578125
# 	Train Total MSE = 1.4958477075871504
# 	Train Ux MSE = 0.5227083589870798
# 	Train Uy MSE = 0.09445480737324706
# 	Train p MSE = 0.878684512467148
# 	Validation Loss = 610419.50390625
# 	Validation Total MSE = 2.1626603272001623
# 	Validation Ux MSE = 0.9161666934773073
# 	Validation Uy MSE = 0.2344263545537399
# 	Validation p MSE = 1.0120671781442934
# Epoch #296
# 	Train Loss = 1141041.9140625
# 	Train Total MSE = 1.4583504623991408
# 	Train Ux MSE = 0.49378159859437637
# 	Train Uy MSE = 0.09482673166792177
# 	Train p MSE = 0.8697421012918733
# 	Validation Loss = 572177.04296875
# 	Validation Total MSE = 2.1730648687330345
# 	Validation Ux MSE = 0.9313185998948954
# 	Validation Uy MSE = 0.23043997004880742
# 	Validation p MSE = 1.0113062381744384
# Model saved!
# Epoch #297
# 	Train Loss = 1129668.16015625
# 	Train Total MSE = 1.4652418714918132
# 	Train Ux MSE = 0.5111979145350332
# 	Train Uy MSE = 0.0844364246196024
# 	Train p MSE = 0.8696075546671976
# 	Validation Loss = 590262.29296875
# 	Validation Total MSE = 2.163350586971994
# 	Validation Ux MSE = 0.9199351100598352
# 	Validation Uy MSE = 0.2316249588788566
# 	Validation p MSE = 1.011790612794585
# Epoch #298
# 	Train Loss = 1143281.92578125
# 	Train Total MSE = 1.4494405056922846
# 	Train Ux MSE = 0.5020171824419116
# 	Train Uy MSE = 0.08350741967515417
# 	Train p MSE = 0.8639159385473318
# 	Validation Loss = 601254.2890625
# 	Validation Total MSE = 2.160300568402824
# 	Validation Ux MSE = 0.9189622264797405
# 	Validation Uy MSE = 0.22939281544442905
# 	Validation p MSE = 1.0119455036470446
# Epoch #299
# 	Train Loss = 1131558.03515625
# 	Train Total MSE = 1.445590764371021
# 	Train Ux MSE = 0.5086501596967958
# 	Train Uy MSE = 0.08190728554572725
# 	Train p MSE = 0.855033346932414
# 	Validation Loss = 582519.28515625
# 	Validation Total MSE = 2.1562320709228517
# 	Validation Ux MSE = 0.9189009714934786
# 	Validation Uy MSE = 0.22497869022821976
# 	Validation p MSE = 1.0123524077868058
# Epoch #300
# 	Train Loss = 1256251.1015625
# 	Train Total MSE = 1.483369982972437
# 	Train Ux MSE = 0.5263256067437264
# 	Train Uy MSE = 0.10615993692993075
# 	Train p MSE = 0.8508844955582661
# 	Validation Loss = 664247.9453125
# 	Validation Total MSE = 2.489941005383508
# 	Validation Ux MSE = 1.1619708691613149
# 	Validation Uy MSE = 0.31004919601699055
# 	Validation p MSE = 1.0179208704980753

# %% [markdown]
# **Exercise 4:**
#
# In this exercise, create another plot function to plot the results of our training and compare it to the ground-truth. For that, build a 3 x 3 plot matrix, in which the first column presents the results of the ground-truth CFD, the second column shows the results by the CNN model, and the third column shows the absolute error between the first and second columns (i.e. between ground-truth and CNN output).

# %%
##########################
##### Your code here #####
##########################

# %%
out = DeepCFD(test_x.to(device))
error = torch.abs(out.cpu() - test_y.cpu())
s =np.random.randint(test_x.shape[0])
visualize(test_y.cpu().detach().numpy(), out.cpu().detach().numpy(), error.cpu().detach().numpy(), s)

# %% [markdown]
# **Exercise 5:**
#
# Go back to exercise 2 and try different model configurations, such as:
#
# Different architectures (UNet, AutoEncoder...)
# Different hyperparameters (filter size, number of filters, learning rate...)
#
# Train the model and plot the results again. How did the above alterations alter the results?
